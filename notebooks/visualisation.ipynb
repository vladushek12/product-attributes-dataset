# %%
import json

import glob
from pathlib import Path
import numpy as np
import pandas as pd
import plotly.express as px

# %% [markdown]
# ## Загрузка датасета

# %%
PATH = "..\\src\\data\\komus\\dataset.json"

# %%
with open(PATH, "r", encoding="UTF-8") as file:
    data = json.load(file)

# %%
print(len(data))
# Out:
# 83755

# %% [markdown]
# ## Обработка категорий

# %%
categories = set()

for product in data:
    categories.update(product["category"])

# %%
len(categories)
# Out:
# 1406

# %% [markdown]
# ## Распределение по атрибутам по категориям

# %%
category_attribute = {}

# %%
for product in data:
    for category in product["category"]:

        if category not in category_attribute:
            category_attribute[category] = {}

        # if "Количество позиций" not in category_attribute[category]:
        #     category_attribute[category]["Количество позиций"] = 0

        # category_attribute[category]["Количество позиций"] += 1

        for attribute in product["attributes"]:
            if attribute not in category_attribute[category]:
                category_attribute[category][attribute] = 0

            category_attribute[category][attribute] += 1

# %% [markdown]
# ## Отображение разложения

# %% [markdown]
# Список категорий

# %%
print(*category_attribute.keys(), sep="\n")
# Out:
# Карандаши
# Карандаши чернографитные
# Коллекции ежедневников
# Канцелярия
# Пленка стрейч упаковочная
# Ящики, лотки, пленка
# Пленка упаковочная
# Пленка пищевая
# Пленка упаковочная хозяйственная
# Расходные материалы для 3D принтеров
# 3D принтеры, сканеры и расходные материалы
# Абразивные расходники
# Адаптеры питания и PoE инжекторы
# Адаптеры питания
# Аэраторы и скарификаторы
# Садовая техника
# Аэрогриль
# Аккумуляторы и блоки питания для этикет-принтеров
# Аккумуляторы и зарядные устройства для инструмента
# Мыши
# Аксессуары
# Клавиатуры
# Эргономика рабочего места
# Подставки для ноутбуков и мобильных устройств
# Гаджеты
# Аксессуары для фото-видеотехники
# Аксессуары для фотоаппаратов
# Карты памяти
# Сумки для фотоаппаратов
# Аксессуары для гаджетов
# Аксессуары для ИБП
# Аксессуары для камер видеонаблюдения
# Аксессуары для кофемашин
# Аксессуары для крупной бытовой техники
# Аксессуары для маникюра и педикюра
# Смарт-часы и фитнес-браслеты
# Аксессуары для мобильных устройств
# Кабели и коннекторы
# Кабели для мобильных устройств
# Внешние аккумуляторы
# Чехлы
# Защитные пленки
# Аксессуары для очков
# Аксессуары для охранных сигнализаций
# Датчики и системы оповещения
# Аксессуары для оптических дисков
# Аксессуары для проекторов
# Указки
# Аксессуары для профессионального аудиооборудования
# Аксессуары для пылесосов и утюгов
# Аксессуары для радиостанций
# Аксессуары для резаков
# Аксессуары для роботов и станков
# Аксессуары для сканеров штрих-кода
# Аксессуары для терминалов сбора данных
# Аксессуары для ценникодержателей
# Аксессуары для цветов
# Аксессуары для ТВ
# Видеосвязь
# Аксессуары для учебных БПЛА
# Аксессуары и инвентарь для санузлов
# Аксессуары для ванных комнат
# Аксессуары и фильтры для очистителей воздуха
# Аксессуары и комплектующие для электротранспорта
# Торговые и рекламные стойки
# Рекламные и торговые стойки
# Аксессуары торгового зала
# Мебель для раздевалок
# Рекламные стойки
# Подставки, стойки и таблички
# Турникеты и системы ограждений
# Манекены, демоформы
# Акустические колонки
# Альбомы для рисования
# Алфавитные и записные книжки
# Аналоговые видеокамеры
# Анемометры (измерители скорости потока воздуха)
# Антивирусы
# Программное обеспечение
# Аппараты для хот-догов
# Аппараты для поп-корна
# Аппараты для шаурмы
# Строительное оборудование
# Аппараты для сварки пластиковых труб
# Аппараты для варки кукурузы
# Аппараты пончиковые
# Аптечки и наборы для автомобилистов
# Аптечки индивидуальные и коллективные
# Аптечки
# Аптечки металлические
# Ароматические саше, палочки, лампы
# Свечи и ароматы для дома
# Личная гигиена
# Для дома
# Ассортимент для аренды кофемашин
# АТС
# Сервера и АТС
# Аудиокомплекты
# Аварийные принадлежности
# Автохимия
# Автокомпрессоры
# Автомобильные аксессуары
# Автомобильные холодильники
# Автомобильные видеорегистраторы
# Автономные системы и модули пожаротушения
# Бакалея
# Бахилы
# Банкетки детские
# Банкетки
# Многоместные секции
# Банки пластиковые
# Барное оборудование
# Соковыжималки профессиональные
# Барные стулья
# Бассейны и аксессуары для бассейнов
# Батареи для ИБП
# Батарейки, аккумуляторы, зарядные устройства
# Лампочки и сопутствующие товары
# Батуты
# Беcпроводное оборудование
# Бейджики, шнурки, рулетки
# Белье для защиты от электродуги
# Бескаркасная детская мебель
# Пуфы и бескаркасная мебель
# Бескаркасная мебель
# Беззеркальные фотоаппараты
# Биговщики
# Оптическая техника и аксессуары
# Бинокли
# Биометрические системы контроля доступа
# Бирки для ключей
# Блендеры
# Блинницы профессиональные
# Блоки питания
# Блокноты для флипчартов
# Флипчарты и аксессуары
# Тетради и блокноты
# Блокноты и бизнес-тетради
# Блюдца
# Бочки пластиковые и металлические
# Ведра, канистры, бутыли
# Одноразовая посуда
# Бокалы одноразовые
# Бокалы, стаканы, стопки
# Наборы и корзины
# Стеклянная посуда для напитков
# Посуда
# Боксерские мешки и груши
# Пакеты полиэтиленовые и бумажные
# БОПП и ПП пакеты
# Ботинки для сварщиков
# Специализированная обувь
# Настенное освещение
# Бра
# Светильники и гирлянды
# Брелоки и аксессуары
# Брошюровщики
# Будильники
# Часы и метеостанции
# Часы
# Бухгалтерские книги и бланки
# Журналы и книги учета
# Книги специализированные
# Бумага для полноцветной лазерной печати
# Бумага для широкоформатных принтеров и чертежных работ
# Ватман
# Калька
# Миллиметровая бумага
# Бумага для заметок
# Закладки для книг и тетрадей
# Бумага для живописи и сухих техник
# Бумага перфорированная однослойная
# Бумажная продукция с вашим логотипом
# Бумажно-гигиеническая продукция
# Бумажные полотенца
# Туалетная бумага и покрытия для унитаза
# Бутылки для воды, спортивные шейкеры
# Красота
# Бутылки
# Чай
# Чайники для кипячения
# Чайники заварочные
# Чашки, кружки, чайные пары
# Чашки одноразовые
# Интерьерные часы
# Метеостанции
# Детям
# Электроника с вашим логотипом
# Чехлы для бутилированной воды
# Чековая лента и ролики
# Ролики и чековая лента
# Черенки
# Инвентарь для улиц и садовых работ
# Чистящие и моющие средства
# Системы оповещения
# Контрольные датчики
# Системы оповещения световые
# Комплекты охранной сигнализации
# Приемники, видеопередатчики, микрофоны
# Датчики умного дома
# Электрогирлянды для внешнего использования
# Уличное освещение
# Электрогирлянды
# Декоративное освещение
# Свечи и подсвечники
# Декоративные светильники
# Светильники
# Декоративный текстиль
# Пледы, покрывала и декоративные подушки
# Деловые папки и портфели
# Демонстрационное оборудование с вашим логотипом
# Демонстрационные системы
# Денежные ящики
# Дерматологические средства защиты кожи
# Держатели для шлифовальной бумаги
# Держатели в автомобиль
# Детекторы металла (проводки)
# Детекторы утечек газов
# Детекторы валют и ценных бумаг
# Детские сиденья, горшки
# Конструкторы робототехнические
# Наборы для творчества и лепки
# Головоломки
# Настольные подставки и наборы
# Подставки для ручек
# Канцелярские наборы и подставки
# Меловые магнитные доски
# Школьные блокноты и тетради
# Тетради общие
# Гарнитуры
# Наушники
# Стиль
# Рюкзаки и ранцы
# Прочее оснащение для спортзалов
# Игры развивающие
# Кулеры, пурифайеры, помпы и аксессуары
# Столы детские
# Стулья детские
# Мягкая детская мебель
# Диэлектрический инструмент
# Отвертки
# Наборы инструментов
# Шарнирно-губцевый и зажимной инструмент
# Канцелярские ножницы и ножи
# Ножи профессиональные
# Диктофоны цифровые
# Диспенсеры для лент
# Клейкие ленты и держатели
# Упаковочные инструменты
# Диспенсеры для стрейч-пленки
# Дозаторы и расходные материалы
# Диспенсеры и держатели
# Освежители воздуха
# Протирочные материалы и диспенсеры
# Дисплей покупателя
# Дистанционное управление, кнопки выхода
# Дистанционное управление умного дома
# Дистиллированная вода
# Диваны двухместные
# Диваны трехместные
# Диваны угловые
# Рамки, грамоты, медали
# Дизайнерская и сертификат-бумага
# Вазы
# Цветы и растения
# Кашпо и горшки для цветов
# Цифровые фоторамки
# Столовый и кухонный текстиль
# Искусственные растения
# Цветочницы и подставки для растений
# Картины, постеры, панно
# Украшение интерьера
# Постельное белье
# Столы интерьерные
# Мебель в интерьере
# Салфетки
# Для сервировки стола
# Дневники школьные, расписания уроков
# Док-станции
# Документ-камеры
# Домкраты
# Домофоны
# Дополнительное электромеханическое оборудование и аксессуары
# Дополнительное оборудование и аксессуары для фаст-фуда
# Дополнительное оборудование и аксессуары для кондиционеров
# Дополнительное оборудование и аксессуары для нарезки, смешивания, отжима
# Дополнительное оборудование и аксессуары для обогревателей
# Дополнительное оборудование, трансиверы
# Дополнительное оборудование
# Дополнительное прачечное оборудование и аксессуары
# Дополнительное тепловое оборудование и аксессуары
# Дополнительные элементы для производственной мебели
# Дополнительные элементы к шкафам
# Дополнительные элементы кухонной мебели
# Дополнительные элементы мебели для гостиниц
# Дополнительные элементы мебели
# Дополнительные элементы
# Стеллажи, стойки для торговли
# Дополнительные и запасные части для печатающей техники
# Дополнительные полки к шкафу
# Телефонные аппараты
# Дополнительные трубки
# Дорожная инфраструктура и ограждения
# Дорожные, спортивные сумки
# Доски для лепки
# Доски комбинированные
# Пробковые доски
# Доски пробковые и планшеты
# Пластиковые доски-планшеты
# Доски раздвижные под интерактивные системы
# Доводчики
# Мыло
# Дрели и шуруповерты
# Двери и дверная фурнитура
# Двери к шкафам
# Дыроколы и расходные материалы
# Дюбель-гвозди
# Дюбели
# Экраны для кондиционеров
# Экраны для проекторов
# Экраны и фронтали
# Экшн-камеры
# Экзоскелеты
# Гигиена полости рта
# Электрические зубные щетки
# Средства для бритья и депиляции
# Электробритвы
# Электрочайники
# Электрогрили
# Электролобзики
# Электронные книги
# Электронные переводчики и словари
# Электропилы
# Электрорубанки
# Электросамокаты
# Электрощитовое оборудование
# Электросковороды профессиональные
# Электровелосипеды
# Элементы бенч-систем
# Элементы ресепшн
# Елки и изделия из хвои
# Елочные игрушки
# Эмаль
# Эпиляторы
# Коврики защитные под кресла
# Настольные лампы
# Напольное и настольное освещение
# Настольные лампы и торшеры
# Коврики на стол
# Корзины для бумаг
# Мешки и емкости для мусора
# Эспандеры, ленты, силовые тросы
# Этикет-лента для этикет-пистолетов
# Этикет-пистолеты
# Этикет-принтеры
# Этикетки для инвентаризации
# Этикетки для почтовой рассылки
# Противокражное оборудование и аксессуары
# Этикетки-пломбы
# Ежедневники и еженедельники
# Планинги
# Файлы и папки файловые
# Файлы
# Папки пластиковые
# Фартуки для барменов и официантов
# Униформа для сферы общественного питания
# Фартуки для поваров
# Фартуки для производства
# Униформа для работников производства
# Фартуки для уроков труда и творчества
# Фартуки одноразовые
# Фартуки, подшлемники и аксессуары для сварщиков
# Фейерверки и салюты
# Фены настенные
# Фены
# Уход за волосами и стайлинг
# Фигурки и статуэтки
# Фигурные и цветные этикетки
# Фильтры и водоочистители
# Фискальные регистраторы
# Фитболы
# Флаги и гербы
# Флагштоки
# Флеш-память USB
# Фломастеры
# Цветные карандаши, фломастеры
# Фляги
# Фольга пищевая
# Фонари
# Освещение для стройки и дачи
# Форматная бумага цветная
# Форматная бумага
# Формы фуршетные
# Фотобумага
# Фотообработка и печать
# Фоторамки, рамки для сертификатов
# Праздничная и поздравительная продукция
# Френч-прессы
# Фрезеры
# Фритюрницы и чебуречницы профессиональные
# Фризеры для мороженого
# Фрукты, ягоды и наборы
# Подарочные корзины
# Фуршетное меню
# Портативная акустика
# Пылесосы
# Конференц - связь
# Внешние жесткие диски
# Гайковерты и винтоверты
# Гамаки и качели
# Кресла подвесные
# Гантели, гири, штанги
# Гардеробы для гостиниц
# Мебель для общежитий
# Гарнитуры для компьютеров
# Гарнитуры для офисных работников
# Набор для специй
# Важные мелочи
# Сервировка стола
# Гастроемкости, банки, миски, контейнеры
# Контейнеры для продуктов
# Сахарницы
# Генераторы электричества
# Гидравлические тележки
# Паллеты и тележки
# Ирригаторы для полости рта
# Насадки для зубных щёток и ирригаторов
# Гигрометры, влагомеры
# Гитары
# Гладильные доски
# Гладильные катки
# Глина, пластика, паста для лепки
# Глобусы и карты
# Карты и атласы
# Головные уборы для защиты от электродуги
# Головные уборы
# Медицинская одежда
# GPS навигация
# Графические планшеты
# Графические редакторы
# Графины, кувшины
# Грамоты, дипломы, благодарности
# Грили профессиональные
# Громкоговорители и встраиваемая акустика
# Грузоподъемное оборудование
# Грузовые тележки
# Гуашь
# Кухонные губки, салфетки и щетки
# Тряпки, салфетки, губки
# Губки для мытья посуды
# Губки-стиратели
# Гвозди
# Идентификаторы
# Игловые пистолет-маркираторы
# Иглы для пистолет-маркираторов
# Игровая мебель
# Игровые приставки и аксессуары
# Игровые столы и аксессуары
# Икра
# Инъекционные средства
# Световые панели, стойки, меню
# Информационное световое оборудование
# Информационные доски-витрины
# Информационные панели
# Информационные стенды и рамки
# Плакаты информационные
# Инструменты для снятия пломб
# Инструменты для живописи
# Интеллектуальные интерактивные роботы
# Интерактивные системы
# Интерком-системы
# Интернет-планшеты
# Инвентарь для мытья окон
# Распылители
# Салфетки хозяйственные
# Опрыскиватели и системы полива
# Опрыскиватели ручные
# Инвентарь для мытья стекол
# Инвентарь для уборки пола
# Швабры, сгоны, рукоятки
# Тележки и ведра для уборки
# Щетки, скребки и сгоны
# Совки
# Лопаты для грунта
# IP-видеокамеры
# Силовое оборудование
# Источники бесперебойного питания
# Сетевые фильтры и удлинители
# Источники питания СКУД
# Изделия для электромонтажа
# Кабель и провод
# Измельчители садовые
# Кабеленесущие системы
# Сетевые кабели и коннекторы
# Стяжки для кабелей
# Кабели и переходники USB
# Кабели питания, шлейфы, переходники
# Кабины акустические
# Календари
# Калькуляторы
# Каллиграфия и графика
# Стержни, чернила, тушь
# Канистры и воронки для ГСМ
# Канистры, ведра, бутыли
# Канистры
# Канцтовары класса Люкс
# Подставки для книг
# Ластики, точилки
# Ластики, точилки, линейки
# Линейки
# Корректоры для текста
# Клей
# Ножницы канцелярские
# Ручки со стираемыми чернилами
# Ручки
# Шариковые ручки
# Папки с арочным механизмом
# Лотки и накопители для бумаг
# Папки на кольцах
# Папки-конверты
# Папки-уголки
# Канцелярские мелочи
# Запасные лезвия для канцелярских ножей
# Капсульные кофемашины
# Карандаши и ручки для маркировки
# Профессиональные маркеры
# Карандаши художественные
# Карандаши цветные
# Карманы для маркировки паллет и стеллажей
# Карнавальные костюмы и аксессуары
# Новогодний декор
# Праздничный декор
# Картотеки, разделители, индексные окна
# Шкафы картотечные и картотеки
# Картридеры
# Картриджи для этикет-принтеров
# Специализированные картриджи
# Картриджи для лазерных принтеров, копиров и МФУ
# Картриджи для струйных принтеров, копиров и МФУ
# Касса слогов и счетного материала
# Кассовые аппараты
# Кастрюли, сотейники, котлы, мантоварки
# Наборы посуды для приготовления
# Кемпинговая мебель
# Кэшбоксы
# Халаты одноразовые
# Хлебобулочные изделия
# Хлебопечки
# Хлеборезки
# Холодильники
# Холодильные моноблоки
# Холсты
# Хомуты
# Хозяйственные и промо сумки, тележки
# Хранение и порядок
# Уход за обувью и одеждой
# Уход за одеждой
# Вешалки-плечики
# Хранение инструмента
# Сумки и рюкзаки для инструментов
# Хрестоматии и внеклассное чтение для детей
# Кипятильники профессиональные
# Кисти для рисования
# Кисти, валики, губки
# Классические МР3-плееры
# Клавишные инструменты
# Клей, герметик, пена монтажная
# Клей универсальный
# Клей специальный
# Клей-спрей
# Клейкие ленты и скотч
# Клейкие ленты
# Скотч и клейкие ленты
# Малярные ленты
# Ключи активации и сервисные контракты
# Ключи
# Кофе, какао
# Кофемашины
# Кофемолки профессиональные
# Кофемолки
# Кофеварки профессиональные
# Кофеварки
# Колеса, колесные опоры и ролики для тележек
# Кольца и ленты бандерольные
# Комбинезоны одноразовые
# Комбоусилители для электрогитар
# Коммутаторы
# Коммутация и управление световым оборудованием
# Комнатные растения
# Растения, саженцы, семена
# Живые растения
# Компакт-диски
# Компактные фотоаппараты
# Компасы
# Комплектующие для кресел
# Комплектующие для ламп и светильников
# Комплектующие для серверов
# Комплекты акустики
# Комплекты видеонаблюдения
# Компоненты и аксессуары для умного дома
# Ноутбуки
# Компьютерная техника для конференций
# Моноблоки
# Системные блоки
# Кондитерский инвентарь
# Кондиционеры мобильные
# Конференц-кресла
# Конференц-столы
# Профессиональные акустические системы
# Конфеты
# Шоколад порционный, плитки, батончики
# Вкусности
# Консервация
# Сиропы и топпинги
# Конструкторы
# Контейнеры алюминиевые
# Контейнеры бумажные
# Контейнеры для хранения бытовые
# Контейнеры бытовые
# Контейнеры для кондитерских изделий
# Контейнеры пластиковые
# Контроллеры
# Коробки для пиццы и пирогов
# Коробки картонные
# Корпусы для ПК
# Корщетки
# Костюмы для сварщиков
# Костюмы для защиты от электродуги
# Коврики диэлектрические и противоусталостные
# Коврики для фитнеса
# Коврики для мыши
# Входные коврики и напольные покрытия
# Коврики входные
# Коврики защитные для резки
# Крафт-мешки
# Мешки, биг-бэги
# Мешки
# Крафт-пакеты с воздушной подушкой
# Пакеты
# Крафт пакеты
# Перчатки
# Краги
# Краски акварельные
# Краски художественные
# Краски пальчиковые
# Краскопульты
# Мячи
# Массажеры и оборудование для массажа
# Приборы для ухода за лицом
# Текстиль с электроподогревом
# Красящая лента (риббоны)
# Крепежная фурнитура
# Кресла для баров и ресторанов
# Кресла для детей компьютерные
# Стулья и кресла для школьников
# Кресла для кассиров
# Кресла для персонала
# Мебель лабораторная
# Кресла для производств и лабораторий
# Кресла для руководителей
# Кресла игровые
# Кресла
# Кронштейны для СВЧ-печей
# Кровати детские
# Кровати для гостиниц
# Кровати и матрасы
# Матрасы
# Кровати металлические
# Крупы, макароны, мука
# Крышки для посуды
# Крышки и держатели для стаканов
# Крючки
# Кухонные аксессуары
# Кухонный инвентарь
# Шкафы кухонные
# Кухонные гарнитуры
# Столешницы кухонные
# Стеновые панели для кухни
# Кухонные щетки, скребки
# Кухонные комбайны
# Ножи кухонные
# Подносы
# Разделочные доски
# Штопоры, открывалки, пробки для бутылок
# Лотки и сушилки
# Овощерезки и овощечистки
# Кулеры для процессора
# Культиваторы и мотоблоки
# Курьер-пакеты, сейф-пакеты
# Куртки и плащи для защиты от электродуги
# Куттеры
# Лабораторная мебель
# Ламинаторы
# Лампочки
# Удлинители
# Розетки и выключатели
# Лампы светодиодные высокой мощности
# Лампы для детекторов валют
# Ланч-боксы
# Лари морозильные
# Лазерные дальномеры (рулетки)
# Ленты для ограждения и разметки
# Ленты для принтеров пластиковых карт
# Тапочки одноразовые
# Ликвидация униформы
# Линеры
# Лингафонные кабинки и столы
# Лопаты автомобильные и универсальные
# Пластиковые ящики
# Лотки складские
# Ложки одноразовые
# Лупы
# Люксметры (измерители освещенности)
# Магнитно-маркерные доски
# Магнитные держатели для досок
# Малярный инструмент
# Манометры
# Маркеры для досок
# Маркеры для творчества
# Маркеры перманентные
# Маркеры специальные
# Мармиты
# Машинки для стрижки волос
# Посудомоечное оборудование
# Машины посудомоечные профессиональные
# Маски медицинские
# Массажные кресла
# Материнские платы
# Матрасы и наматрасники
# Маты спортивные
# Мебель для бани и сауны
# Мебель для банкетов и кейтеринга
# Мебель для библиотек
# Мебель для кабинета врача
# Мебель для кукол
# Шкафы с полками, комбинированные для гостиниц
# Тумбы прикроватные для гостиниц
# Мебель для пищевых производств
# Стеллажи пищевые
# Мебель для столовых
# Мебель для улицы
# Зеркала
# Шкафы и стеллажи для дома и дачи
# Тумбы и комоды для дома
# Системы хранения
# Столы для школьников
# Столы для дома и дачи
# Модульная мягкая мебель
# Перегородки для зонирования пространства
# Медали, ленты, кубки
# Медицинская мебель для больничной палаты
# Медицинская мебель для процедурных
# Медицинские металлические шкафы, стойки
# Медицинские приборы
# Механизмы и материалы для архивации
# Степлеры электрические
# Мел
# Мешки для сменной обуви
# Ведра для бытового мусора
# Металлодетекторы
# МФУ
# Микроволновые печи
# Миксеры профессиональные
# Миксеры
# Микшерные пульты
# Мини-бары
# Мини-кухни
# Мини-печи
# Мишура, дождик, бусы
# Многофункциональный инструмент
# Мобильная связь
# Смартфоны
# Мобильные телефоны
# Сим-карты и тарифные планы
# Модемы
# Модули ресепшн
# Модули угловые
# Мойки высокого давления
# Смесители и мойки
# Мойки
# Мольберты
# Молоко и молочные напитки
# Молочная продукция
# Сливки натуральные и сухие
# Молотки отбойные
# Мониторы
# Моноподы и штативы для смартфонов
# Монтажное оборудование
# Морозильники
# Мультимедиа проекторы
# Мультиметры
# Мультитулы
# Мультиварки
# Мультстудии
# Музыкальные центры
# Мягкие детские игровые комплексы
# Мягкие контурные игрушки
# Мясорубки и мясоразрыхлители профессиональные
# Мясорубки
# Набор принадлежностей для белых магнитно-маркерных досок
# Подарочные чайные и кофейные сервизы
# Сервизы для чая и кофе
# Подарочные продуктовые корзины
# Наборы и сервизы для чая и кофе
# Подарочные наборы с персонализацией
# Наборы клавиатура+мышь
# Наградная продукция с вашим логотипом
# Накладки защитные для мебели
# Наклейки для мебели
# Наколенники защитные
# Средства предупреждения травм
# Напильники и надфили
# Нарукавники одноразовые
# Насосы и оборудование
# Научно-образовательное ПО
# Навигационное ПО и карты
# Нить, иглы, ленты, шнуры для прошивки документов
# Нитки и иголки
# Нивелиры
# Низковольтное оборудование
# Носки трикотажные
# Зимний спорт
# Новогодний досуг
# Ножи для электрорубанков
# Ножи одноразовые
# Ножницы по металлу и болторезы
# Ножовки по дереву и металлу
# Обеденные комплекты
# Обложки для переплета
# Обложки для термопереплета
# Облучатели-рециркуляторы, соляные лампы
# Тепловые завесы
# Обогреватели
# Оборудование для чистки и нарезки овощей
# Оборудование для дезинфекции и очистки
# Оборудование для уборки
# Оборудование для работ на высоте
# Пылесосы профессиональные
# Поломоечные машины
# Оборудование для видеоконференций
# Оборудование VoIP
# Образовательные наборы
# Обручи спортивные
# Обслуживание и ремонт зерновых кофемашин
# Обувь от термических рисков электродуги
# Очистители воздуха
# Очки защитные для газосварочных, доменных и прокатных работ
# Очки
# Одежда от повышенных температур
# Стаканы одноразовые
# Одноразовые тарелки и миски
# Вилки одноразовые
# Размешиватели
# Одноразовое медицинское белье
# Перчатки медицинские
# Одноразовые перчатки
# Перчатки одноразовые нитриловые и латексные повышенной прочности
# Перчатки полиэтиленовые и ТПЭ
# Офисное ПО
# Офисные принадлежности с вашим логотипом
# Офисные защитные экраны на опорах
# Офисные защитные экраны на струбцинах
# Огнетушители
# Оперативная память
# Операционные системы
# Опрыскиватели аккумуляторные и помповые
# Оптические приводы для ПК
# Опции для принтеров пластиковых карт
# Орехи и сухофрукты
# Организаторы интерьера
# Оснастка для дрелей
# Оснастка для электропил
# Оснастка для фрезеров
# Оснастка для лобзиков
# Оснастка для МФ-инструмента и граверов
# Оснастка для паяльных работ
# Оснастка для перфораторов и отбойных молотков
# Оснастка для шлифовальных машин
# Оснастка для шуруповертов и гайковертов
# Оснастка для строительных пылесоcов
# Оснастка для сварочных работ
# Осушители воздуха
# Прожекторы светодиодные
# Светильники уличные и ЖКХ
# Профессиональная химия
# Отпариватели
# Отвертки аккумуляторные
# Овощи, зелень, грибы
# Пакеты для транспортировки и хранения
# Пакеты фасовочные
# Пакеты майка
# Пакеты пищевые бумажные, уголки
# Пакеты с замком Zip Lock
# Пакеты вакуумные для продуктов
# Пакеты полиэтиленовые с вырубной ручкой
# Пакеты с петлевыми ручками
# Палатки
# Паллеты пластиковые
# Тележки складные
# Ручки, полки и борта для ручных тележек
# Тележки электрические
# Столы подъемные
# Папки адресные
# Папки архивные
# Папки для черчения
# Папки для школы
# Папки для труда
# Папки-планшеты
# Парогенераторы
# Пароконвектоматы
# Пароочистители и паровые швабры
# Пароварки профессиональные
# Паровые системы
# Парты
# Пастель, сангина, уголь
# Патроны, фильтры и расходные материалы
# Паяльники
# Пазлы
# Печати и штампы
# Штемпельные краски
# Печенье, крекеры, пряники
# Печи для фаст-фуда
# Печи для пиццы
# Печи конвекционные
# Печи подовые
# Пеналы, тубусы для ключей
# Перчатки резиновые хозяйственные и КЩС
# Перчатки и рукавицы хозяйственные
# Перчатки для дачи и сада
# Перчатки для защиты от механических повреждений
# Перчатки от термических рисков электрической дуги
# Рукавицы
# Перевязочные средства
# Перфораторы
# Пирометры
# Писчая бумага
# Письменные принадлежности с вашим логотипом
# Пистолеты для пен и герметиков
# Пистолеты гвоздезабивные (нейлеры)
# Пистолеты клеевые
# Пистолеты монтажные аккумуляторные
# Учебно-лабораторное оборудование
# Плакаты и методические пособия
# Плашки, печати для опечатывания
# Пластиковая мебель
# Ящики пластиковые для склада
# Ящики пластиковые пищевые
# Ящики для овощей, фруктов и ягод
# Пластилин скульптурный и гипс
# Пластилин
# Пледы и покрывала
# Пленка для ламинирования
# Пленка строительная
# Плетеная мебель
# Плиткорезы ручные
# Плиты для фаст-фуда
# Плиты электрические
# Плиты газовые
# Плиты профессиональные
# Пломбираторы
# Пломбы для опломбирования
# Плоттеры
# Пневмоинструмент
# ПО для идентификации, защиты информации, электронной подписи
# ПО для систем видеонаблюдения
# ПО для торговли
# Почтовые конверты и пакеты
# Почтовые ПЭ пакеты
# Подарочная упаковка
# Подарочные карты и сертификаты
# Подогревающие лампы и поверхности
# Подписки на сервисы
# Подставки и кронштейны для огнетушителей
# Подставки под системный блок
# Подушки для смачивания пальцев
# Подушки и одеяла
# Подвесная регистратура
# Подвязки и опоры для растений
# Покупательские тележки, корзины
# Полиграфическое оборудование
# Полиграфия с вашим логотипом
# Полипропиленовые ленты и защитные уголки
# Полки к стеллажам
# Полки
# Полнолицевые маски и противогазы
# Промышленные и сервисные роботы
# Полотенца
# Полотенца белые
# Полотна ножовочные
# Полумаски
# Полупромышленные сплит-системы
# Поршневые компрессоры
# Посуда для СВЧ
# Посуда для запекания
# Столовая посуда
# Посуда с вашим логотипом
# Термосумки, термопакеты
# Посудомоечные машины
# Потолочное освещение
# Светильники светодиодные
# Поварской инвентарь
# Поверхности жарочные
# Поздравительные открытки и подарочные конверты для денег
# Пожарные рукава и расходные материалы
# Праздничная одноразовая посуда
# Презентеры
# Приемники и держатели измерительного оборудования
# Принадлежности для парикмахеров
# Принтеры матричные
# Принтеры пластиковых карт
# Принтеры
# Приставки к столу
# Прочая техника для кухни
# Продукты быстрого приготовления
# Средства для стирки
# Профессиональная техника для укладки волос
# Профессиональные кофемашины
# Профессиональные микроволновые печи
# Профессиональные стирально-сушильные машины
# Профессиональные стиральные машины
# Профессиональные сушильные машины
# Программы для смартфонов
# Видеоредакторы и мультимедиа
# SIEM системы, мониторинг и корреляция событий ИБ
# Программное обеспечение для управления бизнесом
# Программы для архитектуры и строительства
# Проигрыватели виниловых дисков
# Промышленное проектирование
# Зеркала противокражные
# Противопожарные принадлежности
# Процессоры
# Проводные микрофоны
# Проволока пломбировочная
# Пружины и каналы для переплета
# Пуфы
# Пускозарядные устройства
# Пылесосы строительные
# Рабочая летняя спецобувь
# Рабочая резиновая спецобувь
# Рабочая летняя спецодежда
# Сигнальная одежда
# Рабочая непромокаемая спецодежда
# Униформа для охранников
# Резиновая обувь
# Рабочая спецодежда для защиты от кислот и щелочей
# Рабочая зимняя спецобувь
# Рабочая зимняя спецодежда
# Рабочие жилеты утепленные
# Рабочие тетради и прописи
# Работа с текстом и речью
# Радар-детекторы
# Радио и аудио гиды
# Радиоприемники
# Радиотелефоны
# Рамки пластиковые
# Расходные материалы для факсимильных аппаратов
# Расходные материалы для генераторов эффектов
# Расходные материалы для поломоечных машин
# Расходные материалы для стройки и дачи
# Расходные материалы и аксессуары
# Раскраски
# Рации, радиостанции
# Разбавители, масла, лаки, грунты
# Разделители полочные
# Разделители
# Рекордеры
# Ременные компрессоры
# Ремешки для смарт-часов и фитнес-браслетов
# Респираторы
# Ресурсные наборы и запчасти
# Резаки
# Резьбонарезной инструмент
# Резинки для денег и напальчники
# Рисоварки профессиональные
# Ролики красящие
# Роллеры и блоки для йоги
# Роллеры
# Рубанки ручные
# Ручки гелевые
# Ручки на подставке
# Ручки перьевые
# Ручные аппликаторы этикеток
# Ручные рулетки
# Ручные уровни и угольники
# Рукоделие и декорирование
# Рулонные шторы и жалюзи
# Рюкзаки для ноутбуков
# Рюкзаки спортивные и туристические
# Садовая сантехника
# Умывальники
# Секаторы и садовые ножницы
# Снегоуборщики
# Садовые фонарики
# Садовый инструмент
# Салфетки, полотенца для авто и промышленной техники
# Средства личной гигиены
# Салфетницы для домашней сервировки
# Самоклеящиеся этикетки для компакт-дисков
# Самоклеящиеся этикетки для папок
# Самоклеящиеся карманы и этикетки для папок
# Самоклеящиеся этикетки удаляемые
# Самоклеящиеся этикетки универсальные
# Самоклеящиеся этикетки всепогодные
# Саморезы и шурупы
# Самоспасатели
# Санобработка водораздаточного оборудования
# Смесители
# Сантехника
# Саундбары
# Счетчики и сортировщики банкнот
# Счетчики монет
# Считыватели, контроллеры, панели
# Сейфы автомобильные
# Сейфы депозитные
# Сейфы для дома и отелей
# Сейфы офисные
# Сейфы несгораемые
# Секундомеры и шагомеры
# Серверное ПО
# Серверы
# Зубочистки
# Сеть и интернет
# Сетевой инструмент
# Сетевые фильтры
# Удлинители бытовые
# Сетевые хранилища (NAS)
# Сетевые коннекторы и розетки
# Сетки и канаты
# Шапочки, балаклавы, сеточки
# Шезлонги
# Щетки и скребки автомобильные
# Щетки металлические
# Щитки защитные
# Щупы измерительные
# Шкафы для бумаг
# Шкафы для классов
# Шкафы для одежды
# Шкафы металлические для сумок
# Шкафы для спец.средств
# Шкафы для ванной
# Шкафы и полки детские
# Шкафы и стойки для сетевого оборудования
# Шкафы инструментальные
# Шкафы картотечные
# Шкафы холодильные, морозильные
# Шкафы хозяйственные
# Шкафы расстоечные
# Шкафы, щиты и ящики пожарные
# Шкафы тамбурные
# Шкафы-витрины кондитерские
# Шкафы взломостойкие
# Шкафы
# Шкатулки
# Школьные тетради (12-24 листов)
# Школьные наборы
# Школьные обложки
# Школьные пеналы
# Шлифмашины прямые и граверы
# Шлифмашины
# Шнурки, стельки, вкладыши
# Уход за обувью
# Шпагаты
# Штангенциркули
# Штативы для нивелиров
# Штендеры
# Шторы
# Штроборезы
# Швейные машины
# Стабилизаторы напряжения для техники
# Системы виртуализации (гипервизоры)
# Системы виртуальной реальности
# Ситечки для чая
# Скакалки
# Скамьи
# Скандинавская ходьба
# Сканеры штрих-кода
# Сканеры
# Скатерти и плейсматы
# Скоросшиватели
# Сковороды, казаны, жаровни
# Сладкие детские подарки
# Слайсеры
# Сменные блоки для тетрадей
# Снеки, жевательная резинка
# Соединители пластиковые для пистолет-маркираторов
# Соковыжималки
# Соусники пластиковые
# Спальные мешки
# Сплит-системы бытовые
# Спортивная форма и защита
# Спортивные комплексы, скамейки, стенки
# Тренажеры
# Спрей для очистки досок
# Спутниковый интернет
# Средства для дезинфекции
# Средства для кухни и мытья посуды
# Средства для промывания глаз
# Средства защиты от насекомых и вредителей
# Защита от вредителей
# Средства защиты от падения с высоты
# Стабилизаторы релейные
# Стайлеры для волос
# Стаканы и палитры для рисования
# Стамески
# Станки
# Стеки, трафареты для лепки
# Стеклоочистители
# Стеклоомывающая (незамерзающая) жидкость
# Стеклорезы
# Стеклянные доски
# Стеллажи для воды бутилированной
# Стеллажи гардеробные
# Стеллажи легкие
# Стеллажи паллетные
# Стеллажи специализированные
# Стеллажи среднегрузовые
# Степ-платформы
# Степлеры и скобы
# Стержни для клеевых пистолетов
# Стиральные машины
# Стойки и кольца
# Столовые приборы
# Столы для переговоров
# Столы для руководителя
# Столы для заседаний руководителей
# Столы письменные
# Стулья обеденные
# Столы и стулья
# Столы обеденные
# Табуреты
# Столы холодильные и морозильные
# Столы приставные
# Столы-трансформеры, коворкинг
# Столы, тумбы под минибар для гостиниц
# Столы учительские
# Строительные степлеры и скобы
# Студийные микрофоны и радиосистемы
# Студийные мониторы
# Стулья офисные
# Стулья школьные
# Сухие бассейны, манежи
# Сумки для ноутбуков
# Сумки и кожгалантерея с вашим логотипом
# Сумки инкассаторские
# Сургуч, пластилин для опечатывания
# Сушилки для белья
# Сушилки для рук
# Сварочные аппараты
# Сварочные маски и аксессуары
# Светильники для школьных досок и спортзалов
# Светильники переносные
# Светильники с вашим логотипом
# Световые головы и прожекторы
# Сыр, колбаса, рыба
# Технические очистители и смазки
# Технические ткани
# Технические жидкости для автомобилей
# Текстиль для ванной, бани и SPA
# Текстиль с вашим логотипом
# Текстовыделители
# Телефоны проводные
# Телефонные кабели
# Телевизоры
# Тележки специализированные
# Тележки для ноутбуков
# Теннис и бадминтон
# Тенты садовые
# Тенты, уличные зонты, навесы, маркизы
# Теодолиты
# Тепловизоры
# Теплый пол
# Терминалы сбора данных
# Термо-паста
# Термоэтикетки (печать с помощью термоголовки)
# Термометры
# Термопистолеты
# Термопоты
# Термотрансферные этикетки
# Тестеры напряжения
# Тесто для лепки, кинетический песок
# Тестомесы и тестораскаты
# Тетради со сменными блоками
# Тетради предметные, нотные
# Тиски и струбцины
# Точки доступа
# Толщиномеры
# Топоры
# Ударно-рычажный инструмент
# Торговая мебель
# Торговые системы
# Тостеры профессиональные
# Тостеры
# Товары для бани и сауны
# Трассы для БПЛА
# Треккинговая обувь
# Тренажеры и манекены для оказания первой помощи
# Трибуны
# Трикотаж
# Триммер
# Ценники бумажные
# Ценники-таблички
# Ценникодержатели напольные/стойки
# Ценникодержатели настольные
# Ценникодержатели подвесные
# Ценникодержатели полочные
# Ценникодержатели специализированные
# Центры управления умного дома
# Цифровые лаборатории
# Циркули и готовальни
# Цветная бумага и картон
# Тубусы
# Тумбы и тележки инструментальные
# Тумбы с раковиной
# Тумбы, шкафы для классной доски
# Тумбы
# Турникеты и шлагбаумы
# ТВ-подписки
# Тюль
# Учебные комплекты БПЛА
# Учебные станки и автоматические линии
# Удаленное управление доступом и сетью
# Ударные инструменты
# Удобрения и грунты
# Угломеры
# Уголки, вешалки для ряжения
# Уход за салоном
# Уничтожители и расходные материалы
# Униформа для горничных и уборщиц
# Жилеты для пищевого производства
# Упаковка для фаст-фуда
# Упаковка для суши, роллов и лапши
# Упаковка под запайку
# Управление и безопасность мобильных устройств
# Уровни лазерные
# USB устройства
# Усилители голоса
# Усилители Wi-Fi сигнала
# Установка и обслуживание сплит-систем
# Утюги
# Увлажнители воздуха
# Вафельницы профессиональные
# Вафли
# Вебкамеры
# Велосипеды
# Вентиляторы для корпуса
# Вентиляторы настольные
# Вентиляторы вытяжные
# Вентиляторы
# Верстаки слесарные, столы производственные
# Вешалки напольные и настенные
# Вешалки гардеробные
# Весы кухонные
# Весы напольные
# Весы торговые
# Видеокамеры для умного дома
# Видеокамеры Flash HD
# Видеокарты
# Видеорегистраторы для систем наблюдения
# Видеорегистраторы персональные
# Видеоскопы
# Видеотехника
# Винные шкафы
# Винты
# Витрины холодильные, морозильные
# Зефир, пастила, мармелад
# Внутренние SSD накопители
# Внутренний жесткий диск
# Вода бутилированная
# Вода, напитки, соки
# Водонагреватели накопительные
# Водонагреватели проточные
# Восковые карандаши,мелки
# Восточные сладости
# Вспомогательная медицинская мебель
# Встраиваемые духовые шкафы
# Встраиваемые микроволновые печи
# Встраиваемые посудомоечные машины
# Встраиваемые варочные панели
# Встраиваемые вытяжки
# Вытяжки для плит
# Web-контроль и контентная фильтрация
# Wi-Fi Роутеры (Маршрутизаторы)
# Яйца
# Ящики для ключей, боксы
# Ящики почтовые
# Заклепочники и заклепки
# Заклепки
# Замена, ремонт и диагностика оборудования
# Замки для компьютерной техники
# Замки и аксессуары
# Замки и фурнитура
# Замки почтовые
# Запайщики для пакетов и контейнеров
# Запасные части (ЗИП) для принтеров
# Запчасти и аксессуары для печатающей техники
# Заправка и восстановление картриджей
# Зарядные устройства сетевые
# Зарядные устройства в автомобиль
# Защита головы
# Защита информации и резервное копирование
# Защита слуха
# Зеркала для ванной
# Зеркальные фотоаппараты
# Зеркальные шары
# Знаки безопасности по ГОСТУ
# Звонки настольные

# %% [markdown]
# Отображение по ключу распределение атрибутов в категории

# %%
CATEGORY = "Карандаши"
data_dict = category_attribute[CATEGORY]

# %%
# Сортировка по значениям (по убыванию)
sorted_items = sorted(data_dict.items(), key=lambda x: x[1], reverse=True)

# Разделение на списки ключей и значений
sorted_keys = [item[0] for item in sorted_items]
sorted_values = [item[1] for item in sorted_items]

# Создание DataFrame (необязательно, но удобно для plotly)
import pandas as pd
df = pd.DataFrame({'Атрибут': sorted_keys, 'Количество': sorted_values})

# Создание графика
fig = px.bar(
    df,
    x='Атрибут',
    y='Количество',
    title=f'График отсортированных значений для категории: {CATEGORY}',
    # labels={'Категория': 'Позиция', 'Значение': 'Количество'},
    color='Количество',  # Цветовая шкала
    text='Количество'    # Отображение значений над столбцами
)

# Настройка визуализации
fig.update_traces(texttemplate='%{text:.2s}', textposition='auto')
fig.update_layout(showlegend=False)

# Отображение графика
fig.show()
print(len(data_dict.keys()))
# Out:
# 20

# %%
# sorted_items = sorted(data_dict.items(), key=lambda x: x[1], reverse=True)

# Разделение на списки ключей и значений
keys = [item for item in category_attribute.keys()]
values = [len(item) for item in category_attribute.values()]

# Создание DataFrame (необязательно, но удобно для plotly)
import pandas as pd
df = pd.DataFrame({'Атрибут': keys, 'Количество': values})

# Создание графика
fig = px.bar(
    df,
    x='Атрибут',
    y='Количество',
    title=f'График',
    # labels={'Категория': 'Позиция', 'Значение': 'Количество'},
    color='Количество',  # Цветовая шкала
    text='Количество'    # Отображение значений над столбцами
)

# Настройка визуализации
fig.update_traces(texttemplate='%{text:.2s}', textposition='auto')
fig.update_layout(showlegend=False)

# Отображение графика
fig.show()

# %% [markdown]
# ## Сравнение пересечения категорий у товаров

# %%
category_dict = {}

# %%
for product in data:
    for category in product["category"]:

        if category not in category_dict:
            category_dict[category] = []

        category_dict[category].append(product)

# %%
CATEGORY = "Детям"

len(category_dict[CATEGORY])

for product in category_dict[CATEGORY]:
    print(product["title"], product["category"])
# Out:
# Часы настенные Troyka 77771712 (30.5x30.5x5 см) ['Часы', 'Часы и метеостанции', 'Интерьерные часы', 'Детям']
# Конструктор NDPlay Робототехника Энергия ветра 6 в 1(на солнечной батарее) ['Конструкторы робототехнические', 'Детям']
# Тесто для лепки Genio Kids Тираннозавр 3 в 1 ['Наборы для творчества и лепки', 'Детям']
# Настольная игра Имаджинариум ['Детям']
# Настольная игра Имаджинариум Детство ['Детям']
# Набор для творчества Lori Химические опыты Цветная лава красная ['Наборы для творчества и лепки', 'Детям']
# Головоломка Эврика Круглые пятнашки №3 (98718) ['Головоломки', 'Детям']
# Настольная игра Десятое королевство Морской бой ['Детям']
# Набор досок для выжигания Тридевятое царство Динозавры (5 штук) ['Наборы для творчества и лепки', 'Детям']
# Часы для шахмат механические ['Детям']
# Подставка-органайзер для канцелярских принадлежностей Deli 6 отделений 25.9x10.3x15 см (E9110) ['Подставки для ручек', 'Канцелярия', 'Канцелярские наборы и подставки', 'Детям', 'Настольные подставки и наборы']
# Конструктор ND Play Боевой дроид от 6 лет (280344) ['Конструкторы робототехнические', 'Детям']
# Подставка-органайзер для канцелярских принадлежностей Attache Ежик 11 отделений 8.5x5x13.5 см ['Подставки для ручек', 'Канцелярия', 'Канцелярские наборы и подставки', 'Детям', 'Настольные подставки и наборы']
# Конструктор ND Play Электронный Подъемный кран от 6 лет (NDP-038) ['Конструкторы робототехнические', 'Детям']
# Доска-мольберт магнитно-меловая/маркерная 56x67см Attache Kids лак (с полочкой) ['Меловые магнитные доски', 'Детям']
# Набор досок для выжигания Тридевятое царство Подарок своими руками маме, бабушке, сестре, подруге (5 штук) ['Наборы для творчества и лепки', 'Детям']
# Настольная игра Десятое королевство Поймай монстрика ['Детям']
# Подставка-стакан для канцелярских принадлежностей Deli E9145 10.4x8.7x8.7 см ['Подставки для ручек', 'Канцелярия', 'Канцелярские наборы и подставки', 'Детям', 'Настольные подставки и наборы']
# Тетрадь общая Kroyter Art А5 60 листов в клетку на скрепке ['Тетради общие', 'Школьные блокноты и тетради', 'Тетради и блокноты', 'Детям']
# Конструктор ND Play Робот-художник 3 в 1 от 6 лет (273877) ['Конструкторы робототехнические', 'Детям']
# Наушники JBL JR310 детские красные/синие (JBLJR310RED) ['Наушники', 'Гарнитуры', 'Детям']
# Конструктор ND Play 3D Электронный Трицератопс от 6 лет (277391) ['Конструкторы робототехнические', 'Детям']
# Настольная игра Десятое королевство Веселый, грустный, злой ['Детям']
# Доска-мольберт грифельная 56x67см Attache Kids ['Меловые магнитные доски', 'Детям']
# Конструктор ND Play 3D Электронный Волшебная птица от 6 лет (277389) ['Конструкторы робототехнические', 'Детям']
# Головоломка Камень, ножницы, бумага (4637186) ['Головоломки', 'Детям']
# Рюкзак Комус Класс Триколор 15 л комбинированный ['Стиль', 'Рюкзаки и ранцы', 'Детям']
# Игровой набор Кетчбол Start Up S744 (2 ракетки, мяч, чехол) ['Прочее оснащение для спортзалов', 'Детям']
# Набор AltairToys Меч в ножнах ['Игры развивающие', 'Детям']
# Конструктор ND Play Роботизированная рука от 6 лет (NDR-044) ['Конструкторы робототехнические', 'Детям']
# Конструктор NDPlay Робототехника Роботостроение 14 в 1 (на солнечной батарее) ['Конструкторы робототехнические', 'Детям']
# Кулер (раздатчик) для воды Vatten kids Duck White (без нагрева и охлаждения) ['Кулеры, пурифайеры, помпы и аксессуары', 'Детям']
# Настольная игра Геодом Большой подарок для мальчика ['Детям']
# Рюкзак Bruno Visconti Rap.The world черный (12-002-140/01) ['Рюкзаки и ранцы', 'Детям']
# Набор Levenhuk LabZZ MTВ3 (микроскоп, телескоп,бинокль) ['Оптическая техника и аксессуары', 'Детям']
# Набор химических опытов Lori Бомбочка-шипучка Сладкая сказка Оп-065 ['Наборы для творчества и лепки', 'Детям']
# Стол детский М-110-1 шахматный регулируемый (разноцветный) ['Столы детские', 'Детям']
# Стул детский Кузя Львенок (с рисунком/красный, рост 1-3) ['Стулья детские', 'Детям']
# Стул детский Кузя (с рисунком/желтый, рост 1-3) ['Стулья детские', 'Детям']
# Пуф Рассвет Божья коровка Б-732 (винилcкожа) ['Для дома', 'Детям', 'Мягкая детская мебель']
# Пуф Рассвет Медвежонок Б-734 (винилcкожа) ['Мягкая детская мебель', 'Детям']
# Пуф Рассвет Утенок Б-730 (винилcкожа) ['Мягкая детская мебель', 'Детям']
# Пуф Рассвет Пчелка Б-731 (винилcкожа) ['Мягкая детская мебель', 'Детям']
# Пуф Рассвет Котенок Б-737 (винилcкожа) ['Мягкая детская мебель', 'Детям']
# Стул детский Кузя Зебра (с рисунком/белый, рост 1-3) ['Стулья детские', 'Детям']
# Стул детский Кузя Ежик (с рисунком/красный, рост 1-3) ['Стулья детские', 'Детям']
# Стул детский Кузя Буратино (с рисунком/желтый, рост 1-3) ['Стулья детские', 'Детям']
# Доска-мольберт магнитно-маркерная/грифельная 33.5x43 см Attache Kids лак ['Меловые магнитные доски', 'Детям']
# Конструктор Makeblock Базовая робототехника mBot Ranger Robot Kit от 8 лет (90092) ['Детям']

# %%
with open("categories.txt", "w", encoding="utf-8") as file:
    file.write("\n".join([category for category in sorted(category_dict.keys())]))

# %%
import json

def dict_to_json(d):
    rounded = {k: round(v, 2) if isinstance(v, (int, float)) else v for k, v in d.items()}
    return json.dumps(rounded, ensure_ascii=False, indent=4)

d = {'TP': 997,
 'FP': 74,
 'FN': 347,
 'Precision': 0.930905695611578,
 'Recall': 0.7418154761904762,
 'F1-score': 0.825672877846791}

print(dict_to_json(d))
# Out:
# {
#     "TP": 997,
#     "FP": 74,
#     "FN": 347,
#     "Precision": 0.93,
#     "Recall": 0.74,
#     "F1-score": 0.83
# }
