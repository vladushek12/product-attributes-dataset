# %%
from langchain_google_vertexai import ChatVertexAI

from langchain.prompts import (
    ChatPromptTemplate,
    SystemMessagePromptTemplate,
    ChatPromptTemplate,
    HumanMessagePromptTemplate
)

from pydantic import BaseModel, Field
from langchain.output_parsers import PydanticOutputParser
from langchain.output_parsers.json import SimpleJsonOutputParser

import os
import json
import re

from typing import Set, List

# %% [markdown]
# ## Загрузка датасета

# %%
PATH = "..\\src\\data\\komus\\dataset.json"

with open(PATH, "r", encoding="UTF-8") as file:
    data = json.load(file)

print(len(data))
# Out:
# 83755

# %%
with open("metrics.json", "r", encoding="utf-8") as file:
    data_metrics = json.load(file)

len(data_metrics)
# Out:
# 100

# %% [markdown]
# ## Объявление LLM

# %% [markdown]
# ### Т-Pro

# %%
from langchain_openai import ChatOpenAI

T_PRO_CREDS = "../secrets/t-pro.json"

with open(T_PRO_CREDS) as file:
    model_params = json.load(file)

llm = ChatOpenAI(**model_params)

# %% [markdown]
# ## Utils

# %%
def create_model_prompts(system_prompt: str,
                         user_prompt: str) -> ChatPromptTemplate:
    system_prompt = SystemMessagePromptTemplate.from_template(system_prompt)
    user_prompt = HumanMessagePromptTemplate.from_template(user_prompt)
    chat_prompt = ChatPromptTemplate.from_messages(
        [system_prompt,
         user_prompt]
    )
    return chat_prompt

def get_batch(data_metrics,
              examples_str,
              parser = SimpleJsonOutputParser()):
    return [
        {
            "examples": examples_str if examples_str else "Без примеров",
            "format_instructions": parser.get_format_instructions(),
            "problem_title": product["title"],
            "problem_decomposition": json.dumps(product["decomposition"], ensure_ascii=False)        
        } for product in data_metrics
    ]

def get_similarity_results(prompt, 
                           llm,
                           batch, 
                           parser = SimpleJsonOutputParser()):
    similarity_chain = prompt | llm | parser

    return similarity_chain.batch(batch)

def evaluate_predictions(y_true, y_pred):
    y_true = set(y_true)
    y_pred = set(y_pred)
    
    TP = len(y_true & y_pred)  # Совпадающие элементы (правильные предсказания)
    FP = len(y_pred - y_true)  # Ошибочные предсказания (лишние элементы)
    FN = len(y_true - y_pred)  # Пропущенные правильные элементы
    TN = None  # Не учитывается в таких задачах
    
    return TP, FP, FN

def evaluate_batch_predictions(batch_results: List[int]):
    total_TP, total_FP, total_FN = 0, 0, 0
    
    for TP, FP, FN in batch_results:
        total_TP += TP
        total_FP += FP
        total_FN += FN
    
    precision = total_TP / (total_TP + total_FP) if (total_TP + total_FP) > 0 else 0
    recall = total_TP / (total_TP + total_FN) if (total_TP + total_FN) > 0 else 0
    f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
    
    return {
        "TP": total_TP,
        "FP": total_FP,
        "FN": total_FN,
        "Precision": precision,
        "Recall": recall,
        "F1-score": f1
    }

def test_prompt(prompt, 
                llm, 
                data_metrics,
                examples_str="",
                get_ans = lambda x: x,
                parser=SimpleJsonOutputParser()):
    batch = get_batch(data_metrics, examples_str, parser)

    results = get_similarity_results(prompt,
                                     llm,
                                     batch,
                                     parser)
    
    y_true_arr = [product["correct_ans"] for product in data_metrics]
    y_pred_arr = [get_ans(res) for res in results]

    scores = [evaluate_predictions(y_true, y_pred) for y_true, y_pred in zip(y_true_arr, y_pred_arr)]

    return [
        {
            "product": product,
            "res": res,
            "score": score
        } for product, res, score in zip(data_metrics, results, scores)
    ]

# %% [markdown]
# # Гипотеза один
# Просим те ключи, значения которых описывают позицию

# %% [markdown]
# ### Вариант без CoT

# %%
SYSTEM_PROMPT = """
Напиши ключи из характеристики, которая присутствует в названии товара.

Примеры
{examples}

Следуй этим правилам:
- Характеристика должна быть полностью или частично представлена в товарной позиции.
- Включай в ответ ключи, для которых удалось найти соответвутствующи фрагмент в названии товара.

Выдай ответ в виде массива JSON.

**Не пиши больше ничего кроме ответа.**
""".strip()

USER_PROMPT = """
Название товара: {problem_title}
Характеристики: {problem_decomposition}
""".strip()

prompt = create_model_prompts(SYSTEM_PROMPT, USER_PROMPT)

# %%
examples = [
    {
        "title": "Карандаш чернографитный пластиковый НВ с ластиком Выбор есть заточенный шестигранный черный корпус (12 штук в наборе)",
        "attributes": { "Торговая марка": "Выбор есть", "Твердость грифеля": "HB", "Наличие ластика": "Да", "Заточенный": "Да", "Профиль карандаша": "шестигранный", "Материал корпуса": "пластик", "Цвет корпуса": "черный", "Длина корпуса карандаша": "185 мм", "Единица продажи": "упаковка", "Кол-во штук в единице продажи": "12", "Кол-во единиц продаж в промежуточной упаковке (кратность)": "6", "Количество единиц продаж в транспортной упаковке": "90", "Страна происхождения": "Россия" },
        "result": ["Торговая марка", "Наличие ластика", "Твердость грифеля", "Заточенный", "Профиль карандаша", "Цвет корпуса", "Кол-во штук в единице продажи"]
    },
    {
        "title": "Сабо женские EVART Ола ЭВА серые (размер 39)",
        "attributes": {"Торговая марка": "Evart", "Коллекция": "Сабо ЭВА Ола", "Тип": "сабо", "Модель": "Ола", "Материал верха обуви": "ЭВА", "Пол": "женский", "Размер": "39", "Цвет": "серый", "Материал подошвы": "ЭВА", "Материал стельки": "отсутствует", "Стелька": "отсутствует", "Подносок": "нет", "Защитные свойства": "от общих загрязнений", "Метод крепления подошвы": "литьевой", "С ремешком": "да", "Перфорация": "Да", "Тип подошвы": "плоская", "Сфера применения": "медицина , пищевое производство и общественное питание , хорека", "Стандарты": "ТР ТС 017/2011", "Честный знак": "Да", "Количество единиц продаж в транспортной упаковке": "1", "Страна происхождения": "Россия", "Вес": "0.227 кг"},
        "result": ["Торговая марка", "Тип", "Модель", "Материал верха обуви", "Пол", "Размер", "Цвет", "Материал подошвы"]
    },
    {
        "title": "Бумага для цветной лазерной печати Xerox Colotech + ( A4, 250 г/кв.м, 250 листов, 003R94671)",
        "attributes": {"Торговая марка": "Xerox Colotech +", "Покрытие": "без покрытия (каландрированная бумага)", "Плотность листа бумаги": "250 г/кв.м", "Белизна CIE": "161 ± 3%", "Формат листов": "А4", "Сертификация по экологическим стандартам": "Нет", "Яркость бумаги": "110", "Количество единиц продаж в транспортной упаковке": "144", "Кол-во единиц продаж в промежуточной упаковке (кратность)": "4", "Страна происхождения": "Австрия", "Количество листов в упаковке": "250 шт"},
        "result": ["Торговая марка", "Плотность листа бумаги", "Формат листов", "Количество листов в упаковке"]
    }
]

examples_str = "\n".join([f"""
{i+1})Название товара: {product["title"]}
Характеристики: {json.dumps(product['attributes'], ensure_ascii=False)}
Ответ: {json.dumps(product['result'], ensure_ascii=False)} 
""".strip() for i, product in enumerate(examples)])
print(examples_str)
# Out:
# 1)Название товара: Карандаш чернографитный пластиковый НВ с ластиком Выбор есть заточенный шестигранный черный корпус (12 штук в наборе)
# Характеристики: {"Торговая марка": "Выбор есть", "Твердость грифеля": "HB", "Наличие ластика": "Да", "Заточенный": "Да", "Профиль карандаша": "шестигранный", "Материал корпуса": "пластик", "Цвет корпуса": "черный", "Длина корпуса карандаша": "185 мм", "Единица продажи": "упаковка", "Кол-во штук в единице продажи": "12", "Кол-во единиц продаж в промежуточной упаковке (кратность)": "6", "Количество единиц продаж в транспортной упаковке": "90", "Страна происхождения": "Россия"}
# Ответ: ["Торговая марка", "Наличие ластика", "Твердость грифеля", "Заточенный", "Профиль карандаша", "Цвет корпуса", "Кол-во штук в единице продажи"]
# 2)Название товара: Сабо женские EVART Ола ЭВА серые (размер 39)
# Характеристики: {"Торговая марка": "Evart", "Коллекция": "Сабо ЭВА Ола", "Тип": "сабо", "Модель": "Ола", "Материал верха обуви": "ЭВА", "Пол": "женский", "Размер": "39", "Цвет": "серый", "Материал подошвы": "ЭВА", "Материал стельки": "отсутствует", "Стелька": "отсутствует", "Подносок": "нет", "Защитные свойства": "от общих загрязнений", "Метод крепления подошвы": "литьевой", "С ремешком": "да", "Перфорация": "Да", "Тип подошвы": "плоская", "Сфера применения": "медицина , пищевое производство и общественное питание , хорека", "Стандарты": "ТР ТС 017/2011", "Честный знак": "Да", "Количество единиц продаж в транспортной упаковке": "1", "Страна происхождения": "Россия", "Вес": "0.227 кг"}
# Ответ: ["Торговая марка", "Тип", "Модель", "Материал верха обуви", "Пол", "Размер", "Цвет", "Материал подошвы"]
# 3)Название товара: Бумага для цветной лазерной печати Xerox Colotech + ( A4, 250 г/кв.м, 250 листов, 003R94671)
# Характеристики: {"Торговая марка": "Xerox Colotech +", "Покрытие": "без покрытия (каландрированная бумага)", "Плотность листа бумаги": "250 г/кв.м", "Белизна CIE": "161 ± 3%", "Формат листов": "А4", "Сертификация по экологическим стандартам": "Нет", "Яркость бумаги": "110", "Количество единиц продаж в транспортной упаковке": "144", "Кол-во единиц продаж в промежуточной упаковке (кратность)": "4", "Страна происхождения": "Австрия", "Количество листов в упаковке": "250 шт"}
# Ответ: ["Торговая марка", "Плотность листа бумаги", "Формат листов", "Количество листов в упаковке"]

# %%
results = test_prompt(
    prompt,
    llm,
    data_metrics,
    examples_str,
    lambda x: x
)

# %%
evaluate_batch_predictions([product["score"] for product in results])
# Out:
# {'TP': 413,
#  'FP': 55,
#  'FN': 39,
#  'Precision': 0.8824786324786325,
#  'Recall': 0.9137168141592921,
#  'F1-score': 0.8978260869565218}

# %% [markdown]
# ### Проверка промпта без примеров

# %%
results = test_prompt(
    prompt,
    llm,
    data_metrics,
    "",
    lambda x: x
)

# %%
evaluate_batch_predictions([product["score"] for product in results])
# Out:
# {'TP': 369,
#  'FP': 159,
#  'FN': 83,
#  'Precision': 0.6988636363636364,
#  'Recall': 0.8163716814159292,
#  'F1-score': 0.7530612244897961}

# %% [markdown]
# ### Вариант на английском

# %%
SYSTEM_PROMPT = """
Write the keys from the characteristic that is present in the product name.

Examples:
{examples}


Pay attention to the strict implementation of these rules:
- The dictionary must consist only of dictionary keys, and the values ​​must be only fragments of the product item.
- Do not write those keys for which there is no match.
- Values ​​should not intersect between other values ​​in your answer.

Give the answer as a JSON array.

**Do not generate any text after the JSON output.**
""".strip()

USER_PROMPT = """
Give an answer for this:
Product title: {problem_title} 
Dictionary: {problem_decomposition}.
""".strip()

prompt = create_model_prompts(SYSTEM_PROMPT, USER_PROMPT)

# %%
examples = [
    {
        "title": "Карандаш чернографитный пластиковый НВ с ластиком Выбор есть заточенный шестигранный черный корпус (12 штук в наборе)",
        "attributes": { "Торговая марка": "Выбор есть", "Твердость грифеля": "HB", "Наличие ластика": "Да", "Заточенный": "Да", "Профиль карандаша": "шестигранный", "Материал корпуса": "пластик", "Цвет корпуса": "черный", "Длина корпуса карандаша": "185 мм", "Единица продажи": "упаковка", "Кол-во штук в единице продажи": "12", "Кол-во единиц продаж в промежуточной упаковке (кратность)": "6", "Количество единиц продаж в транспортной упаковке": "90", "Страна происхождения": "Россия" },
        "result": ["Торговая марка", "Наличие ластика", "Твердость грифеля", "Заточенный", "Профиль карандаша", "Цвет корпуса", "Кол-во штук в единице продажи"]
    },
    {
        "title": "Сабо женские EVART Ола ЭВА серые (размер 39)",
        "attributes": {"Торговая марка": "Evart", "Коллекция": "Сабо ЭВА Ола", "Тип": "сабо", "Модель": "Ола", "Материал верха обуви": "ЭВА", "Пол": "женский", "Размер": "39", "Цвет": "серый", "Материал подошвы": "ЭВА", "Материал стельки": "отсутствует", "Стелька": "отсутствует", "Подносок": "нет", "Защитные свойства": "от общих загрязнений", "Метод крепления подошвы": "литьевой", "С ремешком": "да", "Перфорация": "Да", "Тип подошвы": "плоская", "Сфера применения": "медицина , пищевое производство и общественное питание , хорека", "Стандарты": "ТР ТС 017/2011", "Честный знак": "Да", "Количество единиц продаж в транспортной упаковке": "1", "Страна происхождения": "Россия", "Вес": "0.227 кг"},
        "result": ["Торговая марка", "Тип", "Модель", "Материал верха обуви", "Пол", "Размер", "Цвет", "Материал подошвы"]
    },
    {
        "title": "Бумага для цветной лазерной печати Xerox Colotech + ( A4, 250 г/кв.м, 250 листов, 003R94671)",
        "attributes": {"Торговая марка": "Xerox Colotech +", "Покрытие": "без покрытия (каландрированная бумага)", "Плотность листа бумаги": "250 г/кв.м", "Белизна CIE": "161 ± 3%", "Формат листов": "А4", "Сертификация по экологическим стандартам": "Нет", "Яркость бумаги": "110", "Количество единиц продаж в транспортной упаковке": "144", "Кол-во единиц продаж в промежуточной упаковке (кратность)": "4", "Страна происхождения": "Австрия", "Количество листов в упаковке": "250 шт"},
        "result": ["Торговая марка", "Плотность листа бумаги", "Формат листов", "Количество листов в упаковке"]
    }
]

examples_str = "\n".join([f"""
{i+1})Product title: {product["title"]}
Dictionary: {json.dumps(product['attributes'], ensure_ascii=False)}
Result: {json.dumps(product['result'], ensure_ascii=False)} 
""".strip() for i, product in enumerate(examples)])
print(examples_str)
# Out:
# 1)Product title: Карандаш чернографитный пластиковый НВ с ластиком Выбор есть заточенный шестигранный черный корпус (12 штук в наборе)
# Dictionary: {"Торговая марка": "Выбор есть", "Твердость грифеля": "HB", "Наличие ластика": "Да", "Заточенный": "Да", "Профиль карандаша": "шестигранный", "Материал корпуса": "пластик", "Цвет корпуса": "черный", "Длина корпуса карандаша": "185 мм", "Единица продажи": "упаковка", "Кол-во штук в единице продажи": "12", "Кол-во единиц продаж в промежуточной упаковке (кратность)": "6", "Количество единиц продаж в транспортной упаковке": "90", "Страна происхождения": "Россия"}
# Result: ["Торговая марка", "Наличие ластика", "Твердость грифеля", "Заточенный", "Профиль карандаша", "Цвет корпуса", "Кол-во штук в единице продажи"]
# 2)Product title: Сабо женские EVART Ола ЭВА серые (размер 39)
# Dictionary: {"Торговая марка": "Evart", "Коллекция": "Сабо ЭВА Ола", "Тип": "сабо", "Модель": "Ола", "Материал верха обуви": "ЭВА", "Пол": "женский", "Размер": "39", "Цвет": "серый", "Материал подошвы": "ЭВА", "Материал стельки": "отсутствует", "Стелька": "отсутствует", "Подносок": "нет", "Защитные свойства": "от общих загрязнений", "Метод крепления подошвы": "литьевой", "С ремешком": "да", "Перфорация": "Да", "Тип подошвы": "плоская", "Сфера применения": "медицина , пищевое производство и общественное питание , хорека", "Стандарты": "ТР ТС 017/2011", "Честный знак": "Да", "Количество единиц продаж в транспортной упаковке": "1", "Страна происхождения": "Россия", "Вес": "0.227 кг"}
# Result: ["Торговая марка", "Тип", "Модель", "Материал верха обуви", "Пол", "Размер", "Цвет", "Материал подошвы"]
# 3)Product title: Бумага для цветной лазерной печати Xerox Colotech + ( A4, 250 г/кв.м, 250 листов, 003R94671)
# Dictionary: {"Торговая марка": "Xerox Colotech +", "Покрытие": "без покрытия (каландрированная бумага)", "Плотность листа бумаги": "250 г/кв.м", "Белизна CIE": "161 ± 3%", "Формат листов": "А4", "Сертификация по экологическим стандартам": "Нет", "Яркость бумаги": "110", "Количество единиц продаж в транспортной упаковке": "144", "Кол-во единиц продаж в промежуточной упаковке (кратность)": "4", "Страна происхождения": "Австрия", "Количество листов в упаковке": "250 шт"}
# Result: ["Торговая марка", "Плотность листа бумаги", "Формат листов", "Количество листов в упаковке"]

# %%
results = test_prompt(
    prompt,
    llm,
    data_metrics,
    examples_str,
    lambda x: x
)

# %%
evaluate_batch_predictions([product["score"] for product in results])
# Out:
# {'TP': 423,
#  'FP': 91,
#  'FN': 29,
#  'Precision': 0.8229571984435797,
#  'Recall': 0.9358407079646017,
#  'F1-score': 0.8757763975155279}

# %% [markdown]
# ### Вариант с CoT

# %%
class SimilarityListResponse(BaseModel):
    reasoning: str = Field(..., description="Ход мыслей перед генерацией списка")
    attributes: List[str] = Field(..., description="Список ключей характеристик")

parser = PydanticOutputParser(pydantic_object=SimilarityListResponse)

SYSTEM_PROMPT = """
Напиши ключи из характеристики, которая присутствует в названии товара.

Примеры
{examples}

Следуй этим правилам:
- Характеристика должна быть полностью или частично представлена в товарной позиции.
- Характеристика должна иметь фрагмент строки для того чтобы понять, что она представлена в товарной позиции.
- Все ключи в ходе мыслей оборачивай в одинарные кавычки - 'текст'

**{format_instructions}**
""".strip()

USER_PROMPT = """
Название товара: {problem_title}
Характеристики: {problem_decomposition}
""".strip()

prompt = create_model_prompts(SYSTEM_PROMPT, USER_PROMPT)

# %%
examples = [
    {
        "title": "Карандаш чернографитный пластиковый НВ с ластиком Выбор есть заточенный шестигранный черный корпус (12 штук в наборе)",
        "attributes": { "Торговая марка": "Выбор есть", "Твердость грифеля": "HB", "Наличие ластика": "Да", "Заточенный": "Да", "Профиль карандаша": "шестигранный", "Материал корпуса": "пластик", "Цвет корпуса": "черный", "Длина корпуса карандаша": "185 мм", "Единица продажи": "упаковка", "Кол-во штук в единице продажи": "12", "Кол-во единиц продаж в промежуточной упаковке (кратность)": "6", "Количество единиц продаж в транспортной упаковке": "90", "Страна происхождения": "Россия" },
        "result": ["Торговая марка", "Наличие ластика", "Твердость грифеля", "Заточенный", "Профиль карандаша", "Цвет корпуса", "Кол-во штук в единице продажи"]
    },
    {
        "title": "Сабо женские EVART Ола ЭВА серые (размер 39)",
        "attributes": {"Торговая марка": "Evart", "Коллекция": "Сабо ЭВА Ола", "Тип": "сабо", "Модель": "Ола", "Материал верха обуви": "ЭВА", "Пол": "женский", "Размер": "39", "Цвет": "серый", "Материал подошвы": "ЭВА", "Материал стельки": "отсутствует", "Стелька": "отсутствует", "Подносок": "нет", "Защитные свойства": "от общих загрязнений", "Метод крепления подошвы": "литьевой", "С ремешком": "да", "Перфорация": "Да", "Тип подошвы": "плоская", "Сфера применения": "медицина , пищевое производство и общественное питание , хорека", "Стандарты": "ТР ТС 017/2011", "Честный знак": "Да", "Количество единиц продаж в транспортной упаковке": "1", "Страна происхождения": "Россия", "Вес": "0.227 кг"},
        "result": ["Торговая марка", "Тип", "Модель", "Материал верха обуви", "Пол", "Размер", "Цвет", "Материал подошвы"]
    },
    {
        "title": "Бумага для цветной лазерной печати Xerox Colotech + ( A4, 250 г/кв.м, 250 листов, 003R94671)",
        "attributes": {"Торговая марка": "Xerox Colotech +", "Покрытие": "без покрытия (каландрированная бумага)", "Плотность листа бумаги": "250 г/кв.м", "Белизна CIE": "161 ± 3%", "Формат листов": "А4", "Сертификация по экологическим стандартам": "Нет", "Яркость бумаги": "110", "Количество единиц продаж в транспортной упаковке": "144", "Кол-во единиц продаж в промежуточной упаковке (кратность)": "4", "Страна происхождения": "Австрия", "Количество листов в упаковке": "250 шт"},
        "result": ["Торговая марка", "Плотность листа бумаги", "Формат листов", "Количество листов в упаковке"]
    }
]

examples_str = "\n".join([f"""
{i+1})Название товара: {product["title"]}
Характеристики: {json.dumps(product['attributes'], ensure_ascii=False)}
Ответ: {json.dumps(product['result'], ensure_ascii=False)} 
""".strip() for i, product in enumerate(examples)])
print(examples_str)
# Out:
# 1)Название товара: Карандаш чернографитный пластиковый НВ с ластиком Выбор есть заточенный шестигранный черный корпус (12 штук в наборе)
# Характеристики: {"Торговая марка": "Выбор есть", "Твердость грифеля": "HB", "Наличие ластика": "Да", "Заточенный": "Да", "Профиль карандаша": "шестигранный", "Материал корпуса": "пластик", "Цвет корпуса": "черный", "Длина корпуса карандаша": "185 мм", "Единица продажи": "упаковка", "Кол-во штук в единице продажи": "12", "Кол-во единиц продаж в промежуточной упаковке (кратность)": "6", "Количество единиц продаж в транспортной упаковке": "90", "Страна происхождения": "Россия"}
# Ответ: ["Торговая марка", "Наличие ластика", "Твердость грифеля", "Заточенный", "Профиль карандаша", "Цвет корпуса", "Кол-во штук в единице продажи"]
# 2)Название товара: Сабо женские EVART Ола ЭВА серые (размер 39)
# Характеристики: {"Торговая марка": "Evart", "Коллекция": "Сабо ЭВА Ола", "Тип": "сабо", "Модель": "Ола", "Материал верха обуви": "ЭВА", "Пол": "женский", "Размер": "39", "Цвет": "серый", "Материал подошвы": "ЭВА", "Материал стельки": "отсутствует", "Стелька": "отсутствует", "Подносок": "нет", "Защитные свойства": "от общих загрязнений", "Метод крепления подошвы": "литьевой", "С ремешком": "да", "Перфорация": "Да", "Тип подошвы": "плоская", "Сфера применения": "медицина , пищевое производство и общественное питание , хорека", "Стандарты": "ТР ТС 017/2011", "Честный знак": "Да", "Количество единиц продаж в транспортной упаковке": "1", "Страна происхождения": "Россия", "Вес": "0.227 кг"}
# Ответ: ["Торговая марка", "Тип", "Модель", "Материал верха обуви", "Пол", "Размер", "Цвет", "Материал подошвы"]
# 3)Название товара: Бумага для цветной лазерной печати Xerox Colotech + ( A4, 250 г/кв.м, 250 листов, 003R94671)
# Характеристики: {"Торговая марка": "Xerox Colotech +", "Покрытие": "без покрытия (каландрированная бумага)", "Плотность листа бумаги": "250 г/кв.м", "Белизна CIE": "161 ± 3%", "Формат листов": "А4", "Сертификация по экологическим стандартам": "Нет", "Яркость бумаги": "110", "Количество единиц продаж в транспортной упаковке": "144", "Кол-во единиц продаж в промежуточной упаковке (кратность)": "4", "Страна происхождения": "Австрия", "Количество листов в упаковке": "250 шт"}
# Ответ: ["Торговая марка", "Плотность листа бумаги", "Формат листов", "Количество листов в упаковке"]

# %%
results = test_prompt(
    prompt,
    llm,
    data_metrics,
    examples_str,
    lambda x: x.attributes,
    parser
)

# %%
evaluate_batch_predictions([product["score"] for product in results])
# Out:
# {'TP': 421,
#  'FP': 73,
#  'FN': 31,
#  'Precision': 0.8522267206477733,
#  'Recall': 0.9314159292035398,
#  'F1-score': 0.8900634249471459}

# %%
for product in results:
    print(product["product"]["title"])
    print(product["res"].reasoning)
    print(f'LLM ans:\t{sorted(product["res"].attributes)}')
    print(f'correct ans:\t{sorted(product["product"]["correct_ans"])}')
    print(product["score"])
    print("---------------")
# Out:
# Тетрадь школьная Комус Класс (№1 School) голубая А5 24 листа в клетку (10 штук в упаковке)
# В названии товара мы выделяем ключевые элементы: 'Тетрадь школьная', 'Комус Класс', 'голубая', 'А5', '24 листа в клетку', '10 штук в упаковке'. Соответствующие характеристики следующие: 'Торговая марка' (из 'Комус Класс'), 'Формат листов' (из 'А5'), 'Количество листов' (из '24 листа'), 'Вид линовки' (из 'в клетку'), 'Цвет обложки' (из 'голубая') и 'Количество штук в упаковке' (из '10 штук в упаковке').
# LLM ans:	['Вид линовки', 'Количество листов', 'Количество штук в упаковке', 'Торговая марка', 'Формат листов', 'Цвет обложки']
# correct ans:	['Вид линовки', 'Количество листов', 'Количество штук в упаковке', 'Торговая марка', 'Формат листов', 'Цвет обложки']
# (6, 0, 0)
# ---------------
# Смазка CET CET2828
# В названии товара явно указаны 'CET' (в верхнем регистре), что соответствует 'Торговой марке', и 'смазка', что соответствует 'Типу'. Другие характеристики, такие как 'малые закупки', 'страна происхождения' и 'количество единиц продаж', не указаны в названии товара.
# LLM ans:	['Тип', 'Торговая марка']
# correct ans:	['Тип', 'Торговая марка']
# (2, 0, 0)
# ---------------
# Кулер для процессора DeepCool ICE EDGE Mini RET
# Анализируя название 'Кулер для процессора DeepCool ICE EDGE Mini RET', мы видим следующие ключевые слова: 'DeepCool' (соответствует 'Торговая марка'), 'ICE EDGE Mini RET' (может указывать на модель, но нет явного упоминания модели в характеристиках). Из характеристик нужно выбрать те, которые относятся к основным параметрам охлаждения и размерам, основанным на информации в названии. Это включает 'Материал основания' (алюминий/медь), 'Количество вентиляторов в комплекте', 'Количество тепловых трубок', которые могут ассоциироваться с 'Mini'. Также 'Форм-фактор' и 'размеры' вроде 'Высота', 'Ширина', 'Глубина' могут быть важны для 'Mini', но в характеристике нет фрагмента строки для 'форм-фактора'.
# LLM ans:	['Количество вентиляторов в комплекте', 'Количество тепловых трубок', 'Материал основания', 'Торговая марка']
# correct ans:	['Торговая марка']
# (1, 3, 0)
# ---------------
# Термистор CET CET531003
# Ключевые характеристики в названии товара 'Термистор CET CET531003' включают 'Термистор', который указывает на 'Тип'; 'CET', который частично совпадает с 'Торговая марка'; и модель 'CET531003'. Однако модель 'CET531003' не является явной характеристикой в нашем списке. Таким образом, мы выбираем 'Торговая марка' и 'Тип'.
# LLM ans:	['Тип', 'Торговая марка']
# correct ans:	['Тип', 'Торговая марка']
# (2, 0, 0)
# ---------------
# Тетрадь школьная Альт Военный паттерн А5 24 листа в линейку (10 штук в упаковке)
# Характеристики, указанные в названии: 'Торговая марка' (Альт), 'Формат листов' (А5), 'Количество листов' (24 листа), 'Вид линовки' (в линейку) и 'Цвет обложки' (Военный паттерн подразумевает 'разноцветный'). Также явно указано 'Количество штук в упаковке' (10 штук вместо 16 из характеристик).
# LLM ans:	['Вид линовки', 'Количество листов', 'Количество штук в упаковке', 'Торговая марка', 'Формат листов', 'Цвет обложки']
# correct ans:	['Вид линовки', 'Количество листов', 'Количество штук в упаковке', 'Торговая марка', 'Формат листов']
# (5, 1, 0)
# ---------------
# Тумба приставная Metal System Style Б.ТП-1 (акация лорка, 412x720x750 мм)
# В названии присутствуют следующие ключевые элементы: 'тумба', 'Metal System Style', 'акация лорка', и размеры '412x720x750 мм'. На основании этого, можно выделить 'Вид', 'Торговая марка', 'Цвет покрытия' и характеристики 'Ширина', 'Глубина' и 'Высота'. Величина 'Торговая марка' не представлена напрямую, но из 'Metal System Style' можно вывести 'Коллекция'. Размеры совпадают с характеристиками 'Ширина', 'Глубина' и 'Высота', соответственно.
# LLM ans:	['Вид', 'Высота', 'Глубина', 'Коллекция', 'Цвет покрытия', 'Ширина']
# correct ans:	['Вид', 'Высота', 'Глубина', 'Коллекция', 'Цвет покрытия', 'Ширина']
# (6, 0, 0)
# ---------------
# Папка-планшет с зажимом Attache A4 пластиковая черная
# В названии товара упоминаются следующие ключевые характеристики: 'Папка-планшет', 'с зажимом', 'Attache', 'A4', 'пластиковая', 'черная'. Из предоставленных характеристик можно определить соответствующие ключи: 'Торговая марка' (Attache), 'Формат' (A4), 'Материал папки' (пластик), 'С зажимом' (да), 'Цвет' (черный).
# LLM ans:	['Материал папки', 'С зажимом', 'Торговая марка', 'Формат', 'Цвет']
# correct ans:	['Материал папки', 'С зажимом', 'Торговая марка', 'Формат', 'Цвет']
# (5, 0, 0)
# ---------------
# Папка-конверт на молнии Attache А5 бесцветная 230 мкм (2 штуки в упаковке)
# Из названия 'Папка-конверт на молнии Attache А5 бесцветная 230 мкм (2 штуки в упаковке)' выбираем ключи характеристики:
# - 'Торговая марка' представлена как 'Attache'.
# - 'Формат' указан как 'А5'.
# - 'Тип застежки' соответствует фрагменту 'на молнии'.
# - 'Цвет' упомянут как 'бесцветная'.
# - 'Толщина' указана как '230 мкм'.
# - 'Количество штук в упаковке' упомянуто как '(2 штуки в упаковке)'.
# LLM ans:	['Количество штук в упаковке', 'Тип застежки', 'Толщина', 'Торговая марка', 'Формат', 'Цвет']
# correct ans:	['Количество штук в упаковке', 'Тип застежки', 'Толщина', 'Торговая марка', 'Формат', 'Цвет']
# (6, 0, 0)
# ---------------
# Уровень пузырьковый Matrix 3 глазка 1200 мм усиленный магнитный (34712)
# В названии товара присутствуют такие фрагменты: 'Matrix', '3 глазка', '1200 мм', 'усиленный магнитный'. Эти фрагменты соответствуют характеристикам 'Торговая марка', 'Количество глазков', 'Длина', и 'Наличие магнита'. Другие ключи не полностью или частично не представлены в названии товара.
# LLM ans:	['Длина', 'Количество глазков', 'Наличие магнита', 'Торговая марка']
# correct ans:	['Длина', 'Количество глазков', 'Наличие магнита', 'Тип', 'Торговая марка']
# (4, 0, 1)
# ---------------
# Пуф Куба складной с ящиком для хранения черный (искусственная кожа, 370x370x400 мм)
# В названии товара присутствуют следующие ключевые фразы: 'Пуф Куба', 'складной', 'с ящиком для хранения', 'черный', 'искусственная кожа', '370x370x400 мм'. 'Пуф Куба' подразумевает 'Торговая марка' или 'Модель', однако в характеристиках отсутствует соответствующая запись. 'Складной' соответствует ключу 'Особенности'. 'Черный' относится к 'Цвет обивки'. 'Искусственная кожа' соответствует 'Материал обивки'. Размеры '370x370x400 мм' соответствуют характеристикам 'Ширина', 'Глубина' и 'Высота'.
# LLM ans:	['Высота', 'Глубина', 'Материал обивки', 'Особенности', 'Цвет обивки', 'Ширина']
# correct ans:	['Высота', 'Глубина', 'Материал обивки', 'Особенности', 'Форма', 'Цвет обивки', 'Ширина']
# (6, 0, 1)
# ---------------
# Набор гелевых ручек Attache Pastel 8 цветов (толщина линии 0.5 мм)
# В названии товара присутствуют 'Attache', 'Pastel', '8 цветов', 'толщина линии 0.5 мм'. Эти фрагменты соответствуют характеристикам 'Торговая марка', 'Цвет чернил', 'Цвет корпуса' и 'Толщина линии письма'. Валидируем наличие других характеристик: 'Pastel' может быть интерпретирован как часть модели или коллекции, но здесь 'Цвет чернил' и 'Цвет корпуса' наиболее подходят, так как имеют значение '8 цветов'. '0.5 мм' напрямую соответствует 'Толщина линии письма'.
# LLM ans:	['Кол-во штук в единице продажи', 'Толщина линии письма', 'Торговая марка', 'Цвет корпуса', 'Цвет чернил']
# correct ans:	['Единица продажи', 'Кол-во штук в единице продажи', 'Толщина линии письма', 'Торговая марка', 'Цвет чернил']
# (4, 1, 1)
# ---------------
# Подставка-органайзер для канцелярских мелочей Attache Maxi Desk 10 отделений черная вращающаяся
# В названии товара указаны ключевые характеристики: торговая марка 'Attache', тип 'подставка-органайзер', количество отделений '10', цвет 'черная' и наличие функции 'вращающаяся'. Каждый из этих элементов можно сопоставить с соответствующими ключами из предоставленных характеристик.
# LLM ans:	['Вращающийся', 'Количество отделений', 'Тип товара', 'Торговая марка', 'Цвет']
# correct ans:	['Вращающийся', 'Количество отделений', 'Тип товара', 'Торговая марка', 'Цвет']
# (5, 0, 0)
# ---------------
# Вал CET CET7805
# В названии товара «Вал CET CET7805» присутствуют соответствующие фрагменты: 'вал', что соответствует характеристике 'Тип', и 'CET', что соответствует характеристике 'Торговая марка'. Остальные характеристики не имеют явных фрагментов строки, которые бы указывали на их присутствие в названии товара.
# LLM ans:	['Тип', 'Торговая марка']
# correct ans:	['Тип', 'Торговая марка']
# (2, 0, 0)
# ---------------
# Ламинатор Bulros FGK330iD формат А3 (LP-D-FGK-33iD-___-PsH-A3)
# В названии товара присутствуют ключевые слова, такие как 'Bulros', 'формат А3', и модель 'FGK330iD'. Эти слова соответствуют характеристикам 'Торговая марка', 'Максимальный формат ламинирования' и 'Модель', которую можно вывести из 'Торговая марка' и соответствующего кода модели в скобках. Кроме того, в названии виден формат 'А3', что соответствует характеристике 'Максимальный формат ламинирования'. Поскольку 'модель' явно не перечислена в характеристиках, мы включаем только ключи, которые отображены в названии товара.
# LLM ans:	['Максимальный формат ламинирования', 'Торговая марка']
# correct ans:	['Максимальный формат ламинирования', 'Торговая марка']
# (2, 0, 0)
# ---------------
# Ручка гелевая неавтоматическая Pensan Glitter Gel золотистая (толщина линии 0.75 мм)
# В названии товара присутствуют следующие ключевые характеристики: 'гелевая', 'неавтоматическая', 'Pensan', 'Glitter Gel', 'золотистая', 'толщина линии 0.75 мм'. 'Торговая марка' зафиксирована как 'Pensan', 'Автоматическая' характеризуется как 'Нет', 'Цвет чернил' соответствует 'золотистый', 'Толщина линии письма' - '0.75 мм'. Остальные характеристики, такие как 'Тип механизма', 'Форма наконечника', и другие, не представлены в полном объеме в названии.
# LLM ans:	['Автоматическая', 'Толщина линии письма', 'Торговая марка', 'Цвет чернил']
# correct ans:	['Автоматическая', 'Толщина линии письма', 'Торговая марка', 'Цвет чернил']
# (4, 0, 0)
# ---------------
# Ламинатор Office Kit L2325 формат A4
# В название товара 'Ламинатор Office Kit L2325 формат A4' включены заголовки торговой марки 'Office Kit', формата 'A4'. Также в модели 'L2325' можно отразить 'Вид' ламинатора и конкретные характеристики, такие как 'Максимальный формат ламинирования' и 'Мощность', учитывая, что эти параметры критично важны для продукта ламинатора.
# LLM ans:	['Вид', 'Максимальный формат ламинирования', 'Мощность', 'Торговая марка']
# correct ans:	['Максимальный формат ламинирования', 'Торговая марка']
# (2, 2, 0)
# ---------------
# Уровень пузырьковый Вихрь 3 глазка 1000 мм усиленный фрезерованный (73/11/4/12)
# В названии товара присутствуют следующие ключевые слова: 'уровень пузырьковый', 'Вихрь', '3 глазка', '1000 мм', 'усиленный', 'фрезерованный'. На основании этих слов выбираем ключи из характеристик: 'Торговая марка' (соответствует 'Вихрь'), 'Тип' (соответствует 'уровень'), 'Количество глазков' (соответствует '3 глазка'), 'Длина' (соответствует '1000 мм'), 'Материал' (соответствует 'алюминий' из характеристик, поскольку 'фрезерованный' указывает, что это обработанный материал). Дополнительные слова, такие как 'усиленный', не имеют соответствующих характеристик.
# LLM ans:	['Длина', 'Количество глазков', 'Материал', 'Тип', 'Торговая марка']
# correct ans:	['Длина', 'Количество глазков', 'Тип', 'Торговая марка']
# (4, 1, 0)
# ---------------
# Элемент рабочей станции Onix-П O.MP-1.NRS-2.8 (дуб аризона/антрацит, 1180х800х750 мм)
# В названии товара упоминаются 'Onix-П', 'дуб аризона/антрацит' и размеры '1180х800х750 мм'. Эти элементы соответствуют характеристикам 'Коллекция', 'Цвет покрытия' и размерам ('Ширина', 'Глубина', 'Высота') соответственно, так как они содержатся в названии и характеризуют товар.
# LLM ans:	['Вид', 'Высота', 'Глубина', 'Коллекция', 'Цвет покрытия', 'Ширина']
# correct ans:	['Вид', 'Высота', 'Глубина', 'Коллекция', 'Цвет покрытия', 'Ширина']
# (6, 0, 0)
# ---------------
# Экран акриловый на струбцине (белый прозрачный, 600х55х400 мм)
# В названии товара указаны следующие ключевые элементы: 'акриловый', 'на струбцине', 'белый прозрачный', и размеры '600х55х400 мм'. Ищем соответствия в характеристиках: 'Материал' (акрил), 'Способ крепления' (струбцина), 'Цвет корпуса' ('белый прозрачный' подходит под ключ 'Цвет'), 'Ширина', 'Глубина', и 'Высота'. Ключ 'Толщина' не упомянут в названии товара, а 'Сборка мебели' и 'Малые закупки' не значимы для имени товара.
# LLM ans:	['Вид', 'Высота', 'Глубина', 'Материал', 'Способ крепления', 'Цвет корпуса', 'Ширина']
# correct ans:	['Вид', 'Высота', 'Глубина', 'Материал', 'Способ крепления', 'Цвет', 'Ширина']
# (6, 1, 1)
# ---------------
# Плащ влагозащитный Poseidon WPL ПВХ на молнии синий (размер 60-62, рост 182-188)
# Из названия товара 'Плащ влагозащитный Poseidon WPL ПВХ на молнии синий (размер 60-62, рост 182-188)' можно выделить следующие характеристики: торговая марка 'Poseidon', защитные свойства 'влагозащитный', материал 'ПВХ', наличие застежки 'молния', цвет 'синий', размер '60-62' и рост '182-188 см'. Также в характеристике упомянуты 'Плащ влагозащитный' и 'Poseidon-ПЛ', которые соответствуют модели и защищённые свойства.
# LLM ans:	['Застежка', 'Защитные свойства', 'Коллекция', 'Материал', 'Модель', 'Размер', 'Рост', 'Цвет']
# correct ans:	['Застежка', 'Защитные свойства', 'Коллекция', 'Материал', 'Модель', 'Размер', 'Рост', 'Цвет']
# (8, 0, 0)
# ---------------
# Папка-конверт на молнии Attache Selection Bloom А4 400 мкм (с ручками)
# Папка-конверт на молнии Attache Selection Bloom А4 400 мкм (с ручками) соответствует характеристикам 'Торговая марка', 'Формат', 'Тип застежки', 'Толщина' и 'Фактура', так как 'рифленая' фактура часто используется в папках с ручками.
# LLM ans:	['Тип застежки', 'Толщина', 'Торговая марка', 'Фактура', 'Формат']
# correct ans:	['Коллекция', 'Тип застежки', 'Толщина', 'Торговая марка', 'Формат']
# (4, 1, 1)
# ---------------
# Шкаф для одежды металлический Cobalt ШРМ11 (серый, 300х500х1860 мм)
# В названии указаны ключевые характеристики: «металлический», 'Cobalt', 'серый', и размеры «300х500х1860 мм». Соответственно, из характеристик выбираем те, которые отражены в названии товара: 'Торговая марка', 'Материал каркаса', 'Цвет', 'Ширина', 'Глубина', и 'Высота'.
# LLM ans:	['Высота', 'Глубина', 'Материал каркаса', 'Торговая марка', 'Цвет', 'Ширина']
# correct ans:	['Вид', 'Высота', 'Глубина', 'Материал каркаса', 'Торговая марка', 'Цвет', 'Ширина']
# (6, 0, 1)
# ---------------
# Ламинатор Гелеос ЛМ Радуга формат A4 фиолетовый
# В названии товара присутствуют следующие информацию: 'Ламинатор Гелеос', 'формат A4' и 'фиолетовый'. Таким образом, можно выделить соответствующие характеристики: 'Торговая марка', 'Максимальный формат ламинирования' и 'Материал корпуса' (далее используется 'Цвет корпуса', так как присутствует цветовое описание). 'Фиолетовый' указывает на цвет корпуса, причем в ключе характеристик 'Цвет корпуса' явно отсутствует, но можно использовать 'Материал корпуса', потому что в его описании можно вывести фрагмент строки относительно цвета в рамках общего описания товара.
# LLM ans:	['Максимальный формат ламинирования', 'Материал корпуса', 'Торговая марка']
# correct ans:	['Максимальный формат ламинирования', 'Торговая марка']
# (2, 1, 0)
# ---------------
# Плащ дождевик полиэтиленовый на липучках зеленый (размер 64-68)
# В названии товара 'Плащ дождевик полиэтиленовый на липучках зеленый (размер 64-68)' присутствуют следующие ключевые фразы: 'полиэтиленовый', 'на липучках', 'зеленый', 'размер 64-68'. На основании этих фраз можно определить, что в характеристике имеются 'Материал' (полиэтилен), 'Цвет' (зеленый), 'Застежка' (липучка) и 'Размер' (должен соответствовать указанным в названии размерам, хотя в характеристике указан 'универсальный', но мы включаем ключ на основе упоминания 'размер').
# LLM ans:	['Застежка', 'Материал', 'Размер', 'Цвет']
# correct ans:	['Застежка', 'Материал', 'Размер', 'Цвет']
# (4, 0, 0)
# ---------------
# Набор кастрюль Лысьвенские эмали Китайская Роза эмалированная сталь 3 штуки (1.5 л, 2 л, 3 л)
# В названии товара присутствуют следующие элементы: 'Лысьвенские эмали', 'набор кастрюль', 'эмалированная сталь', и указание на количество ('3 штуки') и объемы ('1.5 л, 2 л, 3 л'). Из этих элементов можем выделить соответствующие ключи: 'Торговая марка', 'Тип', 'Материал', 'Покрытие', 'Количество предметов в наборе' и 'Объем посуды'. Внимание следует уделить тому, что в характеристиках указано 'Количество предметов в наборе': '6', однако в названии указано '3 штуки', что скорее относится к количеству кастрюль, но не общему количеству предметов (кастрюли и крышки), следовательно, 'Количество предметов в наборе' не включаем. Включаем 'Объем посуды', так как размеры кастрюль полностью представлены в названии.
# LLM ans:	['Материал', 'Объем посуды', 'Покрытие', 'Тип', 'Торговая марка']
# correct ans:	['Материал', 'Объем посуды', 'Тип', 'Торговая марка']
# (4, 1, 0)
# ---------------
# Ламинатор Fellowes Saturn 3i формат А3 (FS-57360)
# Название товара 'Ламинатор Fellowes Saturn 3i формат А3 (FS-57360)' включает следующие явные указания в характеристиках: 'Fellowes' соответствует 'Торговой марке', 'формат А3' соответствует 'Максимальный формат ламинирования', а 'Saturn 3i' указывает на 'Модель', следовательно, 'Название модели' могло бы быть частью характеристики. Однако, модель явно не указана как отдельный ключ, поэтому ключ 'Модель' не включает. Также, 'FS-57360' может указывать на артикул, но это не отображается в характеристиках. Основные характеристики, которые можно извлечь из названия: 'Торговая марка', 'Максимальный формат ламинирования'
# LLM ans:	['Максимальный формат ламинирования', 'Торговая марка']
# correct ans:	['Максимальный формат ламинирования', 'Торговая марка']
# (2, 0, 0)
# ---------------
# Плащ влагозащитный Extra-Vision WPL ПВХ на молнии лимонный с СОП (размер 52-54, рост 170-176)
# В названии товара указаны следующие ключевые фрагменты: 'Extra-Vision', 'ПВХ', 'на молнии', 'лимонный', 'размер 52-54', 'рост 170-176'. Из этого можно выделить характеристики:
# 1. 'Торговая марка' (по фрагменту 'Extra-Vision').
# 2. 'Материал' (содержит 'ПВХ').
# 3. 'Застежка' (упомянут 'на молнии').
# 4. 'Цвет' (может быть выделен 'лимонный').
# 5. 'Размер' (упомянут '52-54').
# 6. 'Рост' (упомянут '170-176').
# 7. 'Защитные свойства' (название начинается с 'влагозащитный').
# 8. 'Наличие карманов' (по фрагменту 'с СОП', что расшифровывается как съемный одноразовый плащ - вероятно, речь идет о карманах в оригинальной версии).
# LLM ans:	['Застежка', 'Защитные свойства', 'Коллекция', 'Материал', 'Наличие карманов', 'Размер', 'Рост', 'Цвет']
# correct ans:	['Застежка', 'Защитные свойства', 'Коллекция', 'Материал', 'Модель', 'Размер', 'Рост', 'Цвет']
# (7, 1, 1)
# ---------------
# Кулер для процессора DeepCool CK-11509
# В названии товара содержится 'DeepCool', поэтому характеристика 'Торговая марка' должна быть включена. Номер модели не влияет на характеристики, но совместимые Socket были указаны в названии, что совпадает с характеристикой 'Совместимый Socket'. Размер вентилятора '92x92 мм' включает его числовое обозначение, что совпадает с 'CK-11509'. Также учитывая наличие числовых значений, такие как '92x92 мм' в названии, мы включаем характеристики, которые содержат эти значения, такие как 'Размер вентилятора'.
# LLM ans:	['Размер вентилятора', 'Совместимый Socket', 'Торговая марка']
# correct ans:	['Торговая марка']
# (1, 2, 0)
# ---------------
# Карандаши цветные Maped Color'Peps Star 24 карандаша 24 цвета трёхгранные
# Анализ названия товара: 'Карандаши цветные Maped Color'Peps Star 24 карандаша 24 цвета трёхгранные'. В нём упоминается 'Maped', что соответствует 'Торговая марка'. Также есть 'цветные' и '24 цвета', которые соответствуют 'Цвет грифеля' и 'Количество цветов'. Слово 'трёхгранные' соответствует 'Форма корпуса'. Название содержит '24 карандаша', что указывает на 'Кол-во штук в единице продажи'.
# LLM ans:	['Кол-во штук в единице продажи', 'Количество цветов', 'Торговая марка', 'Форма корпуса', 'Цвет грифеля']
# correct ans:	['Кол-во штук в единице продажи', 'Количество цветов', 'Торговая марка', 'Форма корпуса']
# (4, 1, 0)
# ---------------
# Акустическая система L Audio FP-15A
# В названии товара присутствует 'L Audio FP-15A', что подразумевает наличие информации о торговой марке, модели и типе устройства. Из характеристик можно выделить: 'Торговая марка' (L Audio), 'Тип акустической системы' (активная), 'Модель' (FP-15A по схеме из названия и описание 'FP-15A'), 'Тип' (акустическая система), 'Цвет' (черный если указан в названии), 'Количество единиц продаж в транспортной упаковке' (это факт, подразумеваемый из просто обозначения систему как продукт). 'Номинальная мощность' и 'Максимальная мощность' совпадают, и только одно значение может быть распознано по имени. Есть также 'Размер', но в названии этот параметр не указан.
# LLM ans:	['Количество единиц продаж в транспортной упаковке', 'Номинальная мощность', 'Тип', 'Тип акустической системы', 'Торговая марка', 'Цвет']
# correct ans:	['Тип', 'Торговая марка']
# (2, 4, 0)
# ---------------
# Акустическая система Behringer Eurolive B108D
# В названии товара упоминается 'Акустическая система Behringer Eurolive B108D'. 'Торговая марка' ('Behringer') и 'Тип' ('акустическая система') явно присутствуют. Также из 'Eurolive B108D' можно предположить, что это модификация и, возможно, идентифицирует 'Модель', но такая характеристика отсутствует в списке. В характеристиках дополнительно имеем 'Тип акустической системы' ('активная'), 'Материал корпуса' явно не упомянут в названии, однако 'Цвет' ('черный') и 'Мониторные колонки' ('Да') вследствие контекста могут быть связаны с особенностями данного продукта. 'Количество полос' ('2') также указывает на особенности системы, представленные в названиях аналогичных продуктов. 'Номинальная мощность' и 'Максимальная мощность' идентичны числовому значению, которое может указываться как основное для акустических систем, однако в названии это не отражено. Остальные характеристики, такие как 'Гарантийный срок' и размеры, не имеют явного соответствия в названии.
# LLM ans:	['Количество полос', 'Мониторные колонки', 'Тип', 'Тип акустической системы', 'Торговая марка', 'Цвет']
# correct ans:	['Тип', 'Торговая марка']
# (2, 4, 0)
# ---------------
# Экран акриловый на струбцине (белый прозрачный, 900х55х400 мм)
# В названии товара указаны следующие ключевые слова: 'экран акриловый', 'на струбцине', 'белый прозрачный', и размеры '900х55х400 мм'. 'Торговая марка' не указана, 'Вид' и 'Способ крепления' частично совпадают с названием. По ключевым фразам из названия можно определить 'Тип крепления', 'Материал', 'Цвет' (при том, что 'Цвет' отсутствует в характеристиках, но можно использовать 'Материал' с дополнительной информацией о цвете), и размеры 'Ширина', 'Глубина', 'Высота'.
# LLM ans:	['Вид', 'Высота', 'Глубина', 'Материал', 'Способ крепления', 'Ширина']
# correct ans:	['Вид', 'Высота', 'Глубина', 'Материал', 'Способ крепления', 'Цвет', 'Ширина']
# (6, 0, 1)
# ---------------
# Кулер для процессора Aerocool Verkho Plus
# В названии товара присутствует 'Aerocool Verkho Plus', что соответствует ключу 'Торговая марка' и частично 'Модель'. Из характеристик 'Торговая марка' и 'Совместимый Socket' относятся напрямую к названию продукта. 'Модель' явно не соответствует характеристикам, но понимаем из названия, что 'Verkho Plus' может быть значением. Для полноты характеристики в названии также встречается 'кулер для процессора', указывающий на тип продукта, однако это совпадает с ключами 'Тип'. Однако, в данном случае 'Тип' не нужен, так как определяется из наименования категории, а не отдельной характеристики.
# LLM ans:	['Совместимый Socket', 'Торговая марка']
# correct ans:	['Торговая марка']
# (1, 1, 0)
# ---------------
# Экран акриловый на струбцине (белый прозрачный, 1000х55х400 мм)
# Анализируем название товара ‘Экран акриловый на струбцине (белый прозрачный, 1000х55х400 мм)’. Из названия видны ключевые слова: 'акриловый', 'струбцина', 'белый прозрачный', и размеры '1000х55х400 мм'. Соотнося эти элементы с характеристиками: 'Материал' указывает на акрил, 'Способ крепления' - на струбцину, и размеры совпадают с 'Ширина', 'Глубина' и 'Высота'. Описание цвета - ‘белый прозрачный’ не соответствует прямой характеристике, но мы можем выделить ‘Материал’ как ключевую характеристику, так как это часть описания 'акриловый'.
# LLM ans:	['Высота', 'Глубина', 'Материал', 'Способ крепления', 'Ширина']
# correct ans:	['Вид', 'Высота', 'Глубина', 'Материал', 'Способ крепления', 'Ширина']
# (5, 0, 1)
# ---------------
# Экран акриловый на струбцине (белый глухой, 1200х55х400 мм)
# В названии товара присутствуют следующие ключевые характеристики: 'экран акриловый', 'на струбцине', 'белый глухой', '1200х55х400 мм'. Из заданных характеристик можно выделить: 'Тип крепления' (поскольку 'на струбцине' соответствует 'струбцина'), 'Материал' (поскольку 'акриловый' соответствует 'акрил'), 'Цвет' (из 'белый глухой' видно, что имеется в виду 'цвет', хотя в характеристике напрямую нет 'Цвет', однако из 'коллекции' можно сделать вывод о цветовом оформлении), 'Ширина', 'Глубина', и 'Высота' (размеры представлены в названии).
# LLM ans:	['Вид', 'Высота', 'Глубина', 'Материал', 'Способ крепления', 'Ширина']
# correct ans:	['Вид', 'Высота', 'Глубина', 'Материал', 'Способ крепления', 'Ширина']
# (6, 0, 0)
# ---------------
# Пластик ABS+ для 3D-принтера ESUN серый матовый 1.75 мм 1 кг
# В названии товара указаны следующие характеристики: 'ESUN' как торговая марка, 'пластик ABS+' как вид и материал, 'серый матовый' как цвет и особенность, '1.75 мм' как диаметр нити и '1 кг' как объем/вес. Все эти характеристики точно соответствуют ключам в предоставленном списке характеристик.
# LLM ans:	['Вид расходных материалов', 'Диаметр нити', 'Материал', 'Объем/вес', 'Особенность', 'Торговая марка', 'Цвет']
# correct ans:	['Вид расходных материалов', 'Диаметр нити', 'Материал', 'Объем/вес', 'Особенность', 'Торговая марка', 'Цвет']
# (7, 0, 0)
# ---------------
# Уровень пузырьковый Вихрь 3 глазка 1200 мм фрезерованный (73/11/4/5)
# В названии товара присутствует 'Уровень пузырьковый Вихрь 3 глазка 1200 мм фрезерованный'. Из характеристик можно выделить: 'Торговая марка' - 'Вихрь', 'Тип' - 'уровень', 'Количество глазков' - '3', 'Длина' - '1200 мм', 'Материал' - фраза 'фрезерованный' указывает на металлическую основу уровня, соответствующую 'алюминий'.
# LLM ans:	['Длина', 'Количество глазков', 'Материал', 'Тип', 'Торговая марка']
# correct ans:	['Длина', 'Количество глазков', 'Тип', 'Торговая марка']
# (4, 1, 0)
# ---------------
# Папка-планшет с зажимом и крышкой Attache A4 красная
# В названии товара присутствуют следующие ключевые слова: 'Папка-планшет', 'с зажимом', 'с крышкой', 'Attache', 'А4' и 'красная'. Соответствующие характеристики из описания: 'Тип папки планшета' (содержит 'с крышкой'), 'Материал покрытия' (имеет фрагмент 'крышка'), 'Формат' (соответствует 'А4'), 'С зажимом' (соответствует 'с зажимом'), 'Торговая марка' (содержит 'Attache'), и 'Цвет' (соответствует 'красная'). Например, 'Расположение зажима' ('сверху') или 'Толщина материала' не упоминаются в названии и, следовательно, не включаются в список.
# LLM ans:	['С зажимом', 'Тип папки планшета', 'Торговая марка', 'Формат', 'Цвет']
# correct ans:	['С зажимом', 'Тип папки планшета', 'Торговая марка', 'Формат', 'Цвет']
# (5, 0, 0)
# ---------------
# Экран акриловый на струбцине (белый прозрачный, 1400х55х400 мм)
# В названии товара присутствуют следующие ключевые фрагменты: 'акриловый экран', 'на струбцине', 'белый прозрачный', '1400х55х400 мм'. На основе этих фрагментов можно определить следующие атрибуты: 'Материал' (акрил), 'Способ крепления' (струбцина), 'Цвет' ('белый прозрачный' подразумевает характеристику цвета), 'Ширина', 'Глубина', и 'Высота' (все размеры присутствуют в названии). Ключ 'Цвет' мы можем вывести из 'белый прозрачный' как косвенно представляемый строка, учитывая, что присутствует описание внешнего вида товара.
# LLM ans:	['Высота', 'Глубина', 'Материал', 'Способ крепления', 'Цвет', 'Ширина']
# correct ans:	['Вид', 'Высота', 'Глубина', 'Материал', 'Способ крепления', 'Ширина']
# (5, 1, 1)
# ---------------
# Папка-планшет с зажимом и крышкой Attache A4 синяя
# В названии товара выделены следующие характеристики: 'Папка-планшет', 'с зажимом', 'закрытая крышка', 'Attache', 'А4', 'синяя'. Эти элементы соответствуют конкретным характеристикам 'Тип папки планшета (с крышкой)', 'С зажимом', 'Торговая марка', 'Формат', и 'Цвет'. Ключ 'Расположение зажима', хотя и присутствует в характеристиках, не указан явно в названии.
# LLM ans:	['С зажимом', 'Тип папки планшета', 'Торговая марка', 'Формат', 'Цвет']
# correct ans:	['С зажимом', 'Тип папки планшета', 'Торговая марка', 'Формат', 'Цвет']
# (5, 0, 0)
# ---------------
# Куртка-ветровка демисезонная Русский дождевик Лидер черная с капюшоном (размер 52-54, рост 182-188)
# В названии товара указаны ключевая информация о типе куртки (ветровка, демисезонная), торговой марке (Русский дождевик), модели (Лидер), цвете (черная), наличия капюшона (с капюшоном), а также размере и росте. На основе этого, выбираем характеристики, которые соответствуют указанным в названии компонентам.
# LLM ans:	['Модель', 'Размер', 'Рост', 'С капюшоном', 'Сезон', 'Тип куртки', 'Торговая марка', 'Цвет']
# correct ans:	['Модель', 'Размер', 'Рост', 'С капюшоном', 'Сезон', 'Торговая марка', 'Цвет']
# (7, 1, 0)
# ---------------
# Набор кастрюль Лысьвенские эмали Urban flower эмалированная сталь 3 штуки (1.45 л, 2.9 л, 4.3 л)
# Присутствующие ключевые слова в названии товара: 'Торговая марка' ('Лысьвенские эмали'), 'Тип' ('набор кастрюль'), 'Материал' ('эмалированная сталь'), 'Покрытие' ('эмалированное'), 'Количество предметов в наборе' ('3 штуки'), 'Объем посуды' (1.45 л, 2.9 л, 4.3 л). Только эти характеристики полностью совпадают или явно упоминаются в названии. Например, 'Количество предметов в наборе' указано как '3 штуки', хотя в характеристиках указано '6'. В данном случае берем именно '3', так как это согласно названию.
# LLM ans:	['Количество предметов в наборе', 'Материал', 'Объем посуды', 'Покрытие', 'Тип', 'Торговая марка']
# correct ans:	['Материал', 'Объем посуды', 'Состав комплекта', 'Тип', 'Торговая марка']
# (4, 2, 1)
# ---------------
# Пластик PLA+ для 3D-принтера ESUN синий матовый 1.75 мм 1 кг
# В названии товара указываются ключевые характеристики: торговая марка 'ESUN', тип материала 'PLA+', особенность 'матовый', цвет 'синий', диаметр нити '1.75 мм', и вес '1 кг'. Эти характеристики также присутствуют в списке характеристик.
# LLM ans:	['Диаметр нити', 'Материал', 'Объем/вес', 'Особенность', 'Торговая марка', 'Цвет']
# correct ans:	['Вид расходных материалов', 'Диаметр нити', 'Материал', 'Объем/вес', 'Особенность', 'Торговая марка', 'Цвет']
# (6, 0, 1)
# ---------------
# Набор кастрюль Appetite Париж 1KB191M эмалированная сталь 3 штуки (2 л, 3 л, 5.5 л)
# В названии товара указаны 'Набор кастрюль Appetite Париж', что указывает на 'Торговая марка' и 'Тип'. Также в названии присутствует 'эмалированная сталь', что соответствует 'Материал'. Объемы кастрюль (2 л, 3 л, 5.5 л) указаны явно, что соответствует ключу 'Объем посуды'. В названии также закреплено '3 штуки', что соответствует 'Количество предметов в наборе'. Однако, в предоставленной характеристике указано 'Количество предметов в наборе': '6', но в названии указан '3 кастрюли', поэтому более точным ключом будет 'Состав комплекта', где упоминается '3 кастрюли'.
# LLM ans:	['Материал', 'Объем посуды', 'Состав комплекта', 'Тип', 'Торговая марка']
# correct ans:	['Материал', 'Объем посуды', 'Покрытие', 'Состав комплекта', 'Тип', 'Торговая марка']
# (5, 0, 1)
# ---------------
# Подставка-органайзер для канцелярских принадлежностей Deli 6 отделений 25.9x10.3x15 см (E9110)
# В названии товара присутствуют следующие ключевые фрагменты: 'Deli' (торговая марка), '6 отделений' (предположительно соответствует 'Количество отделений'), '25.9x10.3x15 см' (соответствует 'Размер'), и 'подставка-органайзер' (соответствует 'Тип товара'). Значение '6 отделений' в названии отличается от значения '7 отделений' в характеристиках, но ключ 'Количество отделений' включен, так как в названии явно указано наличие отделений. Размеры в названии и характеристиках совпадают по сути, но в других единицах измерения, поэтому 'Размер' также соответствует.
# LLM ans:	['Количество отделений', 'Размер', 'Тип товара', 'Торговая марка']
# correct ans:	['Количество отделений', 'Размер', 'Тип товара', 'Торговая марка']
# (4, 0, 0)
# ---------------
# Доска магнитно-маркерная 100x180 см лаковое покрытие Attache Classic
# В названии товара 'Доска магнитно-маркерная 100x180 см лаковое покрытие Attache Classic' упоминаются следующие ключевые слова: 'магнитно-маркерная', '100x180 см', 'лаковое покрытие' и 'Attache Classic'. 'Магнитно-маркерная' соответствует 'Тип рабочей поверхности' и 'Серия досок', так как это важные элементы, описывающие доску. '100x180 см' соответствует 'Размер доски (ВхШ)'. 'Лаковое покрытие' указывает на 'Тип покрытия доски'. 'Attache' совпадает с 'Торговой маркой'.
# LLM ans:	['Размер доски (ВхШ)', 'Серия досок', 'Тип покрытия доски', 'Тип рабочей поверхности', 'Торговая марка']
# correct ans:	['Размер доски (ВхШ)', 'Серия досок', 'Тип покрытия доски', 'Тип рабочей поверхности', 'Торговая марка']
# (5, 0, 0)
# ---------------
# Тетрадь школьная зеленая Гознак А5 24 листа в клетку
# В названии товара указаны ключевые характеристики: 'школьная', 'зеленая', 'Гознак', 'А5', '24 листа', 'в клетку'. Сопоставляя их с характеристиками продукта, 'Торговая марка' может быть определена как 'Гознак'. 'Зеленая' указывает на 'Цвет обложки', 'А5' перекликается с 'Формат листов', '24 листа' с 'Количество листов', а 'в клетку' соответствует 'Вид линовки'.
# LLM ans:	['Вид линовки', 'Количество листов', 'Торговая марка', 'Формат листов', 'Цвет обложки']
# correct ans:	['Вид линовки', 'Количество листов', 'Торговая марка', 'Формат листов', 'Цвет обложки']
# (5, 0, 0)
# ---------------
# Модуль сушильный для обуви СОЮЗ-10 (без подставки)
# В названии товара представлены следующие ключи из характеристик: 'Торговая марка' (СОЮЗ-10, предполагается, что это часть названия бренда или серии), 'Цвет' (серый), 'Количество отделений' (указано 'без подставки', предполагая, что он имеет одно отделение без дополнительной подставки). Также 'Вешалка (перекладина) для одежды' может быть обоснована, так как в названии указана 'без подставки', что подразумевает отсутствие аксессуаров вроде подставки или вешалки.
# LLM ans:	['Вешалка (перекладина) для одежды', 'Количество отделений', 'Торговая марка', 'Цвет']
# correct ans:	[]
# (0, 4, 0)
# ---------------
# Доска магнитно-маркерная 75x100 см BoardSYS Twist лак (поворотная)
# В названии товара указаны следующие характеристики: 'BoardSYS' (торговая марка), '75x100 см' (размер доски), 'магнитно-маркерная' (тип рабочей поверхности), 'Twist' (серия досок), и 'лак' (тип покрытия доски). Также упоминается 'поворотная', что соответствует 'поворотный механизм' в характеристиках. Используется только полное или частичное соответствие характеристик в названии.
# LLM ans:	['Поворотный механизм', 'Размер доски (ВхШ)', 'Серия досок', 'Тип покрытия доски', 'Тип рабочей поверхности', 'Торговая марка']
# correct ans:	['Поворотный механизм', 'Размер доски (ВхШ)', 'Размер рабочей поверхности', 'Серия досок', 'Тип покрытия доски', 'Тип рабочей поверхности', 'Торговая марка']
# (6, 0, 1)
# ---------------
# Костюм непромокаемый Мойщик-2 полиэстер/хлопок желтый/черный с СОП (размер 52-54, рост 182-188)
# Название товара содержит следующие ключевые фрагменты: 'непромокаемый', 'Мойщик-2', 'полиэстер/хлопок', 'желтый/черный', и 'размер', 'рост'. Из характеристик видим, что 'Модель', 'Материал', 'Цвет', 'Размер' и 'Рост' соответствуют этим частям. В названии отсутствуют другие детали, такие как подкладка, утеплитель, наличие карманов и капюшона, но ключевая информация о непромокаемости и принадлежности к типу костюма присутствует.
# LLM ans:	['Материал', 'Модель', 'Размер', 'Рост', 'Цвет']
# correct ans:	['Защитные свойства', 'Материал', 'Материал подкладки', 'Модель', 'Размер', 'Рост', 'Тип', 'Цвет']
# (5, 0, 3)
# ---------------
# Карандаши цветные Deli Super Wings 12 карандашей 12 цветов шестигранные (EC126-12)
# В названии товара указаны следующие характеристики: 'Карандаши цветные' указывает на 'Тип стержня' (разноцветный), 'Deli' - 'Торговая марка', '12 карандашей' и '12 цветов' соответствуют 'Кол-во штук в единице продажи' и 'Количество цветов', 'шестигранные' соответствует 'Форма корпуса'. 'Цвет грифеля' представлен как 'разноцветный', который не указывается явно в названии, но подразумевается из 'цветные карандаши'.
# LLM ans:	['Кол-во штук в единице продажи', 'Количество цветов', 'Тип стержня', 'Торговая марка', 'Форма корпуса']
# correct ans:	['Кол-во штук в единице продажи', 'Количество цветов', 'Коллекция', 'Торговая марка', 'Форма корпуса']
# (4, 1, 1)
# ---------------
# Пластик EN-PLA+ для 3D-принтера Creality3D зеленое яблоко матовый 1.75 мм 1 кг
# В названии товара присутствуют следующие фрагменты, которые соответствуют ключам из характеристик: 'Пластик', 'EN-PLA+', 'Creality3D', 'зеленое яблоко', 'матовый', '1.75 мм', '1 кг'. Идентифицируем 'Торговая марка' как 'Creality3D', 'Вид расходных материалов' как 'пластик', 'Материал' как 'PLA+', 'Цвет' как 'зеленое яблоко', 'Особенность' как 'матовый', 'Диаметр нити' как '1.75 мм', и 'Объем/вес' как '1 кг'.
# LLM ans:	['Вид расходных материалов', 'Диаметр нити', 'Материал', 'Объем/вес', 'Особенность', 'Торговая марка', 'Цвет']
# correct ans:	['Вид расходных материалов', 'Диаметр нити', 'Материал', 'Объем/вес', 'Особенность', 'Торговая марка', 'Цвет']
# (7, 0, 0)
# ---------------
# Кулер для процессора ID-Cooling SE-903-SD V3
# В названии товара указан 'ID-Cooling SE-903-SD V3', что явно относится к 'Торговая марка'. Из названия видны 'SE-903', что соответствует 'Количество тепловых трубок', '903' указывает на 3 тепловых трубки. Также в названии указывается размер вентилятора, '903' соответственно 92x92 мм ('Размер вентилятора'). Все остальные характеристики не содержат явные совпадения в названии, кроме версии V3, которая уже включена в 'Торговая марка'.
# LLM ans:	['Количество тепловых трубок', 'Размер вентилятора', 'Совместимый Socket', 'Торговая марка']
# correct ans:	['Торговая марка']
# (1, 3, 0)
# ---------------
# Печь HP (5958)
# В названии товара присутствует 'HP', что совпадает с 'Cet' в характеристике как потенциальной торговой маркой из-за ошибки или опечатки. Однако более вероятно, что 'HP' является торговой маркой. 'Тип': печь, присутствует в самом названии. 'Количество единиц продаж в транспортной упаковке': не может быть выделено из названия товара, так как это числовая характеристика. Таким образом, ключи из названия товара: 'Торговая марка' и 'Тип'.
# LLM ans:	['Тип', 'Торговая марка']
# correct ans:	['Тип']
# (1, 1, 0)
# ---------------
# Фотополимер для 3D-принтера HARZ Labs Industrial Rigid черный 0.915 л
# В названии товара упоминаются следующие характеристики: 'HARZ Labs' (торговая марка), 'фотополимер' (вид расходных материалов), 'черный' (цвет), и '0.915 л' (объем). Эти характеристики можно найти в соответствующих ключах в списке характеристик.
# LLM ans:	['Вид расходных материалов', 'Объем', 'Торговая марка', 'Цвет']
# correct ans:	['Вид расходных материалов', 'Объем', 'Торговая марка', 'Цвет']
# (4, 0, 0)
# ---------------
# Папка-планшет с зажимом Attache Economy A4 пластиковая синяя
# В названии товара присутствуют следующие ключевые фрагменты: 'Папка-планшет', 'с зажимом', 'Attache Economy', 'A4', 'пластиковая', 'синяя'. Эти фрагменты позволяют выделить следующие характеристики: 'Торговая марка', 'Тип папки планшета' (можно уточнить на основе 'без крышки'), 'Формат', 'Материал папки', 'Цвет', 'С зажимом'. Также формат 'A4' в ходе рассуждений соответствует 'Расположение зажима' и 'Количество зажимов', хотя формально это не указано в названии, так как 'с зажимом' подразумевает наличие одного зажима сверху.
# LLM ans:	['Количество зажимов', 'Материал папки', 'Расположение зажима', 'С зажимом', 'Торговая марка', 'Формат', 'Цвет']
# correct ans:	['Материал папки', 'Тип папки планшета', 'Торговая марка', 'Формат', 'Цвет']
# (4, 3, 1)
# ---------------
# Ламинатор Bulros PDA4-230CN формат А4 (LP-D-PDA-23CN-___-PsH-A4)
# В названии товара 'Ламинатор Bulros PDA4-230CN формат А4 (LP-D-PDA-23CN-___-PsH-A4)' присутствуют следующие ключевые фрагменты: 'Bulros' (соответствует 'Торговая марка'), 'формат А4' (соответствует 'Максимальный формат ламинирования'), и 'LP-D-PDA-23CN' (модельного обозначения; '23CN' указывает на 230 ватт и 250 мкм, но это не точные соответствия характеристик). Кроме того, 'PDA4-230CN' совпадает с 'Вид', 'Максимальная толщина пленки', и 'Мощность' по цифровым значениям в названии.
# LLM ans:	['Максимальная толщина пленки', 'Максимальный формат ламинирования', 'Мощность', 'Торговая марка']
# correct ans:	['Максимальный формат ламинирования', 'Торговая марка']
# (2, 2, 0)
# ---------------
# Ручка гелевая неавтоматическая Bruno Visconti SimpleWrite Zefir черная корпус soft touch (толщина линии 0.4 мм)
# В названии товара присутствуют следующие ключевые фразы: 'гелевая', 'неавтоматическая', 'Bruno Visconti', 'черная', 'корпус soft touch', и 'толщина линии 0.4 мм'. Из перечисленных характеристик, 'Торговая марка' совпадает с 'Bruno Visconti'. 'Автоматическая' соответствует 'неавтоматическая'. 'Цвет чернил' совпадает с 'черная'. 'Покрытие soft touch' упоминается в названии. 'Толщина линии письма' совпадает с 'толщина линии 0.4 мм'. 'Материал корпуса' частично совпадает с 'корпус soft touch', поскольку присутствует 'прорезиненный пластик' с покрытием soft touch.
# LLM ans:	['Автоматическая', 'Материал корпуса', 'Покрытие soft touch', 'Толщина линии письма', 'Торговая марка', 'Цвет чернил']
# correct ans:	['Автоматическая', 'Покрытие soft touch', 'Толщина линии письма', 'Торговая марка', 'Цвет корпуса', 'Цвет чернил']
# (5, 1, 1)
# ---------------
# Папка-конверт на кнопке Attache Акварель А4 180 мкм (5 штук в упаковке)
# В названии товара присутствуют следующие фрагменты: 'Папка-конверт на кнопке', 'Attache', 'Акварель', 'А4', '180 мкм', '5 штук в упаковке'. На основе этих фрагментов следует выбрать характеристики, присутствующие в описании: 'Торговая марка' (Attache), 'Тип застежки' (кнопка), 'Формат' (А4), 'Толщина' (180 мкм), и 'Количество штук в упаковке' (5). Ключ 'Коллекция' частично соответствует 'Акварель', но не будет включён, так как требуются точные совпадения или явные фрагменты.
# LLM ans:	['Количество штук в упаковке', 'Тип застежки', 'Толщина', 'Торговая марка', 'Формат']
# correct ans:	['Количество штук в упаковке', 'Коллекция', 'Тип застежки', 'Толщина', 'Торговая марка', 'Формат']
# (5, 0, 1)
# ---------------
# Рабочая станция Metal System Style БП.РАС-СП-2.4 (вяз благородный/антрацит, 1600x1475x750 мм)
# В наименовании товара указаны следующие ключевые элементы: 'Мetal System Style', 'вяз благородный/антрацит', '1600x1475x750 мм'. Исходя из этих данных, можно определить следующие соответствующие характеристики: 'Торговая марка' (из 'Metal System Style'), 'Цвет покрытия' (из 'вяз благородный/антрацит') и размеры 'Ширина', 'Глубина' и 'Высота' (из '1600x1475x750 мм'). Также в названии указано 'рабочая станция', соответствующее характеристике 'Вид'.
# LLM ans:	['Вид', 'Высота', 'Глубина', 'Коллекция', 'Цвет покрытия', 'Ширина']
# correct ans:	['Вид', 'Высота', 'Глубина', 'Коллекция', 'Цвет покрытия', 'Ширина']
# (6, 0, 0)
# ---------------
# Набор канцелярский Attache Selection S-357 пластиковый 10 предметов черный
# В названии товара присутствуют следующие ключевые фрагменты: 'Attache Selection', 'пластиковый', '10 предметов', и 'черный'. Соответствующие характеристики — 'Торговая марка', 'Материал', 'Цвет' и 'Количество предметов в наборе'. Характеристика 'Прозрачный' не присутствует в названии, а также остаются характеристики, которые не подтверждены напрямую названием, такие как 'Размер' и 'Количество штук в упаковке'. Однако 'Количество штук в упаковке' актуально для общего количества в транспортировке, а не для набора, поэтому не включается в итоговый список.
# LLM ans:	['Количество предметов в наборе', 'Материал', 'Торговая марка', 'Цвет']
# correct ans:	['Количество предметов в наборе', 'Материал', 'Торговая марка', 'Цвет']
# (4, 0, 0)
# ---------------
# Набор посуды Panairo The Brusnika литой алюминий 3 предмета
# В названии товара присутствуют следующие ключевые фрагменты: 'Panairo' соответствует 'Торговая марка', 'набор посуды' соответствует 'Тип', 'литой алюминий' соответствует 'Материал', '3 предмета' соответствует 'Количество предметов в наборе'. Эти фрагменты полностью или частично совпадают с характеристиками, и именно они используются для создания логического списка ключей.
# LLM ans:	['Количество предметов в наборе', 'Материал', 'Тип', 'Торговая марка']
# correct ans:	['Количество предметов в наборе', 'Материал', 'Тип', 'Торговая марка']
# (4, 0, 0)
# ---------------
# Папка-конверт на кнопке Attache Selection Digital A4 180 мкм (6 штук в упаковке)
# В названии товара упомянуты следующие элементы: 'Папка-конверт', 'на кнопке', 'Attache Selection Digital', 'A4', '180 мкм', и '6 штук в упаковке'. Таким образом, из характеристик можно выделить следующие ключи: 'Торговая марка' (Attache), 'Коллекция' (включает часть Digital), 'Тип застежки' ('на кнопке'), 'Формат' ('A4'), 'Толщина' ('180 мкм') и 'Количество штук в упаковке' ('6 штук в упаковке'). Ключ 'Коллекция' включает информацию, представленную в названии, частично, как 'Digital'.
# LLM ans:	['Количество штук в упаковке', 'Тип застежки', 'Толщина', 'Торговая марка', 'Формат']
# correct ans:	['Количество штук в упаковке', 'Коллекция', 'Тип застежки', 'Толщина', 'Торговая марка', 'Формат']
# (5, 0, 1)
# ---------------
# Папка-конверт на кнопке Attache Selection Digital A5 180 мкм (6 штук в упаковке)
# В названии присутствуют фрагменты 'Attache Selection Digital', 'A5', '180 мкм' и '6 штук в упаковке'. 'Attache' подходит под 'Торговая марка'. 'Selection Digital' можно интерпретировать как поддержку коллекции, но она не входит в ключи характеристик. 'A5' совпадает с 'Формат'. '180 мкм' совпадает с 'Толщина'. '6 штук в упаковке' совпадает с 'Количество штук в упаковке'. 'Папка-конверт на кнопке' соответствует 'Тип застежки'.
# LLM ans:	['Количество штук в упаковке', 'Тип застежки', 'Толщина', 'Торговая марка', 'Формат']
# correct ans:	['Количество штук в упаковке', 'Коллекция', 'Тип застежки', 'Толщина', 'Торговая марка', 'Формат']
# (5, 0, 1)
# ---------------
# Пуф Lego ВМ-20 бежевый (искусственная кожа, 815x630x420 мм)
# В названии присутствуют название бренда Lego, цвет — 'бежевый', материал — 'искусственная кожа', а также размеры — '815x630x420 мм', которые соответствуют характеристикам 'Торговая марка', 'Цвет обивки', 'Материал обивки', 'Ширина', 'Глубина' и 'Высота'.
# LLM ans:	['Высота', 'Глубина', 'Материал обивки', 'Торговая марка', 'Цвет обивки', 'Ширина']
# correct ans:	['Высота', 'Глубина', 'Материал обивки', 'Цвет обивки', 'Ширина']
# (5, 1, 0)
# ---------------
# Тетрадь школьная Комус Класс Play А5 18 листов в клетку (матовая ламинация)
# В названии товара указано следующее: 'Тетрадь школьная Комус Класс Play А5 18 листов в клетку (матовая ламинация)'. Поэтому анализируем ключи в характеристиках: 'Торговая марка', 'Формат листов', 'Количество листов', 'Вид линовки', 'Отделка обложки'. В каждом случае явно присутствуют соответствующие элементы: 'Komus Class' как часть торговой марки 'Комус Класс', 'А5' соответствует формату листов, '18 листов' соответствует количеству листов, 'в клетку' соответствует виду линовки, 'матовая ламинация' соответствует отделке обложки.
# LLM ans:	['Вид линовки', 'Количество листов', 'Отделка обложки', 'Торговая марка', 'Формат листов']
# correct ans:	['Вид линовки', 'Количество листов', 'Отделка обложки', 'Торговая марка', 'Формат листов']
# (5, 0, 0)
# ---------------
# Рабочая станция Metal System Style БП.РАС-СА-2.2 (белый/серый, 1400x1835х750 мм)
# В названии товара указано: 'Рабочая станция Metal System Style', что соответствует 'Вид' и 'Коллекция', однако полные названия не совпадают, только 'Metal System Style' частично соответствует 'Коллекция'. Также в названии указаны цвета 'белый/серый', которые соответствуют характеристике 'Цвет покрытия'. Кроме того, в названии приведены размеры станции '1400x1835х750 мм', что соответствует характеристикам 'Ширина', 'Глубина' и 'Высота'. Остальные характеристики не упоминаются в названии.
# LLM ans:	['Вид', 'Высота', 'Глубина', 'Цвет покрытия', 'Ширина']
# correct ans:	['Вид', 'Высота', 'Глубина', 'Коллекция', 'Цвет покрытия', 'Ширина']
# (5, 0, 1)
# ---------------
# ...
# LLM ans:	['Тип', 'Торговая марка']
# correct ans:	['Тип']
# (1, 1, 0)
# ---------------
# Набор посуды Panairo CA-NAB-4 алюминий/нержавеющая сталь/дерево 4 предмета
# В названии присутствуют следующие ключевые фрагменты: 'Panairo', 'алюминий/нержавеющая сталь/дерево', и '4 предмета'. Из характеристик, соответствующие названию ключи: 'Торговая марка', 'Материал', и 'Количество предметов в наборе'.
# LLM ans:	['Количество предметов в наборе', 'Материал', 'Торговая марка']
# correct ans:	['Количество предметов в наборе', 'Материал', 'Тип', 'Торговая марка']
# (3, 0, 1)
# ---------------
# Доска магнитно-маркерная/меловая 120x150 см BoardSYS Twist (поворотная с выдвижными планками)
# В названии товара присутствуют ключевые фразы 'Доска магнитно-маркерная/меловая', '120x150 см', 'BoardSYS Twist', 'поворотная с выдвижными планками'. Из них можно выделить следующие характеристики: 'Торговая марка', 'Тип рабочей поверхности', 'Размер доски (ВхШ)', 'Поворотный механизм', 'Серия досок', и 'Наличие выдвижной перекладины'. Ключ 'размер' и 'тип покрытия' также указан в названии через верхне-нижний регистр и слэш, соответственно. В характеристике 'Цвет доски' белый/зеленый цвет может подтверждать разнофункциональность доски, но так как цвет напрямую в названии не упоминается, он не включается в список.
# LLM ans:	['Наличие выдвижной перекладины', 'Поворотный механизм', 'Размер доски (ВхШ)', 'Серия досок', 'Тип рабочей поверхности', 'Торговая марка']
# correct ans:	['Наличие выдвижной перекладины', 'Поворотный механизм', 'Размер доски (ВхШ)', 'Размер рабочей поверхности', 'Серия досок', 'Тип рабочей поверхности', 'Торговая марка']
# (6, 0, 1)
# ---------------
# Акустическая система Roxton MS-20TW
# 'Торговая марка' находится в начале названия товара 'Roxton'. 'Тип акустической системы' ('пассивная') отсутствует напрямую в названии, но ключ слово 'акустическая система' присутствует. 'Номинальная мощность' и 'Максимальная мощность' обе имеют значение '20 Вт', что частично соответствует 'MS-20TW'. 'Тип' признается на основании прямого указания в части названия 'акустическая система'. 'Цвет' или иные явные цветовые обозначения не находятся в названии. 'Размер' и физические измерения также не представлены. 'Количество полос' (2) может быть релевантным 'MS-20TW', если '20TW' интерпретируется как «2 полосы», но это неявное соответствие. Таким образом ключи 'Roxton', 'акустическая система', и фрагмент '20TW' помогли выделить 'Тип акустической системы' и 'Номинальная мощность'.
# LLM ans:	['Номинальная мощность', 'Тип', 'Тип акустической системы', 'Торговая марка']
# correct ans:	['Тип', 'Торговая марка']
# (2, 2, 0)
# ---------------
# Тетрадь школьная красная №1 School Интенсив А5 12 листов в линейку (10 штук в упаковке)
# В названии товара указаны следующие элементы, которые могут соответствовать характеристикам: 'Тетрадь школьная', 'красная', '№1 School', 'А5', '12 листов в линейку', и '10 штук в упаковке'. На основе этих данных: '№1 School' соответствует 'Торговая марка', 'красная' соответствует 'Цвет обложки', 'А5' соответствует 'Формат листов'. '12 листов в линейку' соответствует 'Количество листов' и 'Вид линовки'. '10 штук в упаковке' соответствует 'Количество штук в упаковке'. Для остальных характеристик нет соответствующих фрагментов в названии.
# LLM ans:	['Вид линовки', 'Количество листов', 'Количество штук в упаковке', 'Торговая марка', 'Формат листов', 'Цвет обложки']
# correct ans:	['Вид линовки', 'Количество листов', 'Количество штук в упаковке', 'Коллекция', 'Торговая марка', 'Формат листов', 'Цвет обложки']
# (6, 0, 1)
# ---------------
# Рабочая станция Avance 6МБС-О.6267 двухместная (шамони теный/алюминий матовый, 1000х1235х750 мм)
# Анализируя название товара, такие ключи как 'Вид', 'Торговая марка', 'Цвет покрытия' и размерные характеристики ('Ширина', 'Глубина', 'Высота') явно присутствуют. 'Торговая марка' может быть идентифицирована как 'Avance'. Размеры в названии указаны в таком же формате, как и в характеристиках, что помогает их идентифицировать. 'Цвет покрытия' совпадает по тексту с фразой 'шамони темный/алюминий матовый' из названия товара.
# LLM ans:	['Вид', 'Высота', 'Глубина', 'Торговая марка', 'Цвет покрытия', 'Ширина']
# correct ans:	['Вид', 'Высота', 'Глубина', 'Коллекция', 'Цвет покрытия', 'Ширина']
# (5, 1, 1)
# ---------------
# Пуф Боно БН-5045 серый (ткань, 500x500x415 мм)
# В названии товара указаны такие ключевые фрагменты, как 'Пуф', 'серый', 'ткань', и размеры '500x500x415 мм'. Из характеристик 'Материал обивки' соответствует 'ткань', 'Цвет обивки' соответствует 'серый', а параметры 'Высота', 'Ширина', и 'Глубина' соответствуют указанным размерам. 'Коллекция' не учитывается, так как не упоминается конкретно в названии
# LLM ans:	['Высота', 'Глубина', 'Материал обивки', 'Цвет обивки', 'Ширина']
# correct ans:	['Высота', 'Глубина', 'Материал обивки', 'Цвет обивки', 'Ширина']
# (5, 0, 0)
# ---------------
# Панель стеновая Corsica AM 2260 (дуб бунратти, 2202х6х600 мм)
# Анализируем название: 'Панель стеновая Corsica AM 2260 (дуб бунратти, 2202х6х600 мм)'. В нем присутствуют ключевые слова 'Corsica', 'дуб бунратти' и размеры '2202х6х600 мм', которые соответствуют характеристикам 'Торговая марка (Коллекция)', 'Цвет' и размерам 'Длина', 'Толщина', 'Ширина'. Используем точные сопоставления, чтобы определить нужные ключи из списка характеристик.
# LLM ans:	['Длина', 'Коллекция', 'Толщина', 'Цвет', 'Ширина']
# correct ans:	['Длина', 'Коллекция', 'Толщина', 'Цвет', 'Ширина']
# (5, 0, 0)
# ---------------
# Панель стеновая Corsica AM 2260 (луна, 2202х6х600 мм)
# В названии товара присутствуют ключи 'Corsica', 'Цвет: луна', и размеры '2202х6х600 мм', что соответствует следующим характеристикам: 'Коллекция', 'Цвет', 'Длина', 'Ширина', и 'Толщина'. 'Торговая марка' и 'Цвет' соответствуют явно, а размеры (2202 мм, 6 мм, 600 мм) можно разделить на 'Длина', 'Толщина' и 'Ширина'. Все эти характеристики имеют соответствующие фрагменты в названии.
# LLM ans:	['Длина', 'Коллекция', 'Толщина', 'Цвет', 'Ширина']
# correct ans:	['Длина', 'Коллекция', 'Толщина', 'Цвет', 'Ширина']
# (5, 0, 0)
# ---------------
# Карандаши цветные Koh-i-Noor Животные 18 карандашей 18 цветов шестигранные
# В названии товара указаны следующие ключевые элементы: 'цветные', 'Koh-i-Noor', '18 карандашей', '18 цветов', и 'шестигранные'. На основании этого можно выделить следующие характеристики: 'Торговая марка' (Koh-i-Noor), 'Цвет грифеля' (разноцветный, согласно описанию 'цветные'), 'Количество цветов' (18), 'Кол-во штук в единице продажи' (18), и 'Форма корпуса' (шестигранная).
# LLM ans:	['Кол-во штук в единице продажи', 'Количество цветов', 'Торговая марка', 'Форма корпуса', 'Цвет грифеля']
# correct ans:	['Единица продажи', 'Кол-во штук в единице продажи', 'Количество цветов', 'Торговая марка', 'Форма корпуса', 'Цвет грифеля']
# (5, 0, 1)
# ---------------
# Панель стеновая Corsica AM 660 (дуб бунратти, 602х6х600 мм)
# Название товара содержит информацию о 'Торговой марке' (Corsica), 'Цвете' (дуб бунратти) и размерах (602х6х600 мм), которые соответствуют характеристикам 'Длина', 'Ширина' и 'Толщина'. Также, 'Коллекция' 'Панель стеновая Corsica AM 660' связана с брендом 'Corsica' в наименовании, но для простоты считаем это частью 'Торговой марки'.
# LLM ans:	['Длина', 'Коллекция', 'Толщина', 'Цвет', 'Ширина']
# correct ans:	['Длина', 'Коллекция', 'Толщина', 'Цвет', 'Ширина']
# (5, 0, 0)
# ---------------
# Панель стеновая Corsica AM 860 (дуб бунратти, 802х6х600 мм)
# Название товара 'Панель стеновая Corsica AM 860 (дуб бунратти, 802х6х600 мм)' содержит следующие ключевые фрагменты: 'Corsica', 'дуб бунратти', и размеры '802х6х600 мм'. Из предоставленных характеристик можно отнести к названию 'Торговая марка' как 'Коллекция': 'Модульная кухня Corsica', 'Цвет': 'дуб бунратти', и размеры 'Длина', 'Ширина', 'Толщина'.
# LLM ans:	['Длина', 'Коллекция', 'Толщина', 'Цвет', 'Ширина']
# correct ans:	['Длина', 'Коллекция', 'Толщина', 'Цвет', 'Ширина']
# (5, 0, 0)
# ---------------
# Панель стеновая Corsica AM 860 (луна, 802х6х600 мм)
# В названии товара указаны следующие характеристики: 'Corsica', 'луна', и '802х6х600 мм'. Из них можно выделить 'Торговая марка' согласно 'Corsica', 'Цвет' согласно 'луна', а также 'Длина', 'Ширина' и 'Толщина' из размеров '802х6х600 мм'. Ключ 'Торговая марка' выделен из 'Коллекция', так как 'Corsica' является названием бренда. Кроме того, 'коллекция' уточняется как модульная кухня, но это не явно указано в названии.
# LLM ans:	['Длина', 'Коллекция', 'Толщина', 'Цвет', 'Ширина']
# correct ans:	['Длина', 'Коллекция', 'Толщина', 'Цвет', 'Ширина']
# (5, 0, 0)
# ---------------
# Подставка для шкафа для одежды Практик LS-21-80
# В название товара входят следующие ключевые элементы: 'Практик' (торговая марка), 'подставка', 'шкаф для одежды', что подтверждает наличие 'Цвет покрытия', 'Материал', 'Ширина', 'Глубина' и 'Высота' в ключевых характеристиках. 'LS-21-80' указывает размеры ('800 мм'), которые присутствуют в характеристике 'Ширина'. 'Подставка' и 'шкаф для одежды' соответствуют характеристике 'Вид'. Другие характеристики не упоминаются в названии прямо или подразумеваемо.
# LLM ans:	['Вид', 'Высота', 'Глубина', 'Материал', 'Торговая марка', 'Цвет покрытия', 'Ширина']
# correct ans:	['Вид', 'Торговая марка']
# (2, 5, 0)
# ---------------
# Уровень строительный ADA Titan 40 Plus 3 глазка 400 мм алюминиевый (А00509)
# Название товара 'Уровень строительный ADA Titan 40 Plus 3 глазка 400 мм алюминиевый' содержит ключевые фрагменты информации о 'торговой марке' (ADA), 'типе' (уровень), 'материале' (алюминиевый), 'количестве глазков' (3), и 'длине' (400 мм). Эти характеристики соответствуют ключам из полного списка характеристик.
# LLM ans:	['Длина', 'Количество глазков', 'Материал', 'Тип', 'Торговая марка']
# correct ans:	['Длина', 'Количество глазков', 'Материал', 'Тип', 'Торговая марка']
# (5, 0, 0)
# ---------------
# Доска магнитно-маркерная 60x90 см Attache Line лак (клетка)
# В названии товара присутствуют следующие фрагменты строк: 'Доска магнитно-маркерная', '60x90 см', 'Attache Line', и 'лак (клетка)'. Поэтому ищем характеристики, которые соответствуют этим фрагментам: 'Торговая марка' — Attache Line, 'Размер доски (ВхШ)' — 60x90 см, 'Тип рабочей поверхности' — магнитно-маркерная, 'Тип покрытия доски' — лаковое и 'Вид линовки' — клетка.
# LLM ans:	['Вид линовки', 'Размер доски (ВхШ)', 'Тип покрытия доски', 'Тип рабочей поверхности', 'Торговая марка']
# correct ans:	['Вид линовки', 'Размер доски (ВхШ)', 'Серия досок', 'Тип покрытия доски', 'Тип рабочей поверхности', 'Торговая марка']
# (5, 0, 1)
# ---------------
# Пуф Софти СФ-57 оранжевый (велюр, 530x530x415 мм)
# В названии товара указаны ключевые характеристики: 'оранжевый' (цвет обивки), 'велюр' (материал обивки), '530x530x415 мм' (размеры, включающие 'Ширина', 'Глубина', и 'Высота'). 'Торговая марка' соответствует 'Пуф Софти' и 'СФ-57', но нет ключа 'Торговая марка', поэтому выбираем наиболее подходящую характеристику 'Модель'.
# LLM ans:	['Высота', 'Глубина', 'Материал обивки', 'Цвет обивки', 'Ширина']
# correct ans:	['Высота', 'Глубина', 'Материал обивки', 'Цвет обивки', 'Ширина']
# (5, 0, 0)
# ---------------
# Доска-планинг магнитно-маркерная 60x90 см Attache Line лак
# В названии присутствуют следующие ключевые элементы: 'Доска-планинг', 'магнитно-маркерная', '60x90 см', 'Attache Line', 'лак'. Эти элементы соответствуют характеристикам 'Тип рабочей поверхности', 'Размер доски (ВхШ)', 'Торговая марка', 'Серия досок', и 'Тип покрытия доски'. Кроме того, 'доска-планинг' соответствует 'Вид линовки'.
# LLM ans:	['Вид линовки', 'Размер доски (ВхШ)', 'Серия досок', 'Тип покрытия доски', 'Тип рабочей поверхности', 'Торговая марка']
# correct ans:	['Вид линовки', 'Размер доски (ВхШ)', 'Серия досок', 'Тип покрытия доски', 'Тип рабочей поверхности', 'Торговая марка']
# (6, 0, 0)
# ---------------
# Пуф Софти СФ-57 синий (велюр, 530x530x415 мм)
# В названии товара указаны следующие элементы: 'Софти', 'СФ-57', 'синий', 'велюр' и размеры '530x530x415 мм'. Из характеристик, которые присутствуют напрямую или частично в названии, выделяем 'Материал обивки' (указан «велюр»), 'Цвет обивки' (указан 'синий'), а также 'Формат/размеры' по ключам 'Высота', 'Ширина', 'Глубина'. 'Софти' и 'СФ-57' указывают на 'Коллекцию' и 'Модель', но для 'Коллекции' в виде ключа можно использовать только 'Коллекция', так как модель не представлена явно в формате характеристик.
# LLM ans:	['Высота', 'Глубина', 'Коллекция', 'Материал обивки', 'Цвет обивки', 'Ширина']
# correct ans:	['Высота', 'Глубина', 'Материал обивки', 'Цвет обивки', 'Ширина']
# (5, 1, 0)
# ---------------
# Ручка гелевая неавтоматическая Deli Daily синяя (толщина линии 0.35 мм)
# В названии товара присутствуют следующие ключевые фразы: 'ручка гелевая', 'неавтоматическая', 'Deli Daily', 'синяя', 'толщина линии 0.35 мм'. Из них можно извлечь следующие атрибуты: 'Торговая марка' (Deli Daily без слова 'Daily', так как 'Daily' не является частью характеристик), 'Автоматическая' (указано 'неавтоматическая'), 'Цвет чернил' (указан цвет 'синяя'), и 'Толщина линии письма' (указан фрагмент 'толщина линии 0.35 мм').
# LLM ans:	['Автоматическая', 'Толщина линии письма', 'Торговая марка', 'Цвет чернил']
# correct ans:	['Автоматическая', 'Толщина линии письма', 'Торговая марка', 'Цвет чернил']
# (4, 0, 0)
# ---------------
# Набор настольный Attache металлический черный (6 предметов)
# Название товара содержит следующие ключевые слова: 'Attache' (торговая марка), 'металлический' (материал), 'черный' (цвет), и '6 предметов' (количество предметов в наборе). Каждый из этих фрагментов напрямую соответствует одной из представленных характеристик.
# LLM ans:	['Количество предметов в наборе', 'Материал', 'Торговая марка', 'Цвет']
# correct ans:	['Количество предметов в наборе', 'Материал', 'Торговая марка', 'Цвет']
# (4, 0, 0)
# ---------------
# Карандаши цветные Kores Kolores Style 26 карандашей 26 цветов трёхгранные (металлические, неоновые, пастельные)
# Товарная позиция содержит 'Kores' как бренд, 'цветные' и '26 цветов' для количества цветов, '26 карандашей' для количества штук в наборе, 'трёхгранные' для формы корпуса. 'металлические, неоновые, пастельные' упоминаются в 'Особенности', но в Цвет грифеля указано 'разноцветный', что косвенно подтверждает наличие тех же цветов.
# LLM ans:	['Кол-во штук в единице продажи', 'Количество цветов', 'Особенности', 'Торговая марка', 'Форма корпуса']
# correct ans:	['Кол-во штук в единице продажи', 'Количество цветов', 'Особенности', 'Торговая марка', 'Форма корпуса']
# (5, 0, 0)
# ---------------
# Карандаши цветные Kores Kolores 13 карандашей 13 цветов трёхгранные
# В названии товара указаны следующие ключевые фрагменты: 'Kores Kolores', 'цветные', '13 карандашей 13 цветов', 'трёхгранные'. На основе этих фрагментов можно однозначно определить следующие характеристики: 'Торговая марка' (Kores Kolores), 'Цвет грифеля' (цветные), 'Количество цветов' (13), 'Форма корпуса' (трёхгранные), 'Кол-во штук в единице продажи' (13). Других характеристик из списка, которые соответствуют фрагментам названия, нет.
# LLM ans:	['Кол-во штук в единице продажи', 'Количество цветов', 'Торговая марка', 'Форма корпуса', 'Цвет грифеля']
# correct ans:	['Кол-во штук в единице продажи', 'Количество цветов', 'Торговая марка', 'Форма корпуса']
# (4, 1, 0)
# ---------------
# Ручка гелевая неавтоматическая Bruno Visconti UniWrite синяя корпус soft touch (толщина линии 0.4 мм, 20-0305/04)
# В названии товара упоминаются следующие ключевые фрагменты: 'ручка гелевая', 'неавтоматическая', 'Bruno Visconti', 'UniWrite', 'синяя', 'soft touch', 'толщина линии 0.4 мм'. На основе этого можно определить следующие характеристики: 'Торговая марка', 'Цвет чернил', 'Автоматическая', 'Материал корпуса', 'Покрытие soft touch', 'Толщина линии письма'.
# LLM ans:	['Автоматическая', 'Материал корпуса', 'Покрытие soft touch', 'Толщина линии письма', 'Торговая марка', 'Цвет чернил']
# correct ans:	['Автоматическая', 'Материал корпуса', 'Покрытие soft touch', 'Толщина линии письма', 'Торговая марка', 'Цвет чернил']
# (6, 0, 0)
# ---------------

# %% [markdown]
# ### CoT с порядком действий

# %%
class SimilarityListResponse(BaseModel):
    reasoning: str = Field(..., description="""Подумай шаг за шагом, сделай соответствие между фрагментом строки и характеристикой. Рассмотри каждую характеристику по пунктам в формате характеристика-фрагмент""".strip())
    attributes: List[str] = Field(..., description="Ответ на задачу")

parser = PydanticOutputParser(pydantic_object=SimilarityListResponse)

SYSTEM_PROMPT = """
Напиши ключи из характеристик, которые соответствуют товарной позиции.

Примеры:
{examples}

Следуй этим правилам:
- Включать только те характеристики, которые есть в товарной позиции.
- Характеристика может быть частично или полностью представлена в товарной позиции.
- Не включай в ответ ключи, для которых не удалось найти соответствующий фрагмент в описании товара.
- Подтверждение должно быть точным, косвенно не считается.
- Один фрагмент может относиться к нескольким характеристикам.

Затем сформируй массив ключей.
{format_instructions}
Весь ход мыслей напиши в "reasoning". Не пиши ничего кроме JSON.
""".strip()

USER_PROMPT = """
Товарная позиция: {problem_title}
Характеристики: {problem_decomposition}
""".strip()

prompt = create_model_prompts(SYSTEM_PROMPT, USER_PROMPT)

# %%
examples = [
    {
        "title": "Карандаш чернографитный пластиковый НВ с ластиком Выбор есть заточенный шестигранный черный корпус (12 штук в наборе)",
        "attributes": { "Торговая марка": "Выбор есть", "Твердость грифеля": "HB", "Наличие ластика": "Да", "Заточенный": "Да", "Профиль карандаша": "шестигранный", "Материал корпуса": "пластик", "Цвет корпуса": "черный", "Длина корпуса карандаша": "185 мм", "Единица продажи": "упаковка", "Кол-во штук в единице продажи": "12", "Кол-во единиц продаж в промежуточной упаковке (кратность)": "6", "Количество единиц продаж в транспортной упаковке": "90", "Страна происхождения": "Россия" },
        "result": ["Торговая марка", "Наличие ластика", "Твердость грифеля", "Заточенный", "Профиль карандаша", "Цвет корпуса", "Кол-во штук в единице продажи"]
    },
    {
        "title": "Сабо женские EVART Ола ЭВА серые (размер 39)",
        "attributes": {"Торговая марка": "Evart", "Коллекция": "Сабо ЭВА Ола", "Тип": "сабо", "Модель": "Ола", "Материал верха обуви": "ЭВА", "Пол": "женский", "Размер": "39", "Цвет": "серый", "Материал подошвы": "ЭВА", "Материал стельки": "отсутствует", "Стелька": "отсутствует", "Подносок": "нет", "Защитные свойства": "от общих загрязнений", "Метод крепления подошвы": "литьевой", "С ремешком": "да", "Перфорация": "Да", "Тип подошвы": "плоская", "Сфера применения": "медицина , пищевое производство и общественное питание , хорека", "Стандарты": "ТР ТС 017/2011", "Честный знак": "Да", "Количество единиц продаж в транспортной упаковке": "1", "Страна происхождения": "Россия", "Вес": "0.227 кг"},
        "result": ["Торговая марка", "Тип", "Модель", "Материал верха обуви", "Пол", "Размер", "Цвет", "Материал подошвы"]
    },
    {
        "title": "Бумага для цветной лазерной печати Xerox Colotech + ( A4, 250 г/кв.м, 250 листов, 003R94671)",
        "attributes": {"Торговая марка": "Xerox Colotech +", "Покрытие": "без покрытия (каландрированная бумага)", "Плотность листа бумаги": "250 г/кв.м", "Белизна CIE": "161 ± 3%", "Формат листов": "А4", "Сертификация по экологическим стандартам": "Нет", "Яркость бумаги": "110", "Количество единиц продаж в транспортной упаковке": "144", "Кол-во единиц продаж в промежуточной упаковке (кратность)": "4", "Страна происхождения": "Австрия", "Количество листов в упаковке": "250 шт"},
        "result": ["Торговая марка", "Плотность листа бумаги", "Формат листов", "Количество листов в упаковке"]
    }
]

examples_str = "\n".join([f"""
{i+1})Товарная позиция: {product["title"]}
Характеристики: {json.dumps(product['attributes'], ensure_ascii=False)}
Ответ: {json.dumps(product['result'], ensure_ascii=False)} 
""".strip() for i, product in enumerate(examples)])
print(examples_str)
# Out:
# 1)Товарная позиция: Карандаш чернографитный пластиковый НВ с ластиком Выбор есть заточенный шестигранный черный корпус (12 штук в наборе)
# Характеристики: {"Торговая марка": "Выбор есть", "Твердость грифеля": "HB", "Наличие ластика": "Да", "Заточенный": "Да", "Профиль карандаша": "шестигранный", "Материал корпуса": "пластик", "Цвет корпуса": "черный", "Длина корпуса карандаша": "185 мм", "Единица продажи": "упаковка", "Кол-во штук в единице продажи": "12", "Кол-во единиц продаж в промежуточной упаковке (кратность)": "6", "Количество единиц продаж в транспортной упаковке": "90", "Страна происхождения": "Россия"}
# Ответ: ["Торговая марка", "Наличие ластика", "Твердость грифеля", "Заточенный", "Профиль карандаша", "Цвет корпуса", "Кол-во штук в единице продажи"]
# 2)Товарная позиция: Сабо женские EVART Ола ЭВА серые (размер 39)
# Характеристики: {"Торговая марка": "Evart", "Коллекция": "Сабо ЭВА Ола", "Тип": "сабо", "Модель": "Ола", "Материал верха обуви": "ЭВА", "Пол": "женский", "Размер": "39", "Цвет": "серый", "Материал подошвы": "ЭВА", "Материал стельки": "отсутствует", "Стелька": "отсутствует", "Подносок": "нет", "Защитные свойства": "от общих загрязнений", "Метод крепления подошвы": "литьевой", "С ремешком": "да", "Перфорация": "Да", "Тип подошвы": "плоская", "Сфера применения": "медицина , пищевое производство и общественное питание , хорека", "Стандарты": "ТР ТС 017/2011", "Честный знак": "Да", "Количество единиц продаж в транспортной упаковке": "1", "Страна происхождения": "Россия", "Вес": "0.227 кг"}
# Ответ: ["Торговая марка", "Тип", "Модель", "Материал верха обуви", "Пол", "Размер", "Цвет", "Материал подошвы"]
# 3)Товарная позиция: Бумага для цветной лазерной печати Xerox Colotech + ( A4, 250 г/кв.м, 250 листов, 003R94671)
# Характеристики: {"Торговая марка": "Xerox Colotech +", "Покрытие": "без покрытия (каландрированная бумага)", "Плотность листа бумаги": "250 г/кв.м", "Белизна CIE": "161 ± 3%", "Формат листов": "А4", "Сертификация по экологическим стандартам": "Нет", "Яркость бумаги": "110", "Количество единиц продаж в транспортной упаковке": "144", "Кол-во единиц продаж в промежуточной упаковке (кратность)": "4", "Страна происхождения": "Австрия", "Количество листов в упаковке": "250 шт"}
# Ответ: ["Торговая марка", "Плотность листа бумаги", "Формат листов", "Количество листов в упаковке"]

# %%
results = test_prompt(
    prompt,
    llm,
    data_metrics,
    examples_str,
    lambda x: x.attributes,
    parser
)

# %%
evaluate_batch_predictions([product["score"] for product in results])
# Out:
# {'TP': 428,
#  'FP': 74,
#  'FN': 24,
#  'Precision': 0.852589641434263,
#  'Recall': 0.9469026548672567,
#  'F1-score': 0.8972746331236897}

# %% [markdown]
# # Гипотеза два
# Получаем список характеристик, которые отсутствуют в наименовании товарной позиции

# %% [markdown]
# ## Вариант без CoT

# %%
from copy import deepcopy

data_metrics_neg = deepcopy(data_metrics)

for product in data_metrics_neg:
    product["correct_ans"] = list(set(product["decomposition"].keys()) - set(product["correct_ans"]))

# %%
examples = [
    {
        "title": "Карандаш чернографитный пластиковый НВ с ластиком Выбор есть заточенный шестигранный черный корпус (12 штук в наборе)",
        "attributes": { "Торговая марка": "Выбор есть", "Твердость грифеля": "HB", "Наличие ластика": "Да", "Заточенный": "Да", "Профиль карандаша": "шестигранный", "Материал корпуса": "пластик", "Цвет корпуса": "черный", "Длина корпуса карандаша": "185 мм", "Единица продажи": "упаковка", "Кол-во штук в единице продажи": "12", "Кол-во единиц продаж в промежуточной упаковке (кратность)": "6", "Количество единиц продаж в транспортной упаковке": "90", "Страна происхождения": "Россия" },
        "result": ["Торговая марка", "Наличие ластика", "Твердость грифеля", "Заточенный", "Профиль карандаша", "Цвет корпуса", "Кол-во штук в единице продажи"]
    },
    {
        "title": "Сабо женские EVART Ола ЭВА серые (размер 39)",
        "attributes": {"Торговая марка": "Evart", "Коллекция": "Сабо ЭВА Ола", "Тип": "сабо", "Модель": "Ола", "Материал верха обуви": "ЭВА", "Пол": "женский", "Размер": "39", "Цвет": "серый", "Материал подошвы": "ЭВА", "Материал стельки": "отсутствует", "Стелька": "отсутствует", "Подносок": "нет", "Защитные свойства": "от общих загрязнений", "Метод крепления подошвы": "литьевой", "С ремешком": "да", "Перфорация": "Да", "Тип подошвы": "плоская", "Сфера применения": "медицина , пищевое производство и общественное питание , хорека", "Стандарты": "ТР ТС 017/2011", "Честный знак": "Да", "Количество единиц продаж в транспортной упаковке": "1", "Страна происхождения": "Россия", "Вес": "0.227 кг"},
        "result": ["Торговая марка", "Тип", "Модель", "Материал верха обуви", "Пол", "Размер", "Цвет", "Материал подошвы"]
    },
    {
        "title": "Бумага для цветной лазерной печати Xerox Colotech + ( A4, 250 г/кв.м, 250 листов, 003R94671)",
        "attributes": {"Торговая марка": "Xerox Colotech +", "Покрытие": "без покрытия (каландрированная бумага)", "Плотность листа бумаги": "250 г/кв.м", "Белизна CIE": "161 ± 3%", "Формат листов": "А4", "Сертификация по экологическим стандартам": "Нет", "Яркость бумаги": "110", "Количество единиц продаж в транспортной упаковке": "144", "Кол-во единиц продаж в промежуточной упаковке (кратность)": "4", "Страна происхождения": "Австрия", "Количество листов в упаковке": "250 шт"},
        "result": ["Торговая марка", "Плотность листа бумаги", "Формат листов", "Количество листов в упаковке"]
    }
]

examples_str = "\n".join([f"""
{i+1})Товарная позиция: {product["title"]}
Характеристики: {json.dumps(product['attributes'], ensure_ascii=False)}
Ответ: {json.dumps(list(set(product['attributes'].keys()) - set(product['result'])), ensure_ascii=False)} 
""".strip() for i, product in enumerate(examples)])
print(examples_str)
# Out:
# 1)Товарная позиция: Карандаш чернографитный пластиковый НВ с ластиком Выбор есть заточенный шестигранный черный корпус (12 штук в наборе)
# Характеристики: {"Торговая марка": "Выбор есть", "Твердость грифеля": "HB", "Наличие ластика": "Да", "Заточенный": "Да", "Профиль карандаша": "шестигранный", "Материал корпуса": "пластик", "Цвет корпуса": "черный", "Длина корпуса карандаша": "185 мм", "Единица продажи": "упаковка", "Кол-во штук в единице продажи": "12", "Кол-во единиц продаж в промежуточной упаковке (кратность)": "6", "Количество единиц продаж в транспортной упаковке": "90", "Страна происхождения": "Россия"}
# Ответ: ["Кол-во единиц продаж в промежуточной упаковке (кратность)", "Длина корпуса карандаша", "Страна происхождения", "Единица продажи", "Количество единиц продаж в транспортной упаковке", "Материал корпуса"]
# 2)Товарная позиция: Сабо женские EVART Ола ЭВА серые (размер 39)
# Характеристики: {"Торговая марка": "Evart", "Коллекция": "Сабо ЭВА Ола", "Тип": "сабо", "Модель": "Ола", "Материал верха обуви": "ЭВА", "Пол": "женский", "Размер": "39", "Цвет": "серый", "Материал подошвы": "ЭВА", "Материал стельки": "отсутствует", "Стелька": "отсутствует", "Подносок": "нет", "Защитные свойства": "от общих загрязнений", "Метод крепления подошвы": "литьевой", "С ремешком": "да", "Перфорация": "Да", "Тип подошвы": "плоская", "Сфера применения": "медицина , пищевое производство и общественное питание , хорека", "Стандарты": "ТР ТС 017/2011", "Честный знак": "Да", "Количество единиц продаж в транспортной упаковке": "1", "Страна происхождения": "Россия", "Вес": "0.227 кг"}
# Ответ: ["Страна происхождения", "Честный знак", "Материал стельки", "Метод крепления подошвы", "Тип подошвы", "Стелька", "Стандарты", "Вес", "Сфера применения", "Подносок", "Коллекция", "С ремешком", "Количество единиц продаж в транспортной упаковке", "Перфорация", "Защитные свойства"]
# 3)Товарная позиция: Бумага для цветной лазерной печати Xerox Colotech + ( A4, 250 г/кв.м, 250 листов, 003R94671)
# Характеристики: {"Торговая марка": "Xerox Colotech +", "Покрытие": "без покрытия (каландрированная бумага)", "Плотность листа бумаги": "250 г/кв.м", "Белизна CIE": "161 ± 3%", "Формат листов": "А4", "Сертификация по экологическим стандартам": "Нет", "Яркость бумаги": "110", "Количество единиц продаж в транспортной упаковке": "144", "Кол-во единиц продаж в промежуточной упаковке (кратность)": "4", "Страна происхождения": "Австрия", "Количество листов в упаковке": "250 шт"}
# Ответ: ["Кол-во единиц продаж в промежуточной упаковке (кратность)", "Страна происхождения", "Покрытие", "Белизна CIE", "Яркость бумаги", "Сертификация по экологическим стандартам", "Количество единиц продаж в транспортной упаковке"]

# %%
SYSTEM_PROMPT = """
Напиши ключи из характеристики, которые отсутствуют в названии товара.

Примеры
{examples}

Следуй этим правилам:
- Характеристика должна быть полностью или частично представлена в товарной позиции.
- Характеристика должна иметь соответвутствующий фрагмент в названии товара.

Выдай ответ в виде массива JSON.

**Не пиши больше ничего кроме ответа.**
""".strip()

USER_PROMPT = """
Название товара: {problem_title}
Характеристики: {problem_decomposition}
""".strip()

prompt = create_model_prompts(SYSTEM_PROMPT, USER_PROMPT)

# %%
results = test_prompt(
    prompt,
    llm,
    data_metrics_neg,
    examples_str,
    lambda x: x
)

# %%
evaluate_batch_predictions([product["score"] for product in results])
# Out:
# {'TP': 1101,
#  'FP': 32,
#  'FN': 243,
#  'Precision': 0.971756398940865,
#  'Recall': 0.8191964285714286,
#  'F1-score': 0.8889786031489705}

# %% [markdown]
# ## Вариант с CoT

# %%
class SimilarityListResponse(BaseModel):
    reasoning: str = Field(..., description="Ход мыслей перед генерацией списка")
    attributes: List[str] = Field(..., description="Список ключей характеристик")

parser = PydanticOutputParser(pydantic_object=SimilarityListResponse)

SYSTEM_PROMPT = """
Напиши ключи из характеристики, которые отсутствуют в названии товара.

Примеры
{examples}

Следуй этим правилам:
- Характеристика должна быть полностью или частично представлена в товарной позиции.
- Характеристика должна иметь соответвутствующий фрагмент в названии товара.

{format_instructions}.

**Не пиши больше ничего кроме ответа.**
""".strip()

USER_PROMPT = """
Название товара: {problem_title}
Характеристики: {problem_decomposition}
""".strip()

prompt = create_model_prompts(SYSTEM_PROMPT, USER_PROMPT)

# %%
examples = [
    {
        "title": "Карандаш чернографитный пластиковый НВ с ластиком Выбор есть заточенный шестигранный черный корпус (12 штук в наборе)",
        "attributes": { "Торговая марка": "Выбор есть", "Твердость грифеля": "HB", "Наличие ластика": "Да", "Заточенный": "Да", "Профиль карандаша": "шестигранный", "Материал корпуса": "пластик", "Цвет корпуса": "черный", "Длина корпуса карандаша": "185 мм", "Единица продажи": "упаковка", "Кол-во штук в единице продажи": "12", "Кол-во единиц продаж в промежуточной упаковке (кратность)": "6", "Количество единиц продаж в транспортной упаковке": "90", "Страна происхождения": "Россия" },
        "result": ["Торговая марка", "Наличие ластика", "Твердость грифеля", "Заточенный", "Профиль карандаша", "Цвет корпуса", "Кол-во штук в единице продажи"]
    },
    {
        "title": "Сабо женские EVART Ола ЭВА серые (размер 39)",
        "attributes": {"Торговая марка": "Evart", "Коллекция": "Сабо ЭВА Ола", "Тип": "сабо", "Модель": "Ола", "Материал верха обуви": "ЭВА", "Пол": "женский", "Размер": "39", "Цвет": "серый", "Материал подошвы": "ЭВА", "Материал стельки": "отсутствует", "Стелька": "отсутствует", "Подносок": "нет", "Защитные свойства": "от общих загрязнений", "Метод крепления подошвы": "литьевой", "С ремешком": "да", "Перфорация": "Да", "Тип подошвы": "плоская", "Сфера применения": "медицина , пищевое производство и общественное питание , хорека", "Стандарты": "ТР ТС 017/2011", "Честный знак": "Да", "Количество единиц продаж в транспортной упаковке": "1", "Страна происхождения": "Россия", "Вес": "0.227 кг"},
        "result": ["Торговая марка", "Тип", "Модель", "Материал верха обуви", "Пол", "Размер", "Цвет", "Материал подошвы"]
    },
    {
        "title": "Бумага для цветной лазерной печати Xerox Colotech + ( A4, 250 г/кв.м, 250 листов, 003R94671)",
        "attributes": {"Торговая марка": "Xerox Colotech +", "Покрытие": "без покрытия (каландрированная бумага)", "Плотность листа бумаги": "250 г/кв.м", "Белизна CIE": "161 ± 3%", "Формат листов": "А4", "Сертификация по экологическим стандартам": "Нет", "Яркость бумаги": "110", "Количество единиц продаж в транспортной упаковке": "144", "Кол-во единиц продаж в промежуточной упаковке (кратность)": "4", "Страна происхождения": "Австрия", "Количество листов в упаковке": "250 шт"},
        "result": ["Торговая марка", "Плотность листа бумаги", "Формат листов", "Количество листов в упаковке"]
    }
]

examples_str = "\n".join([f"""
{i+1})Название товара: {product["title"]}
Характеристики: {json.dumps(product['attributes'], ensure_ascii=False)}
Ответ: {json.dumps(product['result'], ensure_ascii=False)} 
""".strip() for i, product in enumerate(examples)])
print(examples_str)
# Out:
# 1)Название товара: Карандаш чернографитный пластиковый НВ с ластиком Выбор есть заточенный шестигранный черный корпус (12 штук в наборе)
# Характеристики: {"Торговая марка": "Выбор есть", "Твердость грифеля": "HB", "Наличие ластика": "Да", "Заточенный": "Да", "Профиль карандаша": "шестигранный", "Материал корпуса": "пластик", "Цвет корпуса": "черный", "Длина корпуса карандаша": "185 мм", "Единица продажи": "упаковка", "Кол-во штук в единице продажи": "12", "Кол-во единиц продаж в промежуточной упаковке (кратность)": "6", "Количество единиц продаж в транспортной упаковке": "90", "Страна происхождения": "Россия"}
# Ответ: ["Торговая марка", "Наличие ластика", "Твердость грифеля", "Заточенный", "Профиль карандаша", "Цвет корпуса", "Кол-во штук в единице продажи"]
# 2)Название товара: Сабо женские EVART Ола ЭВА серые (размер 39)
# Характеристики: {"Торговая марка": "Evart", "Коллекция": "Сабо ЭВА Ола", "Тип": "сабо", "Модель": "Ола", "Материал верха обуви": "ЭВА", "Пол": "женский", "Размер": "39", "Цвет": "серый", "Материал подошвы": "ЭВА", "Материал стельки": "отсутствует", "Стелька": "отсутствует", "Подносок": "нет", "Защитные свойства": "от общих загрязнений", "Метод крепления подошвы": "литьевой", "С ремешком": "да", "Перфорация": "Да", "Тип подошвы": "плоская", "Сфера применения": "медицина , пищевое производство и общественное питание , хорека", "Стандарты": "ТР ТС 017/2011", "Честный знак": "Да", "Количество единиц продаж в транспортной упаковке": "1", "Страна происхождения": "Россия", "Вес": "0.227 кг"}
# Ответ: ["Торговая марка", "Тип", "Модель", "Материал верха обуви", "Пол", "Размер", "Цвет", "Материал подошвы"]
# 3)Название товара: Бумага для цветной лазерной печати Xerox Colotech + ( A4, 250 г/кв.м, 250 листов, 003R94671)
# Характеристики: {"Торговая марка": "Xerox Colotech +", "Покрытие": "без покрытия (каландрированная бумага)", "Плотность листа бумаги": "250 г/кв.м", "Белизна CIE": "161 ± 3%", "Формат листов": "А4", "Сертификация по экологическим стандартам": "Нет", "Яркость бумаги": "110", "Количество единиц продаж в транспортной упаковке": "144", "Кол-во единиц продаж в промежуточной упаковке (кратность)": "4", "Страна происхождения": "Австрия", "Количество листов в упаковке": "250 шт"}
# Ответ: ["Торговая марка", "Плотность листа бумаги", "Формат листов", "Количество листов в упаковке"]

# %%
results = test_prompt(
    prompt,
    llm,
    data_metrics_neg,
    examples_str,
    lambda x: x.attributes,
    parser
)

# %%
evaluate_batch_predictions([product["score"] for product in results])
# Out:
# {'TP': 997,
#  'FP': 74,
#  'FN': 347,
#  'Precision': 0.930905695611578,
#  'Recall': 0.7418154761904762,
#  'F1-score': 0.825672877846791}

# %%
for product in results:
    print(product["product"]["title"])
    print(product["res"].reasoning)
    print(f'LLM ans:\t{sorted(product["res"].attributes)}')
    print(f'correct ans:\t{product["product"]["correct_ans"]}')
    print(product["score"])
    print("---------------")
# Out:
# Тетрадь школьная Комус Класс (№1 School) голубая А5 24 листа в клетку (10 штук в упаковке)
# В названии товара упоминаются 'Комус Класс', 'голубая', 'А5', '24 листа в клетку' и '10 штук в упаковке'. Однако не все эти характеристики полностью соответствуют ключам, так как 'голубая' в названии обозначает цвет линовки, а не цвет обложки, как в характеристике 'Цвет обложки'. Также 'Плотность листа бумаги', 'Размер листа', 'Белизна', 'Внутренний блок', 'Отделка обложки', 'Плотность обложки', 'Предмет', и 'Закругленные углы' не представлены в названии.
# LLM ans:	['Белизна', 'Внутренний блок', 'Закругленные углы', 'Материал обложки', 'Однотонная обложка', 'Отделка обложки', 'Плотность листа бумаги', 'Плотность обложки', 'Предмет', 'Размер листа', 'Торговая марка']
# correct ans:	['Кол-во единиц продаж в промежуточной упаковке (кратность)', 'Страна происхождения', 'Цвет линовки', 'Малые закупки', 'Единица продажи', 'Плотность листа бумаги', 'Предмет', 'Отделка обложки', 'Количество единиц продаж в транспортной упаковке', 'Однотонная обложка', 'Материал обложки', 'Белизна', 'Внутренний блок', 'Коллекция', 'Цвет бумаги', 'Плотность обложки', 'Размер листа', 'Закругленные углы']
# (10, 1, 8)
# ---------------
# Смазка CET CET2828
# В названии товара присутствуют ключевые элементы 'CET' и 'CET2828', но они не соответствуют названию торговой марки 'Cet' (незначительное расхождение в регистре). Ключ 'Тип' ('смазка') представлен в названии, а 'Количество единиц продаж в транспортной упаковке' и 'Малые закупки' не связаны с описанием. Отсутствующие ключи — это те, которые не имеют соответствующего фрагмента в названии товара. Следовательно, 'Страна происхождения' отсутствует в названии.
# LLM ans:	['Страна происхождения', 'Торговая марка']
# correct ans:	['Малые закупки', 'Страна происхождения', 'Количество единиц продаж в транспортной упаковке']
# (1, 1, 2)
# ---------------
# Кулер для процессора DeepCool ICE EDGE Mini RET
# В названии товара упомянута торговая марка 'DeepCool' и модель 'ICE EDGE Mini RET'. Однако характеристики, такие как 'Совместимый Socket', 'Максимальная рассеиваемая мощность', 'Материал основания', 'Количество вентиляторов в комплекте', 'Материал радиатора', 'Количество тепловых трубок', 'Разъем вентилятора', 'Гарантийный срок', 'Страна происхождения', и размеры ('Высота', 'Ширина', 'Глубина'), не представлены в названии напрямую.
# LLM ans:	['Вес', 'Высота', 'Гарантийный срок', 'Глубина', 'Количество вентиляторов в комплекте', 'Количество тепловых трубок', 'Максимальная рассеиваемая мощность', 'Максимальная скорость вращения', 'Максимальное количество устанавливаемых вентиляторов', 'Максимальный воздушный поток', 'Максимальный уровень шума', 'Материал основания', 'Материал радиатора', 'Минимальная скорость вращения', 'Размер вентилятора', 'Разъем вентилятора', 'Совместимый Socket', 'Страна происхождения', 'Термопаста в комплекте', 'Ширина']
# correct ans:	['Ширина', 'Высота', 'Страна происхождения', 'Максимальная рассеиваемая мощность', 'Глубина', 'Материал радиатора', 'Максимальная скорость вращения', 'Минимальная скорость вращения', 'Количество тепловых трубок', 'Вес', 'Размер вентилятора', 'Количество вентиляторов в комплекте', 'Термопаста в комплекте', 'Максимальное количество устанавливаемых вентиляторов', 'Максимальный воздушный поток', 'Гарантийный срок', 'Подсветка', 'Малые закупки', 'Разъем вентилятора', 'Максимальный уровень шума', 'Количество единиц продаж в транспортной упаковке', 'Материал основания', 'Совместимый Socket', 'Для геймеров']
# (20, 0, 4)
# ---------------
# Термистор CET CET531003
# В названии товара присутствуют 'CET' и 'термистор'. Однако, 'Торговая марка' в характеристике указана как 'Cet', что отличается регистром, а 'Количество единиц продаж в транспортной упаковке' и 'Страна происхождения' отсутствуют в названии полностью.
# LLM ans:	['Количество единиц продаж в транспортной упаковке', 'Страна происхождения', 'Торговая марка']
# correct ans:	['Малые закупки', 'Страна происхождения', 'Количество единиц продаж в транспортной упаковке']
# (2, 1, 1)
# ---------------
# Тетрадь школьная Альт Военный паттерн А5 24 листа в линейку (10 штук в упаковке)
# В названии товара указаны такие характеристики как 'Альт Военный паттерн А5 24 листа в линейку', '10 штук в упаковке'. Мы исключаем эти характеристики из анализа. Остальные характеристики не включены ни полностью, ни частично в названии товара.
# LLM ans:	['Белизна', 'Внутренний блок', 'Закругленные углы', 'Количество штук в упаковке', 'Материал обложки', 'Однотонная обложка', 'Отделка обложки', 'Плотность листа бумаги', 'Плотность обложки', 'Предмет', 'Размер листа', 'Торговая марка', 'Цвет бумаги', 'Цвет линовки', 'Цвет обложки']
# correct ans:	['Кол-во единиц продаж в промежуточной упаковке (кратность)', 'Страна происхождения', 'Цвет линовки', 'Малые закупки', 'Единица продажи', 'Плотность листа бумаги', 'Предмет', 'Отделка обложки', 'Количество единиц продаж в транспортной упаковке', 'Однотонная обложка', 'Материал обложки', 'Белизна', 'Внутренний блок', 'Цвет бумаги', 'Плотность обложки', 'Цвет обложки', 'Размер листа', 'Закругленные углы']
# (13, 2, 5)
# ---------------
# Тумба приставная Metal System Style Б.ТП-1 (акация лорка, 412x720x750 мм)
# В названии товара указаны: 'тумба', 'акация лорка', и размеры '412x720x750 мм'. Однако в названии отсутствуют ключи, такие как количество ящиков, материал кромки, сборка мебели и статус 'Малые закупки'
# LLM ans:	['Количество ящиков', 'Малые закупки', 'Материал кромки', 'Сборка мебели']
# correct ans:	['Страна происхождения', 'Количество ящиков', 'Малые закупки', 'Сборка мебели', 'Материал', 'Материал кромки']
# (4, 0, 2)
# ---------------
# Папка-планшет с зажимом Attache A4 пластиковая черная
# В названии товара упомянуты 'Папка-планшет', 'с зажимом', 'Attache', 'A4', 'пластиковая' и 'черная'. Следовательно, характеристики 'Тип папки планшета', 'Расположение зажима', 'Количество зажимов', 'Материал покрытия', 'Защита нижнего края папки', 'Прозрачный', 'Фактура', 'Наличие кармана на внутренней обложке папки', 'Держатель для ручки', 'Возможность крепления к стене', 'Вместимость', 'Кол-во единиц продаж в промежуточной упаковке (кратность)', 'Количество единиц продаж в транспортной упаковке', 'Страна происхождения', 'Малые закупки', 'Размер', 'Толщина материала' отсутствуют в названии.
# LLM ans:	['Вместимость', 'Возможность крепления к стене', 'Держатель для ручки', 'Защита нижнего края папки', 'Кол-во единиц продаж в промежуточной упаковке (кратность)', 'Количество единиц продаж в транспортной упаковке', 'Количество зажимов', 'Малые закупки', 'Материал покрытия', 'Наличие кармана на внутренней обложке папки', 'Прозрачный', 'Размер', 'Расположение зажима', 'Страна происхождения', 'Тип папки планшета', 'Толщина материала', 'Фактура']
# correct ans:	['Прозрачный', 'Кол-во единиц продаж в промежуточной упаковке (кратность)', 'Страна происхождения', 'Наличие кармана на внутренней обложке папки', 'Расположение зажима', 'Фактура', 'Размер', 'Малые закупки', 'Вместимость', 'Толщина материала', 'Защита нижнего края папки', 'Возможность крепления к стене', 'Тип папки планшета', 'Материал покрытия', 'Количество единиц продаж в транспортной упаковке', 'Держатель для ручки', 'Количество зажимов']
# (17, 0, 0)
# ---------------
# Папка-конверт на молнии Attache А5 бесцветная 230 мкм (2 штуки в упаковке)
# В названии присутствуют 'папка-конверт', 'на молнии', 'А5', 'бесцветная', '230 мкм', и '2 штуки в упаковке'. Определенные ключи, такие как 'Торговая марка', 'Тип застежки', 'Формат папки', 'Цвет', 'Толщина', и 'Количество штук в упаковке', можно найти в названии. Однако, такие ключи, как 'Материал', 'Вместимость', 'Формат папки ориентирован', 'Прозрачный', 'Цвет молнии', 'Фактура', 'Количество отделений', и 'Размер', не полностью или не частично указаны в названии.
# LLM ans:	['Вместимость', 'Количество отделений', 'Материал', 'Прозрачный', 'Размер', 'Фактура', 'Формат папки ориентирован', 'Цвет молнии']
# correct ans:	['Прозрачный', 'Кол-во единиц продаж в промежуточной упаковке (кратность)', 'Количество отделений', 'Страна происхождения', 'Фактура', 'Размер', 'Цвет молнии', 'Малые закупки', 'Вместимость', 'Формат папки ориентирован', 'С расширением', 'Количество единиц продаж в транспортной упаковке', 'Материал']
# (8, 0, 5)
# ---------------
# Уровень пузырьковый Matrix 3 глазка 1200 мм усиленный магнитный (34712)
# В названии товара указаны следующие характеристики: Торговая марка (Matrix), Тип (уровень), Количество глазков (3), Длина (1200 мм), Наличие магнита (усиленный магнитный). Отсутствующие характеристики не были указаны прямо или непрямо в названии.
# LLM ans:	['Вес', 'Материал', 'Наличие поверки', 'Страна происхождения']
# correct ans:	['Страна происхождения', 'Наличие поверки', 'Малые закупки', 'Вес', 'Приказ 804. Код раздела', 'Количество единиц продаж в транспортной упаковке', 'Материал']
# (4, 0, 3)
# ---------------
# Пуф Куба складной с ящиком для хранения черный (искусственная кожа, 370x370x400 мм)
# В названии указаны следующие характеристики: 'Пуф Куба', 'складной с ящиком для хранения', 'черный', 'искусственная кожа' и размеры '370x370x400 мм'. Характеристики 'Торговая марка', 'Форма', 'Материал опор (ножки)', 'Сборка мебели', 'Гарантийный срок', 'Страна происхождения', 'Малые закупки' и 'Высота опор' полностью или частично не представлены в названии товара.
# LLM ans:	['Высота опор', 'Гарантийный срок', 'Коллекция', 'Малые закупки', 'Материал опор (ножки)', 'Сборка мебели', 'Страна происхождения']
# correct ans:	['Страна происхождения', 'Гарантийный срок', 'Высота опор', 'Малые закупки', 'Сборка мебели', 'Коллекция', 'Материал опор (ножки)']
# (7, 0, 0)
# ---------------
# Набор гелевых ручек Attache Pastel 8 цветов (толщина линии 0.5 мм)
# В названии товара упоминаются 'набор гелевых ручек', 'Attache', 'Pastel', '8 цветов', и 'толщина линии 0.5 мм'. Таким образом, 'Торговая марка', 'Цвет чернил', 'Цвет корпуса', и 'Толщина линии письма' частично или полностью присутствуют в названии. Остальные характеристики, которые не упомянуты, должны быть включены в список.
# LLM ans:	['Возможность смены стержня', 'Диаметр шарика', 'Длина стержня', 'Клип', 'Кол-во единиц продаж в промежуточной упаковке (кратность)', 'Кол-во штук в единице продажи', 'Количество единиц продаж в транспортной упаковке', 'Малые закупки', 'Материал наконечника', 'Наличие резиновой манжетки', 'Подходит под персонализацию', 'Покрытие soft touch', 'Размер', 'Рисунок на корпусе', 'Страна происхождения', 'Тип механизма', 'Тип упаковки', 'Форма корпуса', 'Форма наконечника']
# correct ans:	['Возможность смены стержня', 'Масляная', 'Страна происхождения', 'Размер', 'Покрытие soft touch', 'Кол-во единиц продаж в промежуточной упаковке (кратность)', 'Автоматическая', 'Наличие резиновой манжетки', 'Малые закупки', 'Подходит под персонализацию', 'Клип', 'Материал наконечника', 'Диаметр шарика', 'Рисунок на корпусе', 'Материал корпуса', 'Форма наконечника', 'Цвет корпуса', 'Длина стержня', 'Количество единиц продаж в транспортной упаковке', 'Форма корпуса', 'Тип упаковки', 'Тип механизма']
# (18, 1, 4)
# ---------------
# Подставка-органайзер для канцелярских мелочей Attache Maxi Desk 10 отделений черная вращающаяся
# В названии указаны торговая марка (Attache), тип товара (подставка-органайзер), количество отделений (10), цвет (черная) и наличие вращающейся функции (вращающаяся). Однако, в названии не упоминаются материал и точное название торговой марки с полной серийностью (Attache Maxi Desk).
# LLM ans:	['Материал', 'Торговая марка']
# correct ans:	['Прозрачный', 'Кол-во единиц продаж в промежуточной упаковке (кратность)', 'Количество штук в упаковке', 'Страна происхождения', 'Размер', 'Малые закупки', 'Количество единиц продаж в транспортной упаковке', 'Материал']
# (1, 1, 7)
# ---------------
# Вал CET CET7805
# В названии товара указаны «CET» и «вал», но нет информации о торговой марке, малых закупках, стране происхождения и количестве единиц продаж в транспортной упаковке.
# LLM ans:	['Количество единиц продаж в транспортной упаковке', 'Малые закупки', 'Страна происхождения', 'Торговая марка']
# correct ans:	['Малые закупки', 'Страна происхождения', 'Количество единиц продаж в транспортной упаковке']
# (3, 1, 0)
# ---------------
# Ламинатор Bulros FGK330iD формат А3 (LP-D-FGK-33iD-___-PsH-A3)
# В названии товара указаны 'Bulros', 'формат А3' и 'FGK330iD', что соответствует 'Торговая марка' и 'Максимальный формат ламинирования'. Давление валков и другие специфические характеристики не упомянуты в названии.
# LLM ans:	['Вентилятор охлаждения', 'Вес', 'Вид', 'Время нагрева', 'Гарантийный срок', 'Диапазон пленок', 'Длина шнура', 'Индикация', 'Количество валов', 'Количество единиц продаж в транспортной упаковке', 'Комплектация', 'Ламинирование фото', 'Максимальная толщина пленки', 'Малые закупки', 'Материал корпуса', 'Мощность', 'Назначение', 'Разжим валов', 'Размер', 'Реверс', 'Регулировка скорости', 'Регулировка температуры нагрева', 'Скорость ламинирования', 'Страна происхождения', 'Тип нагревательного элемента', 'Холодное ламинирование']
# correct ans:	['Страна происхождения', 'Размер', 'Количество валов', 'Вид', 'Вентилятор охлаждения', 'Вес', 'Количество единиц продаж в транспортной упаковке', 'Длина шнура', 'Максимальная толщина пленки', 'Диапазон пленок', 'Скорость ламинирования', 'Назначение', 'Разжим валов', 'Гарантийный срок', 'Регулировка температуры нагрева', 'Малые закупки', 'Холодное ламинирование', 'Комплектация', 'Мощность', 'Регулировка скорости', 'Индикация', 'Время нагрева', 'Тип нагревательного элемента', 'Реверс', 'Ламинирование фото', 'Материал корпуса']
# (26, 0, 0)
# ---------------
# Ручка гелевая неавтоматическая Pensan Glitter Gel золотистая (толщина линии 0.75 мм)
# В названии товара упомянуты: 'Ручка гелевая неавтоматическая', 'Pensan', 'Glitter Gel', 'золотистая' и 'толщина линии 0.75 мм'. Однако, характеристики 'Цвет чернил', 'Возможность смены стержня', 'Форма наконечника', 'Материал наконечника', 'Длина стержня', 'Материал корпуса', 'Наличие резиновой манжетки', 'Цвет корпуса', 'Кол-во штук в единице продажи', 'Тип упаковки', 'Страна происхождения' и 'Диаметр шарика' не соответствуют указанным частям названия или отсутствуют в нём полностью.
# LLM ans:	['Возможность смены стержня', 'Диаметр шарика', 'Длина стержня', 'Клип', 'Кол-во штук в единице продажи', 'Материал наконечника', 'Наличие резиновой манжетки', 'Подходит под персонализацию', 'Покрытие soft touch', 'Размер', 'Рисунок на корпусе', 'Страна происхождения', 'Тип механизма', 'Тип упаковки', 'Форма корпуса', 'Цвет корпуса']
# correct ans:	['Возможность смены стержня', 'Масляная', 'Страна происхождения', 'Размер', 'Единица продажи', 'Покрытие soft touch', 'Кол-во единиц продаж в промежуточной упаковке (кратность)', 'Наличие резиновой манжетки', 'Малые закупки', 'Подходит под персонализацию', 'Клип', 'Материал наконечника', 'Диаметр шарика', 'Рисунок на корпусе', 'Материал корпуса', 'Форма наконечника', 'Цвет корпуса', 'Длина стержня', 'Кол-во штук в единице продажи', 'Количество единиц продаж в транспортной упаковке', 'Форма корпуса', 'Тип упаковки', 'Тип механизма']
# (16, 0, 7)
# ---------------
# Ламинатор Office Kit L2325 формат A4
# В названии товара 'Ламинатор Office Kit L2325 формат A4' указаны только 'Торговая марка', 'Модель' и 'Максимальный формат ламинирования'. Таким образом, все остальные характеристики, которые не включены в название, должны быть добавлены в список.
# LLM ans:	['Вентилятор охлаждения', 'Вес', 'Вид', 'Время нагрева', 'Гарантийный срок', 'Диапазон пленок', 'Длина шнура', 'Индикация', 'Количество валов', 'Комплектация', 'Ламинирование фото', 'Максимальная толщина пленки', 'Малые закупки', 'Материал корпуса', 'Мощность', 'Назначение', 'Разжим валов', 'Размер', 'Реверс', 'Регулировка скорости', 'Регулировка температуры нагрева', 'Скорость ламинирования', 'Страна происхождения', 'Тип нагревательного элемента', 'Холодное ламинирование']
# correct ans:	['Страна происхождения', 'Размер', 'Количество валов', 'Вид', 'Вентилятор охлаждения', 'Вес', 'Количество единиц продаж в транспортной упаковке', 'Длина шнура', 'Максимальная толщина пленки', 'Диапазон пленок', 'Скорость ламинирования', 'Назначение', 'Разжим валов', 'Гарантийный срок', 'Регулировка температуры нагрева', 'Малые закупки', 'Холодное ламинирование', 'Комплектация', 'Мощность', 'Регулировка скорости', 'Индикация', 'Время нагрева', 'Тип нагревательного элемента', 'Реверс', 'Ламинирование фото', 'Материал корпуса']
# (25, 0, 1)
# ---------------
# Уровень пузырьковый Вихрь 3 глазка 1000 мм усиленный фрезерованный (73/11/4/12)
# В названии товара присутствуют марка 'Вихрь', '3 глазка', длина '1000 мм', и определенные характеристики такие как 'усиленный' и 'фрезерованный'. Однако характеристики 'Товарная марка', 'Материал', 'Наличие магнита', 'Наличие поверки', 'Длина', которые представлены в детализированном виде в характеристиках, не совсем соответствуют части названия. 'Малые закупки' и 'Приказ 804. Код раздела' точно не упоминаются в названии.
# LLM ans:	['Вес', 'Малые закупки', 'Материал', 'Наличие магнита', 'Наличие поверки', 'Приказ 804. Код раздела', 'Страна происхождения', 'Товарная марка']
# correct ans:	['Страна происхождения', 'Наличие поверки', 'Малые закупки', 'Наличие магнита', 'Вес', 'Приказ 804. Код раздела', 'Количество единиц продаж в транспортной упаковке', 'Материал']
# (7, 1, 1)
# ---------------
# Элемент рабочей станции Onix-П O.MP-1.NRS-2.8 (дуб аризона/антрацит, 1180х800х750 мм)
# Название товара содержит следующие характеристики: 'элемент рабочей станции', 'Onix-П', 'дуб аризона/антрацит', и размеры '1180х800х750 мм'. Отсутствующими являются 'Коллекция', 'Материал', 'Материал кромки', 'Сборка мебели', 'Малые закупки', так как они не представлены в названии товара полностью или частично.
# LLM ans:	['Коллекция', 'Малые закупки', 'Материал', 'Материал кромки', 'Сборка мебели']
# correct ans:	['Страна происхождения', 'Количество ящиков', 'Малые закупки', 'Сборка мебели', 'Материал', 'Материал кромки']
# (4, 1, 2)
# ---------------
# Экран акриловый на струбцине (белый прозрачный, 600х55х400 мм)
# В названии товара указаны размеры экрана (600х55х400 мм) и цвет (белый прозрачный), также указан тип крепления (на струбцине). Однако, в названии отсутствуют ключи характеристики, такие как 'Вид', 'Тип крепления', 'Материал', 'Толщина', 'Сборка мебели', 'Страна происхождения' и 'Малые закупки', так как они либо не упомянуты, либо не соответствуют напрямую обозначенным фрагментам.
# LLM ans:	['Вид', 'Коллекция', 'Малые закупки', 'Сборка мебели', 'Страна происхождения', 'Тип крепления', 'Толщина']
# correct ans:	['Толщина', 'Страна происхождения', 'Малые закупки', 'Сборка мебели', 'Коллекция', 'Тип крепления']
# (6, 1, 0)
# ---------------
# Плащ влагозащитный Poseidon WPL ПВХ на молнии синий (размер 60-62, рост 182-188)
# В названии товара содержатся следующие ключевые характеристики: 'Poseidon WPL', 'ПВХ на молнии', 'синий', 'размер 60-62', 'рост 182-188'. Однако, в названии отсутствуют 'Коллекция', 'Модель', 'Пол', 'Название ткани', 'Класс защиты', 'Элементы отражения света', 'С капюшоном', 'Вентиляционные вставки', 'Наличие карманов', 'Стандарты', 'Отрасль', 'Вес'.
# LLM ans:	['Вентиляционные вставки', 'Вес', 'Класс защиты', 'Коллекция', 'Модель', 'Название ткани', 'Наличие карманов', 'Отрасль', 'Пол', 'С капюшоном', 'Стандарты', 'Элементы отражения света']
# correct ans:	['Название ткани', 'Класс риска', 'Вес', 'Приказ 804. Код раздела', 'Материал подкладки', 'Наличие карманов', 'Демисезонного применения', 'Плотность г/кв.м', 'Элементы отражения света', 'Класс защиты', 'С капюшоном', 'Страна происхождения', 'Пол', 'Отрасль', 'Вентиляционные вставки', 'С утеплителем', 'Малые закупки', 'Стандарты', 'Количество единиц продаж в транспортной упаковке']
# (10, 2, 9)
# ---------------
# Папка-конверт на молнии Attache Selection Bloom А4 400 мкм (с ручками)
# В названии товара присутствуют упоминания о молнии, формате А4, толщине 400 мкм и наличии ручек. Отсутствуют следующие ключевые характеристики: торговая марка без слова 'Bloom', фактура, количество отделений и цвет папки.
# LLM ans:	['Количество отделений', 'Торговая марка', 'Фактура', 'Цвет']
# correct ans:	['Прозрачный', 'Кол-во единиц продаж в промежуточной упаковке (кратность)', 'Количество штук в упаковке', 'Количество отделений', 'Цвет', 'Страна происхождения', 'Фактура', 'Размер', 'Цвет молнии', 'Малые закупки', 'Вместимость', 'Формат папки ориентирован', 'С расширением', 'Количество единиц продаж в транспортной упаковке', 'Материал']
# (3, 1, 12)
# ---------------
# Шкаф для одежды металлический Cobalt ШРМ11 (серый, 300х500х1860 мм)
# В названии товара указаны марка (Cobalt), тип (шкаф для одежды), материал (металлический), цвет (серый) и размеры (300х500х1860 мм). Все остальные характеристики, не упомянутые в названии, должны быть включены в список отсутствующих.
# LLM ans:	['Вес', 'Вешалка (перекладина) для одежды', 'Вид', 'Возможность закрытия дверей отдельно друг от друга', 'Гарантийный срок', 'Количество отделений', 'Количество полок в отделении', 'Малые закупки', 'Материал дверей', 'Нагрузка на полку', 'Приказ 804. Код раздела', 'Сборка мебели', 'Тип замка']
# correct ans:	['Количество полок в отделении', 'Количество отделений', 'Гарантийный срок', 'Материал дверей', 'Малые закупки', 'Тип замка', 'Вес', 'Сборка мебели', 'Приказ 804. Код раздела', 'Вешалка (перекладина) для одежды', 'Возможность закрытия дверей отдельно друг от друга', 'Нагрузка на полку']
# (12, 1, 0)
# ---------------
# Ламинатор Гелеос ЛМ Радуга формат A4 фиолетовый
# В названии товара присутствуют торговая марка (Гелеос), формат (A4) и цвет (фиолетовый). Однако отсутствуют такие ключи, как 'Вид', 'Назначение', 'Максимальная толщина пленки', 'Диапазон пленок', 'Регулировка скорости', 'Регулировка температуры нагрева', 'Тип нагревательного элемента', 'Количество валов', 'Реверс', 'Разжим валов', 'Холодное ламинирование', 'Ламинирование фото', 'Индикация', 'Вентилятор охлаждения', 'Мощность', 'Длина шнура', 'Материал корпуса', 'Комплектация', 'Гарантийный срок', и 'Малые закупки'.
# LLM ans:	['Вентилятор охлаждения', 'Вид', 'Гарантийный срок', 'Диапазон пленок', 'Длина шнура', 'Индикация', 'Количество валов', 'Комплектация', 'Ламинирование фото', 'Максимальная толщина пленки', 'Малые закупки', 'Материал корпуса', 'Мощность', 'Назначение', 'Разжим валов', 'Реверс', 'Регулировка скорости', 'Регулировка температуры нагрева', 'Тип нагревательного элемента', 'Холодное ламинирование']
# correct ans:	['Страна происхождения', 'Размер', 'Количество валов', 'Вид', 'Вентилятор охлаждения', 'Вес', 'Количество единиц продаж в транспортной упаковке', 'Длина шнура', 'Максимальная толщина пленки', 'Диапазон пленок', 'Скорость ламинирования', 'Назначение', 'Разжим валов', 'Гарантийный срок', 'Регулировка температуры нагрева', 'Малые закупки', 'Холодное ламинирование', 'Комплектация', 'Мощность', 'Регулировка скорости', 'Индикация', 'Время нагрева', 'Тип нагревательного элемента', 'Реверс', 'Ламинирование фото', 'Материал корпуса']
# (20, 0, 6)
# ---------------
# Плащ дождевик полиэтиленовый на липучках зеленый (размер 64-68)
# В названии товара указана информация о том, что плащ дождевик изготовлен из полиэтилена, имеет застежку на липучках, зеленого цвета и размер 64-68. Однако, некоторые характеристики, такие как пол, модель, наличие капюшона, не упоминаются в названии.
# LLM ans:	['Защитные свойства', 'Коллекция', 'Материал подкладки', 'Модель', 'Наличие карманов', 'Плотность г/кв.м', 'Пол', 'Размер', 'Рост', 'С капюшоном', 'С утеплителем']
# correct ans:	['Название ткани', 'Класс защиты', 'Класс риска', 'С капюшоном', 'Страна происхождения', 'Пол', 'Вес', 'Отрасль', 'Количество единиц продаж в транспортной упаковке', 'Приказ 804. Код раздела', 'Коллекция', 'Вентиляционные вставки', 'Защитные свойства', 'С утеплителем', 'Малые закупки', 'Материал подкладки', 'Наличие карманов', 'Стандарты', 'Модель', 'Демисезонного применения', 'Рост', 'Плотность г/кв.м', 'Элементы отражения света']
# (10, 1, 13)
# ---------------
# Набор кастрюль Лысьвенские эмали Китайская Роза эмалированная сталь 3 штуки (1.5 л, 2 л, 3 л)
# В названии указаны тип продукции (набор кастрюль), материал (эмалированная сталь), количество штук (3 штуки) и объём (1.5 л, 2 л, 3 л). Однако в характеристике указано, что набор состоит из 6 предметов ('Количество предметов в наборе': '6'), и также упоминаются ключи, которые не встречаются в названии, такие как 'Цвет корпуса', 'Для индукционных плит', 'Использование в духовке', и 'Приказ 804. Код раздела'.
# LLM ans:	['Для индукционных плит', 'Использование в духовке', 'Количество предметов в наборе', 'Приказ 804. Код раздела', 'Торговая марка', 'Цвет корпуса']
# correct ans:	['Страна происхождения', 'Покрытие', 'Количество предметов в наборе', 'Состав комплекта', 'Для индукционных плит', 'Использование в духовке', 'Цвет корпуса', 'Приказ 804. Код раздела', 'Количество единиц продаж в транспортной упаковке']
# (5, 1, 4)
# ---------------
# Ламинатор Fellowes Saturn 3i формат А3 (FS-57360)
# В названии товара указаны 'Fellowes', 'Saturn 3i' как модель и 'формат А3'. Остальные характеристики, такие как 'Вид', 'Назначение', 'Максимальная толщина пленки', 'Диапазон пленок', и т.д., не представлены в названии или представлены не полностью.
# LLM ans:	['Вентилятор охлаждения', 'Вес', 'Вид', 'Время нагрева', 'Гарантийный срок', 'Диапазон пленок', 'Индикация', 'Количество валов', 'Количество единиц продаж в транспортной упаковке', 'Комплектация', 'Ламинирование фото', 'Максимальная толщина пленки', 'Малые закупки', 'Материал корпуса', 'Мощность', 'Назначение', 'Разжим валов', 'Размер', 'Реверс', 'Регулировка скорости', 'Регулировка температуры нагрева', 'Скорость ламинирования', 'Страна происхождения', 'Тип нагревательного элемента', 'Холодное ламинирование']
# correct ans:	['Страна происхождения', 'Размер', 'Количество валов', 'Вид', 'Вентилятор охлаждения', 'Вес', 'Количество единиц продаж в транспортной упаковке', 'Длина шнура', 'Максимальная толщина пленки', 'Диапазон пленок', 'Скорость ламинирования', 'Назначение', 'Разжим валов', 'Гарантийный срок', 'Регулировка температуры нагрева', 'Малые закупки', 'Холодное ламинирование', 'Комплектация', 'Мощность', 'Регулировка скорости', 'Индикация', 'Время нагрева', 'Тип нагревательного элемента', 'Реверс', 'Ламинирование фото', 'Материал корпуса']
# (25, 0, 1)
# ---------------
# Плащ влагозащитный Extra-Vision WPL ПВХ на молнии лимонный с СОП (размер 52-54, рост 170-176)
# В названии товара указаны такие ключи, как 'влагозащитный', 'Extra-Vision', 'ПВХ', 'на молнии', 'лимонный', 'размер 52-54' и 'рост 170-176'. Однако некоторые ключи характеристик, такие как 'Коллекция', 'Модель', 'Класс защиты', 'Элементы отражения света', 'С капюшоном', 'Вентиляционные вставки' и 'Наличие карманов', отсутствуют в названии либо в явном виде, либо их аббревиатуры не распознаются.
# LLM ans:	['Вентиляционные вставки', 'Класс защиты', 'Коллекция', 'Модель', 'Наличие карманов', 'С капюшоном', 'Элементы отражения света']
# correct ans:	['Название ткани', 'Класс риска', 'Вес', 'Приказ 804. Код раздела', 'Материал подкладки', 'Наличие карманов', 'Демисезонного применения', 'Плотность г/кв.м', 'Элементы отражения света', 'Класс защиты', 'С капюшоном', 'Страна происхождения', 'Пол', 'Отрасль', 'Вентиляционные вставки', 'С утеплителем', 'Малые закупки', 'Стандарты', 'Количество единиц продаж в транспортной упаковке']
# (5, 2, 14)
# ---------------
# Кулер для процессора DeepCool CK-11509
# В названии товара указаны только 'Кулер для процессора' и 'DeepCool CK-11509'. Такие ключи как 'Модель' (CK-11509) частично представлены, однако не все полные названия характеристик видны в названии, например, совместимость с Socket, уровень мощности, материалы, способы подключения и прочие технические характеристики.
# LLM ans:	['Вес', 'Высота', 'Гарантийный срок', 'Глубина', 'Для геймеров', 'Количество вентиляторов в комплекте', 'Максимальная рассеиваемая мощность', 'Максимальное количество устанавливаемых вентиляторов', 'Максимальный уровень шума', 'Материал основания', 'Материал радиатора', 'Подсветка', 'Размер вентилятора', 'Разъем вентилятора', 'Совместимый Socket', 'Термопаста в комплекте', 'Торговая марка', 'Ширина']
# correct ans:	['Ширина', 'Высота', 'Страна происхождения', 'Максимальная рассеиваемая мощность', 'Глубина', 'Материал радиатора', 'Максимальная скорость вращения', 'Минимальная скорость вращения', 'Размер вентилятора', 'Вес', 'Количество вентиляторов в комплекте', 'Термопаста в комплекте', 'Максимальное количество устанавливаемых вентиляторов', 'Максимальный воздушный поток', 'Гарантийный срок', 'Подсветка', 'Малые закупки', 'Разъем вентилятора', 'Максимальный уровень шума', 'Количество единиц продаж в транспортной упаковке', 'Материал основания', 'Совместимый Socket', 'Для геймеров']
# (17, 1, 6)
# ---------------
# Карандаши цветные Maped Color'Peps Star 24 карандаша 24 цвета трёхгранные
# В названии указаны 'Maped', 'цветные', '24 карандаша', '24 цвета', и 'трёхгранные'. Следовательно, ключи 'Торговая марка', 'Количество цветов', 'Кол-во штук в единице продажи', и 'Форма корпуса' присутствуют. Отсутствующими являются те характеристики, которые не упомянуты полностью или частично в названии.
# LLM ans:	['Аксессуары в комплекте', 'Диаметр грифеля', 'Диаметр корпуса карандаша', 'Длина корпуса', 'Кол-во единиц продаж в промежуточной упаковке (кратность)', 'Количество единиц продаж в транспортной упаковке', 'Малые закупки', 'Материал корпуса', 'Особенности', 'Размер упаковки (ШхГхВ)', 'Страна происхождения', 'Тип стержня', 'Тип упаковки', 'Цвет грифеля']
# correct ans:	['Диаметр корпуса карандаша', 'Кол-во единиц продаж в промежуточной упаковке (кратность)', 'Тип стержня', 'Страна происхождения', 'Особенности', 'Малые закупки', 'Единица продажи', 'Аксессуары в комплекте', 'Размер упаковки (ШхГхВ)', 'Цвет грифеля', 'Количество единиц продаж в транспортной упаковке', 'Длина корпуса', 'Тип упаковки', 'Материал корпуса', 'Диаметр грифеля']
# (14, 0, 1)
# ---------------
# Акустическая система L Audio FP-15A
# В названии товара 'Акустическая система L Audio FP-15A' упоминаются только 'L Audio' и 'FP-15A'. Не все ключи из характеристик найдены в названии, например, не указаны тип установки, материал корпуса, цвет, и некоторые функциональные характеристики, такие как номинальная мощность и диапазон воспроизводимых частот.
# LLM ans:	['Гарантийный срок', 'Диаметр СЧ динамика', 'Диапазон воспроизводимых частот', 'Количество полос', 'Комплектация', 'Максимальная мощность', 'Материал корпуса', 'Номинальная мощность', 'Размер', 'Сопротивление', 'Страна происхождения', 'Тип установки', 'Торговая марка', 'Цвет', 'Чувствительность']
# correct ans:	['Диапазон воспроизводимых частот', 'Страна происхождения', 'Цвет', 'Размер', 'Номинальная мощность', 'Мониторные колонки', 'Количество полос', 'Тип установки', 'Чувствительность', 'Тип акустической системы', 'Максимальная мощность', 'Гарантийный срок', 'Диаметр СЧ динамика', 'Комплектация', 'Сопротивление', 'Количество единиц продаж в транспортной упаковке', 'Материал корпуса']
# (14, 1, 3)
# ---------------
# Акустическая система Behringer Eurolive B108D
# В названии товара есть упоминание 'Behringer Eurolive B108D' и 'акустическая система', но отсутствуют упоминания о 'Тип установки', 'Номинальная мощность', 'Материал корпуса', 'Цвет', 'Сопротивление', 'Диапазон воспроизводимых частот', 'Диаметр ВЧ динамика', 'Диаметр НЧ динамика', 'Мониторные колонки', 'Количество полос', и 'Размер', которые не включены полностью или частично.
# LLM ans:	['Диаметр ВЧ динамика', 'Диаметр НЧ динамика', 'Диапазон воспроизводимых частот', 'Количество полос', 'Материал корпуса', 'Мониторные колонки', 'Номинальная мощность', 'Размер', 'Сопротивление', 'Тип установки', 'Цвет']
# correct ans:	['Диапазон воспроизводимых частот', 'Страна происхождения', 'Цвет', 'Размер', 'Номинальная мощность', 'Мониторные колонки', 'Количество полос', 'Тип установки', 'Чувствительность', 'Тип акустической системы', 'Максимальная мощность', 'Гарантийный срок', 'Комплектация', 'Диаметр НЧ динамика', 'Сопротивление', 'Диаметр ВЧ динамика', 'Количество единиц продаж в транспортной упаковке', 'Материал корпуса']
# (11, 0, 7)
# ---------------
# Экран акриловый на струбцине (белый прозрачный, 900х55х400 мм)
# В названии указаны размеры, цвет и тип крепления экрана, но не перечислены коллекция, тип экрана, способ и материал крепления, толщина, сборка мебели, страна происхождения и информация о малых закупках.
# LLM ans:	['Вид', 'Коллекция', 'Малые закупки', 'Сборка мебели', 'Страна происхождения', 'Толщина']
# correct ans:	['Толщина', 'Страна происхождения', 'Малые закупки', 'Сборка мебели', 'Коллекция', 'Тип крепления']
# (5, 1, 1)
# ---------------
# Кулер для процессора Aerocool Verkho Plus
# В названии товара указаны только торговая марка 'Aerocool' и модель 'Verkho Plus'. Другие характеристики, такие как Совместимый Socket, Материал основания, Материал радиатора и т. д., отсутствуют в названии.
# LLM ans:	['Высота', 'Гарантийный срок', 'Глубина', 'Количество вентиляторов в комплекте', 'Максимальная рассеиваемая мощность', 'Максимальная скорость вращения', 'Максимальное количество устанавливаемых вентиляторов', 'Максимальный воздушный поток', 'Максимальный уровень шума', 'Материал основания', 'Материал радиатора', 'Минимальная скорость вращения', 'Размер вентилятора', 'Разъем вентилятора', 'Совместимый Socket', 'Страна происхождения', 'Термопаста в комплекте', 'Ширина']
# correct ans:	['Ширина', 'Высота', 'Страна происхождения', 'Максимальная рассеиваемая мощность', 'Глубина', 'Материал радиатора', 'Максимальная скорость вращения', 'Минимальная скорость вращения', 'Размер вентилятора', 'Количество вентиляторов в комплекте', 'Термопаста в комплекте', 'Максимальное количество устанавливаемых вентиляторов', 'Максимальный воздушный поток', 'Гарантийный срок', 'Подсветка', 'Малые закупки', 'Разъем вентилятора', 'Максимальный уровень шума', 'Количество единиц продаж в транспортной упаковке', 'Материал основания', 'Совместимый Socket', 'Для геймеров']
# (18, 0, 4)
# ---------------
# Экран акриловый на струбцине (белый прозрачный, 1000х55х400 мм)
# Название товара содержит информацию о типе экрана (акриловый), наличии струбцины, цвете (белый прозрачный) и размерах (1000х55х400 мм). Однако оно не включает информацию о типе крепления, способе крепления, сборке мебели, стране происхождения, малых закупках и толщине.
# LLM ans:	['Вид', 'Малые закупки', 'Сборка мебели', 'Страна происхождения', 'Тип крепления', 'Толщина']
# correct ans:	['Толщина', 'Страна происхождения', 'Малые закупки', 'Сборка мебели', 'Коллекция', 'Тип крепления']
# (5, 1, 1)
# ---------------
# Экран акриловый на струбцине (белый глухой, 1200х55х400 мм)
# Название товара определяет материал (акриловый), тип крепления (на струбцине), цвет (белый) и размер (1200х55х400 мм), поэтому остальные ключи, не упоминаемые в названии, должны быть в результате. Ключи 'Способ крепления', 'Сборка мебели', 'Страна происхождения' и 'Малые закупки' не отражены в названии товара, так как они являются деталями, не развернутыми в тексте названия. Стандарт 'вид' указан в названии через описание ('экран акриловый'), а 'тип крепления' ('к столу') и 'твердость грифеля' отсутствуют.
# LLM ans:	['Вид', 'Коллекция', 'Малые закупки', 'Сборка мебели', 'Страна происхождения', 'Тип крепления', 'Толщина']
# correct ans:	['Толщина', 'Страна происхождения', 'Малые закупки', 'Сборка мебели', 'Коллекция', 'Тип крепления']
# (6, 1, 0)
# ---------------
# Пластик ABS+ для 3D-принтера ESUN серый матовый 1.75 мм 1 кг
# В названии товара указаны торговая марка (ESUN), полное название материала (ABS+), диаметр нити (1.75 мм), вес (1 кг) и цвет (серый). Однако не указаны следующие характеристики: длина намотки, вес в упаковке, температура печати, температура платформы и малые закупки, так как они не упоминаются или не частично не релевантны названию.
# LLM ans:	['Вес в упаковке', 'Длина намотки', 'Малые закупки', 'Температура печати', 'Температура платформы']
# correct ans:	['Температура печати', 'Страна происхождения', 'Малые закупки', 'Длина намотки', 'Вес в упаковке', 'Количество единиц продаж в транспортной упаковке', 'Температура платформы']
# (5, 0, 2)
# ---------------
# Уровень пузырьковый Вихрь 3 глазка 1200 мм фрезерованный (73/11/4/5)
# В названии товара указаны ключи 'уровень пузырьковый', '3 глазка', '1200 мм', и 'фрезерованный'. Поэтому характеристики 'Торговая марка', 'Материал', 'Количество глазков', и 'Длина' частично или полностью представлены в названии. Остальные характеристики, такие как 'Наличие магнита', 'Наличие поверки', 'Страна происхождения', 'Малые закупки', 'Приказ 804. Код раздела' и 'Вес', отсутствуют в названии.
# LLM ans:	['Вес', 'Малые закупки', 'Материал', 'Наличие магнита', 'Наличие поверки', 'Приказ 804. Код раздела', 'Страна происхождения', 'Торговая марка']
# correct ans:	['Страна происхождения', 'Наличие поверки', 'Малые закупки', 'Наличие магнита', 'Вес', 'Приказ 804. Код раздела', 'Количество единиц продаж в транспортной упаковке', 'Материал']
# (7, 1, 1)
# ---------------
# Папка-планшет с зажимом и крышкой Attache A4 красная
# Название товара содержит информацию о типе папки (с зажимом и крышкой), формате (A4), и цвете (красная). Следовательно, характеристики 'Торговая марка', 'Расположение зажима', 'Количество зажимов', 'Материал папки', 'Материал покрытия', 'Защита нижнего края папки', 'Фактура', 'Вместимость', 'Возможность крепления к стене', 'Размер', и 'Толщина материала' отсутствуют в названии.
# LLM ans:	['Вместимость', 'Возможность крепления к стене', 'Защита нижнего края папки', 'Количество зажимов', 'Материал папки', 'Материал покрытия', 'Размер', 'Расположение зажима', 'Толщина материала', 'Торговая марка', 'Фактура']
# correct ans:	['Прозрачный', 'Кол-во единиц продаж в промежуточной упаковке (кратность)', 'Страна происхождения', 'Наличие кармана на внутренней обложке папки', 'Расположение зажима', 'Фактура', 'Размер', 'Малые закупки', 'Вместимость', 'Материал папки', 'Толщина материала', 'Защита нижнего края папки', 'Возможность крепления к стене', 'Материал покрытия', 'Количество единиц продаж в транспортной упаковке', 'Держатель для ручки', 'Количество зажимов']
# (10, 1, 7)
# ---------------
# Экран акриловый на струбцине (белый прозрачный, 1400х55х400 мм)
# В названии товара указаны размеры экрана и факт использования струбцины для крепления, но не упоминается его вид, возможность сборки мебели, страна происхождения, условия малых закупок, и толщина. Также материал акрил и способ его крепления с указанием 'на струбцине' представлены в названии, но 'Способ крепления: струбцина' более точно указывает, как крепится экран, и может считаться уникальной характеристикой.
# LLM ans:	['Вид', 'Малые закупки', 'Сборка мебели', 'Страна происхождения', 'Толщина']
# correct ans:	['Толщина', 'Страна происхождения', 'Малые закупки', 'Сборка мебели', 'Коллекция', 'Тип крепления']
# (4, 1, 2)
# ---------------
# Папка-планшет с зажимом и крышкой Attache A4 синяя
# В названии указаны: Торговая марка 'Attache', 'с зажимом', 'с крышкой', формат 'А4' и цвет 'синяя'. Остальные характеристики должны соответствовать им или явно отсутствовать в названии.
# LLM ans:	['Вместимость', 'Возможность крепления к стене', 'Держатель для ручки', 'Защита нижнего края папки', 'Кол-во единиц продаж в промежуточной упаковке (кратность)', 'Количество единиц продаж в транспортной упаковке', 'Количество зажимов', 'Малые закупки', 'Материал папки', 'Материал покрытия', 'Наличие кармана на внутренней обложке папки', 'Прозрачный', 'Размер', 'Расположение зажима', 'Страна происхождения', 'Толщина материала', 'Фактура']
# correct ans:	['Прозрачный', 'Кол-во единиц продаж в промежуточной упаковке (кратность)', 'Страна происхождения', 'Наличие кармана на внутренней обложке папки', 'Расположение зажима', 'Фактура', 'Размер', 'Малые закупки', 'Вместимость', 'Материал папки', 'Толщина материала', 'Защита нижнего края папки', 'Возможность крепления к стене', 'Материал покрытия', 'Количество единиц продаж в транспортной упаковке', 'Держатель для ручки', 'Количество зажимов']
# (17, 0, 0)
# ---------------
# Куртка-ветровка демисезонная Русский дождевик Лидер черная с капюшоном (размер 52-54, рост 182-188)
# В названии присутствуют 'Куртка-ветровка', 'демисезонная', 'черная с капюшоном', 'размер 52-54', 'рост 182-188'. Из характеристик отсутствуют 'Торговая марка', 'Модель', 'Состав ткани', 'Название ткани', 'Пропитка'.
# LLM ans:	['Вентиляционные отверстия', 'Застежка', 'Класс защиты', 'Класс риска', 'Малые закупки', 'Модель', 'Название ткани', 'Пол', 'Пропитка', 'С утеплителем', 'Состав ткани', 'Тип куртки', 'Торговая марка', 'Элементы отражения света']
# correct ans:	['Название ткани', 'Класс риска', 'Тип куртки', 'Честный знак', 'Материал подкладки', 'Элементы отражения света', 'Состав ткани', 'Класс защиты', 'Страна происхождения', 'Пол', 'Плотность материала', 'Вентиляционные отверстия', 'Пропитка', 'Защитные свойства', 'С утеплителем', 'Малые закупки', 'Застежка', 'Стандарты', 'Количество единиц продаж в транспортной упаковке']
# (12, 2, 7)
# ---------------
# Набор кастрюль Лысьвенские эмали Urban flower эмалированная сталь 3 штуки (1.45 л, 2.9 л, 4.3 л)
# В названии указаны 'Лысьвенские эмали Urban flower', 'эмалированная сталь', '3 штуки' и объемы '1.45 л, 2.9 л, 4.3 л'. В описание вошли ключи 'Торговая марка', 'Материал', и 'Объем посуды'. Однако, количество предметов в наборе указано как '3 штуки' в названии, но характеристики говорят об '6' предметах, что явно является несоответствием. Также в название не вошли 'Покрытие', 'Цвет корпуса', 'Для индукционных плит', 'Состав комплекта', 'Использование в духовке', 'Количество единиц продаж в транспортной упаковке' и 'Страна происхождения'.
# LLM ans:	['Для индукционных плит', 'Использование в духовке', 'Количество предметов в наборе', 'Покрытие', 'Приказ 804. Код раздела', 'Состав комплекта', 'Страна происхождения', 'Цвет корпуса']
# correct ans:	['Страна происхождения', 'Покрытие', 'Количество предметов в наборе', 'Использование в духовке', 'Для индукционных плит', 'Цвет корпуса', 'Приказ 804. Код раздела', 'Количество единиц продаж в транспортной упаковке']
# (7, 1, 1)
# ---------------
# Пластик PLA+ для 3D-принтера ESUN синий матовый 1.75 мм 1 кг
# В названии товара представлены ключи: 'торговая марка' (ESUN), 'материал' (PLA+), 'диаметр нити' (1.75 мм), 'цвет' (синий) и 'объем/вес' (1 кг). Характеристики 'длина намотки', 'вес в упаковке', 'температура печати', 'температура платформы', 'страна происхождения', 'количество единиц продаж в транспортной упаковке' и 'малые закупки' не представлены в названии товара.
# LLM ans:	['Вес в упаковке', 'Вид расходных материалов', 'Длина намотки', 'Количество единиц продаж в транспортной упаковке', 'Малые закупки', 'Страна происхождения', 'Температура печати', 'Температура платформы']
# correct ans:	['Температура печати', 'Страна происхождения', 'Малые закупки', 'Длина намотки', 'Вес в упаковке', 'Количество единиц продаж в транспортной упаковке', 'Температура платформы']
# (7, 1, 0)
# ---------------
# Набор кастрюль Appetite Париж 1KB191M эмалированная сталь 3 штуки (2 л, 3 л, 5.5 л)
# В названии товара указаны торговая марка 'Appetite', 'эмалированная сталь', объёмы кастрюль '2 л, 3 л, 5.5 л' и количество '3 штуки'. Ключи 'Цвет корпуса', 'Количество предметов в наборе', 'Для индукционных плит', 'Состав комплекта', 'Использование в духовке' и 'Приказ 804. Код раздела' не представлены в названии, и хотя 'Материал' частично присутствует, 'Покрытие' не представлено, так как это одно и то же свойство ('эмалированная сталь' уже указывает на эмалированное покрытие). Также 'Объем посуды' представлен в названии через объёмы отдельных кастрюль.
# LLM ans:	['Для индукционных плит', 'Использование в духовке', 'Количество предметов в наборе', 'Приказ 804. Код раздела', 'Состав комплекта', 'Цвет корпуса']
# correct ans:	['Страна происхождения', 'Количество предметов в наборе', 'Использование в духовке', 'Для индукционных плит', 'Цвет корпуса', 'Приказ 804. Код раздела', 'Количество единиц продаж в транспортной упаковке']
# (5, 1, 2)
# ---------------
# Подставка-органайзер для канцелярских принадлежностей Deli 6 отделений 25.9x10.3x15 см (E9110)
# В названии товара присутствуют 'Deli', 'подставка-органайзер', '6 отделений', '25.9x10.3x15 см' и 'E9110'. Однако в характеристиках 'Количество отделений' указано как '7', а размеры представлены как '259х103х150 мм', что соответствует '25.9x10.3x15 см'. Ключи 'Торговая марка', 'Материал', 'Цвет', 'Вращающийся', 'Прозрачный', 'Количество штук в упаковке' и 'Страна происхождения' полностью или частично не указаны в названии, так что они входят в список. Ключ 'Размер' соответствует названию, но в другом формате, поэтому не включён. Количество во 'вращающемся' и 'прозрачном' явно отсутствуют в названии.
# LLM ans:	['Вращающийся', 'Количество отделений', 'Количество штук в упаковке', 'Материал', 'Прозрачный', 'Страна происхождения', 'Торговая марка', 'Цвет']
# correct ans:	['Прозрачный', 'Кол-во единиц продаж в промежуточной упаковке (кратность)', 'Количество штук в упаковке', 'Страна происхождения', 'Цвет', 'Вращающийся', 'Малые закупки', 'Количество единиц продаж в транспортной упаковке', 'Материал']
# (6, 2, 3)
# ---------------
# Доска магнитно-маркерная 100x180 см лаковое покрытие Attache Classic
# В названии товара упоминается 'магнитно-маркерная', '100x180 см', 'лаковое покрытие' и 'Attache Classic'. Однако, из характеристик отсутствуют 'Торговая марка', 'Серия досок', 'Количество рабочих поверхностей', 'Крепление на стену', 'Размер рабочей поверхности', 'Цвет доски', 'Наличие полочки', 'Гарантийный срок покрытия', 'Общая гарантия' ('границей для гарантии считается 1 год'), и 'Страна происхождения' не представлены непосредственно или полностью в названии. Также, 'Поворотный механизм' и 'Наличие выдвижной перекладины' упоминаются как 'Нет', что не обязательно должно быть в названии.
# LLM ans:	['Гарантийный срок', 'Гарантийный срок покрытия', 'Количество рабочих поверхностей', 'Крепление на стену', 'Наличие полочки', 'Размер рабочей поверхности', 'Серия досок', 'Торговая марка', 'Цвет доски']
# correct ans:	['Крепление на стену', 'Страна происхождения', 'Расположение', 'Поворотный механизм', 'Материал рамы', 'Вес', 'Вид доски', 'Приказ 804. Код раздела', 'Количество рабочих поверхностей', 'Антибликовое покрытие', 'Наличие полочки', 'Особенности', 'Гарантийный срок', 'Малые закупки', 'Наличие выдвижной перекладины', 'Гарантийный срок покрытия', 'Вид линовки', 'Количество единиц продаж в транспортной упаковке', 'Размер рабочей поверхности', 'Цвет доски']
# (7, 2, 13)
# ---------------
# Тетрадь школьная зеленая Гознак А5 24 листа в клетку
# В названии товара указаны формат листов (A5), количество листов (24 листа), цвет обложки (зеленая) и вид линовки (в клетку). Однако в характеристиках присутствуют дополнительные ключи, которые не упомянуты в названии, такие как Торговая марка, Плотность листа бумаги, Цвет бумаги, Размер листа, Белизна, Цвет линовки, Внутренний блок, Отделка обложки, Однотонная обложка, Материал обложки, Предмет, и другие.
# LLM ans:	['Белизна', 'Внутренний блок', 'Кол-во единиц продаж в промежуточной упаковке (кратность)', 'Количество единиц продаж в транспортной упаковке', 'Количество штук в упаковке', 'Материал обложки', 'Однотонная обложка', 'Отделка обложки', 'Плотность листа бумаги', 'Предмет', 'Размер листа', 'Страна происхождения', 'Торговая марка', 'Цвет бумаги', 'Цвет линовки']
# correct ans:	['Кол-во единиц продаж в промежуточной упаковке (кратность)', 'Количество штук в упаковке', 'Страна происхождения', 'Цвет линовки', 'Единица продажи', 'Плотность листа бумаги', 'Предмет', 'Отделка обложки', 'Количество единиц продаж в транспортной упаковке', 'Однотонная обложка', 'Материал обложки', 'Белизна', 'Цвет бумаги', 'Внутренний блок', 'Размер листа']
# (14, 1, 1)
# ---------------
# Модуль сушильный для обуви СОЮЗ-10 (без подставки)
# Название товара включает информацию о типе модуля (сушильный для обуви), его модели (СОЮЗ-10) и указывает отсутствие подставки. Однако в характеристике существуют ключи, которые не упоминаются или не отражены в названии товара, такие как торговая марка, цвет, уровень шума, прочие технические и физические характеристики.
# ...
# LLM ans:	['Высота опор', 'Гарантийный срок', 'Коллекция', 'Малые закупки', 'Материал опор (ножки)', 'Сборка мебели', 'Страна происхождения', 'Форма']
# correct ans:	['Страна происхождения', 'Особенности', 'Гарантийный срок', 'Высота опор', 'Малые закупки', 'Форма', 'Сборка мебели', 'Коллекция', 'Материал опор (ножки)']
# (8, 0, 1)
# ---------------
# Панель стеновая Corsica AM 2260 (дуб бунратти, 2202х6х600 мм)
# В названии товара указаны такие характеристики как 'Corsica', 'дуб бунратти', '2202х6х600 мм', которые соответствуют 'Коллекция', 'Цвет', 'Длина', 'Ширина' и 'Толщина'. Однако, в названии не упоминается 'Материал', 'Гарантийный срок', 'Сборка мебели', 'Страна происхождения' и 'Малые закупки'.
# LLM ans:	['Гарантийный срок', 'Малые закупки', 'Материал', 'Сборка мебели', 'Страна происхождения']
# correct ans:	['Страна происхождения', 'Гарантийный срок', 'Малые закупки', 'Сборка мебели', 'Материал']
# (5, 0, 0)
# ---------------
# Панель стеновая Corsica AM 2260 (луна, 2202х6х600 мм)
# В названии товара указаны ключи 'Цвет', 'Длина', 'Ширина' и 'Толщина', так как эти характеристики явно присутствуют в названии. Остальные ключи не представлены в названии товара.
# LLM ans:	['Гарантийный срок', 'Коллекция', 'Малые закупки', 'Материал', 'Сборка мебели', 'Страна происхождения']
# correct ans:	['Страна происхождения', 'Гарантийный срок', 'Малые закупки', 'Сборка мебели', 'Материал']
# (5, 1, 0)
# ---------------
# Карандаши цветные Koh-i-Noor Животные 18 карандашей 18 цветов шестигранные
# В названии товара указаны торговая марка 'Koh-i-Noor', количество карандашей и форма корпуса 'шестигранные', а также тематическая серия 'Животные'. Отсутствуют характеристики, которые не выражены полностью или не выражены через соответствующие фрагменты в названии: тип стержня, материал корпуса, цвет грифеля, диаметр грифеля, диаметр корпуса карандаша, тип упаковки, страна происхождения, и другие технические характеристики.
# LLM ans:	['Аксессуары в комплекте', 'Диаметр грифеля', 'Диаметр корпуса карандаша', 'Кол-во единиц продаж в промежуточной упаковке (кратность)', 'Количество единиц продаж в транспортной упаковке', 'Малые закупки', 'Материал корпуса', 'Особенности', 'Размер упаковки (ШхГхВ)', 'Страна происхождения', 'Тип стержня', 'Тип упаковки']
# correct ans:	['Диаметр корпуса карандаша', 'Кол-во единиц продаж в промежуточной упаковке (кратность)', 'Тип стержня', 'Страна происхождения', 'Особенности', 'Малые закупки', 'Аксессуары в комплекте', 'Размер упаковки (ШхГхВ)', 'Количество единиц продаж в транспортной упаковке', 'Длина корпуса', 'Тип упаковки', 'Материал корпуса', 'Диаметр грифеля']
# (12, 0, 1)
# ---------------
# Панель стеновая Corsica AM 660 (дуб бунратти, 602х6х600 мм)
# В названии товара указаны торговая марка (Corsica) и цвет (дуб бунратти), а также размеры (602х6х600 мм). Отсутствующие характеристики — те, которые не упомянуты полностью или частично в названии товара, например, материал, гарантийный срок и сборка мебели.
# LLM ans:	['Гарантийный срок', 'Коллекция', 'Малые закупки', 'Материал', 'Сборка мебели', 'Страна происхождения']
# correct ans:	['Страна происхождения', 'Гарантийный срок', 'Малые закупки', 'Сборка мебели', 'Материал']
# (5, 1, 0)
# ---------------
# Панель стеновая Corsica AM 860 (дуб бунратти, 802х6х600 мм)
# В названии товара указаны «Corsica», «дуб бунратти», «802х6х600 мм», но отсутсвуют такие характеристики, как «Коллекция», «Материал», «Гарантийный срок», «Сборка мебели» и «Страна происхождения». Также, хотя размеры указаны в названии, «Толщина» в названии представлена только как числовое значение без наименования ключа.
# LLM ans:	['Гарантийный срок', 'Коллекция', 'Материал', 'Сборка мебели', 'Страна происхождения']
# correct ans:	['Страна происхождения', 'Гарантийный срок', 'Малые закупки', 'Сборка мебели', 'Материал']
# (4, 1, 1)
# ---------------
# Панель стеновая Corsica AM 860 (луна, 802х6х600 мм)
# В названии явно указаны цвет 'луна' и размер 802х6х600 мм. Однако такие характеристики, как 'Коллекция', 'Материал', 'Гарантийный срок', 'Сборка мебели', 'Страна происхождения' и 'Малые закупки', не отражены в названии товара.
# LLM ans:	['Гарантийный срок', 'Коллекция', 'Малые закупки', 'Материал', 'Сборка мебели', 'Страна происхождения']
# correct ans:	['Страна происхождения', 'Гарантийный срок', 'Малые закупки', 'Сборка мебели', 'Материал']
# (5, 1, 0)
# ---------------
# Подставка для шкафа для одежды Практик LS-21-80
# В названии товара указаны 'Подставка для шкафа', 'для одежды' и 'Практик LS-21-80'. На основе этих фрагментов, ключи 'Торговая марка' и 'Вид' присутствуют. Код 'LS-21-80' не дает информации о других характеристиках, таких как 'Цвет покрытия', 'Материал', и габариты. Поэтому другие характеристики не представлены в названии товара.
# LLM ans:	['Высота', 'Гарантийный срок', 'Глубина', 'Малые закупки', 'Материал', 'Сборка мебели', 'Страна происхождения', 'Цвет покрытия', 'Ширина']
# correct ans:	['Ширина', 'Высота', 'Страна происхождения', 'Особенности', 'Гарантийный срок', 'Глубина', 'Малые закупки', 'Количество единиц продаж в транспортной упаковке', 'Сборка мебели', 'Цвет покрытия', 'Материал']
# (9, 0, 2)
# ---------------
# Уровень строительный ADA Titan 40 Plus 3 глазка 400 мм алюминиевый (А00509)
# В названии товара указаны следующие характеристики: 'Уровень строительный', 'ADA Titan 40 Plus', '3 глазка', '400 мм', 'алюминиевый'. Отсутствуют ключи 'Тип', 'Наличие магнита', 'Страна происхождения', и 'Вес', так как часть из них либо не представлена явно, либо соответствует другим общим словам в названии. 'Торговая марка' и 'Материал' в названии частично соответствуют ('ADA' и 'алюминиевый'), но 'Наличие магнита' и 'Вес' нет.
# LLM ans:	['Вес', 'Наличие магнита', 'Страна происхождения']
# correct ans:	['Страна происхождения', 'Наличие поверки', 'Малые закупки', 'Наличие магнита', 'Вес', 'Приказ 804. Код раздела', 'Количество единиц продаж в транспортной упаковке']
# (3, 0, 4)
# ---------------
# Доска магнитно-маркерная 60x90 см Attache Line лак (клетка)
# В названии товара представлены основные параметры: размеры, торговая марка, серия и тип покрытия. Однако некоторые атрибуты отсутствуют, такие как вид доски, тип рабочей поверхности, материал рамы, антибликовое покрытие и другие технические детали, не имеющие явного упоминания в названии.
# LLM ans:	['Антибликовое покрытие', 'Вид доски', 'Гарантийный срок', 'Гарантийный срок покрытия', 'Количество рабочих поверхностей', 'Крепление на стену', 'Материал рамы', 'Наличие выдвижной перекладины', 'Наличие полочки', 'Поворотный механизм', 'Размер рабочей поверхности', 'Серия досок', 'Торговая марка', 'Цвет доски']
# correct ans:	['Крепление на стену', 'Поворотный механизм', 'Вес', 'Вид доски', 'Приказ 804. Код раздела', 'Антибликовое покрытие', 'Особенности', 'Гарантийный срок', 'Гарантийный срок покрытия', 'Размер рабочей поверхности', 'Цвет доски', 'Страна происхождения', 'Расположение', 'Материал рамы', 'Количество рабочих поверхностей', 'Наличие полочки', 'Малые закупки', 'Наличие выдвижной перекладины', 'Количество единиц продаж в транспортной упаковке']
# (12, 2, 7)
# ---------------
# Пуф Софти СФ-57 оранжевый (велюр, 530x530x415 мм)
# В названии товара упоминаются цвет (оранжевый), материал обивки (велюр) и размеры (530x530x415 мм). Отсутствуют следующие характеристики: Коллекция, Форма, Материал опор (ножки), Сборка мебели, Гарантийный срок, Страна происхождения, Малые закупки и Высота опор.
# LLM ans:	['Высота опор', 'Гарантийный срок', 'Коллекция', 'Малые закупки', 'Материал опор (ножки)', 'Сборка мебели', 'Страна происхождения', 'Форма']
# correct ans:	['Страна происхождения', 'Особенности', 'Гарантийный срок', 'Высота опор', 'Малые закупки', 'Форма', 'Сборка мебели', 'Коллекция', 'Материал опор (ножки)']
# (8, 0, 1)
# ---------------
# Доска-планинг магнитно-маркерная 60x90 см Attache Line лак
# В названии товара указаны Торговая марка (Attache Line), размер доски (60x90 см), Тип рабочей поверхности (магнитно-маркерная) и Тип покрытия доски (лак). Вид линовки (планинг) частично представлен через слово 'доска-планинг'. Остальные характеристики отсутствуют в названии.
# LLM ans:	['Антибликовое покрытие', 'Вид доски', 'Гарантийный срок', 'Гарантийный срок покрытия', 'Количество рабочих поверхностей', 'Крепление на стену', 'Наличие выдвижной перекладины', 'Наличие полочки', 'Особенности', 'Поворотный механизм', 'Размер рабочей поверхности', 'Серия досок', 'Страна происхождения', 'Торговая марка', 'Цвет доски']
# correct ans:	['Крепление на стену', 'Поворотный механизм', 'Вес', 'Вид доски', 'Приказ 804. Код раздела', 'Антибликовое покрытие', 'Особенности', 'Гарантийный срок', 'Гарантийный срок покрытия', 'Размер рабочей поверхности', 'Цвет доски', 'Страна происхождения', 'Расположение', 'Материал рамы', 'Количество рабочих поверхностей', 'Наличие полочки', 'Малые закупки', 'Наличие выдвижной перекладины', 'Количество единиц продаж в транспортной упаковке']
# (13, 2, 6)
# ---------------
# Пуф Софти СФ-57 синий (велюр, 530x530x415 мм)
# В названии товара указаны цвет обивки (синий), материал обивки (велюр) и размеры (530x530x415 мм), что соответствует ключам 'Цвет обивки', 'Материал обивки', 'Высота', 'Ширина' и 'Глубина'. Отсутствующие в названии ключи характеристики 'Форма', 'Материал опор (ножки)', 'Гарантийный срок', 'Страна происхождения', и 'Высота опор'.
# LLM ans:	['Высота опор', 'Гарантийный срок', 'Материал опор (ножки)', 'Страна происхождения', 'Форма']
# correct ans:	['Страна происхождения', 'Особенности', 'Гарантийный срок', 'Высота опор', 'Малые закупки', 'Форма', 'Сборка мебели', 'Коллекция', 'Материал опор (ножки)']
# (5, 0, 4)
# ---------------
# Ручка гелевая неавтоматическая Deli Daily синяя (толщина линии 0.35 мм)
# В названии товара указаны: 'гелевая', 'неавтоматическая', 'синяя', 'толщина линии 0.35 мм'. Ключи 'Торговая марка', 'Цвет чернил', 'Толщина линии письма', 'Материал корпуса' и 'Цвет корпуса' частично совпадают с названием, но 'Масляная', 'Форма наконечника', 'Материал наконечника', 'Наличие резиновой манжетки', 'Возможность смены стержня', 'Клип', 'Покрытие soft touch', 'Форма корпуса', 'Подходит под персонализацию', 'Тип упаковки', 'Кол-во штук в единице продажи', 'Кол-во единиц продаж в промежуточной упаковке (кратность)', 'Количество единиц продаж в транспортной упаковке', 'Страна происхождения', 'Малые закупки', 'Диаметр шарика', и 'Размер' не указаны в названии.
# LLM ans:	['Возможность смены стержня', 'Диаметр шарика', 'Клип', 'Кол-во единиц продаж в промежуточной упаковке (кратность)', 'Кол-во штук в единице продажи', 'Количество единиц продаж в транспортной упаковке', 'Малые закупки', 'Масляная', 'Материал наконечника', 'Наличие резиновой манжетки', 'Подходит под персонализацию', 'Покрытие soft touch', 'Размер', 'Страна происхождения', 'Тип упаковки', 'Форма корпуса', 'Форма наконечника']
# correct ans:	['Возможность смены стержня', 'Масляная', 'Страна происхождения', 'Размер', 'Единица продажи', 'Покрытие soft touch', 'Кол-во единиц продаж в промежуточной упаковке (кратность)', 'Наличие резиновой манжетки', 'Малые закупки', 'Подходит под персонализацию', 'Клип', 'Материал наконечника', 'Диаметр шарика', 'Рисунок на корпусе', 'Материал корпуса', 'Форма наконечника', 'Цвет корпуса', 'Длина стержня', 'Кол-во штук в единице продажи', 'Количество единиц продаж в транспортной упаковке', 'Форма корпуса', 'Тип упаковки', 'Тип механизма']
# (17, 0, 6)
# ---------------
# Набор настольный Attache металлический черный (6 предметов)
# В названии товара указаны следующие характеристики: торговая марка (Attache), материал (металлический) и цвет (черный). Однако такие характеристики, как наличие коврика, наличие лотка для бумаг, комплектация, малые закупки, подарочная упаковка, страна происхождения и количество единиц продаж в транспортной упаковке, не представлены или не зафиксированы в названии прямо.
# LLM ans:	['Количество единиц продаж в транспортной упаковке', 'Комплектация', 'Малые закупки', 'Наличие коврика', 'Подарочная упаковка', 'Страна происхождения']
# correct ans:	['Подарочная упаковка', 'Страна происхождения', 'Наличие лотка для бумаг', 'Малые закупки', 'Комплектация', 'Наличие коврика', 'Количество единиц продаж в транспортной упаковке']
# (6, 0, 1)
# ---------------
# Карандаши цветные Kores Kolores Style 26 карандашей 26 цветов трёхгранные (металлические, неоновые, пастельные)
# Название товара включает 'Kores Kolores Style', '26 карандашей', '26 цветов', 'трёхгранные', и 'металлические, неоновые, пастельные'. Из этих ключей в характеристике у нас есть 'Торговая марка', 'Количество цветов', 'Кол-во штук в единице продажи', и 'Особенности'. Остальные характеристики не найдены в названии товара, за исключением 'Тип упаковки', так как оно является частью 'Особенности'.
# LLM ans:	['Диаметр грифеля', 'Диаметр корпуса карандаша', 'Длина корпуса', 'Кол-во единиц продаж в промежуточной упаковке (кратность)', 'Малые закупки', 'Материал корпуса', 'Размер упаковки (ШхГхВ)', 'Страна происхождения', 'Тип стержня', 'Цвет грифеля']
# correct ans:	['Диаметр корпуса карандаша', 'Кол-во единиц продаж в промежуточной упаковке (кратность)', 'Тип стержня', 'Страна происхождения', 'Малые закупки', 'Единица продажи', 'Аксессуары в комплекте', 'Размер упаковки (ШхГхВ)', 'Цвет грифеля', 'Количество единиц продаж в транспортной упаковке', 'Длина корпуса', 'Тип упаковки', 'Материал корпуса', 'Диаметр грифеля']
# (10, 0, 4)
# ---------------
# Карандаши цветные Kores Kolores 13 карандашей 13 цветов трёхгранные
# В названии товара упоминаются следующие ключи: 'Карандаши цветные', 'Kores Kolores', '13 карандашей', '13 цветов', 'трёхгранные'. Из характеристик, ключи 'Тип стержня', 'Материал корпуса', 'Цвет грифеля', 'Диаметр грифеля', 'Длина корпуса', 'Диаметр корпуса карандаша', 'Тип упаковки', 'Аксессуары в комплекте', 'Размер упаковки (ШхГхВ)', 'Малые закупки', 'Кол-во единиц продаж в промежуточной упаковке (кратность)', 'Количество единиц продаж в транспортной упаковке' и 'Страна происхождения' не представлены или не соответствуют фрагментам в названии товара.
# LLM ans:	['Аксессуары в комплекте', 'Диаметр грифеля', 'Диаметр корпуса карандаша', 'Длина корпуса', 'Кол-во единиц продаж в промежуточной упаковке (кратность)', 'Количество единиц продаж в транспортной упаковке', 'Малые закупки', 'Материал корпуса', 'Размер упаковки (ШхГхВ)', 'Страна происхождения', 'Тип стержня', 'Тип упаковки', 'Цвет грифеля']
# correct ans:	['Диаметр корпуса карандаша', 'Кол-во единиц продаж в промежуточной упаковке (кратность)', 'Тип стержня', 'Страна происхождения', 'Особенности', 'Малые закупки', 'Единица продажи', 'Аксессуары в комплекте', 'Размер упаковки (ШхГхВ)', 'Цвет грифеля', 'Количество единиц продаж в транспортной упаковке', 'Длина корпуса', 'Тип упаковки', 'Материал корпуса', 'Диаметр грифеля']
# (13, 0, 2)
# ---------------
# Ручка гелевая неавтоматическая Bruno Visconti UniWrite синяя корпус soft touch (толщина линии 0.4 мм, 20-0305/04)
# В названии товара упомянуты 'Ручка гелевая неавтоматическая', 'Bruno Visconti UniWrite', 'синяя', 'корпус soft touch', и 'толщина линии 0.4 мм'. Однако характеристики 'Цвет чернил', 'Возможность смены стержня', 'Форма корпуса', 'Цвет корпуса', 'Рисунок на корпусе', и 'Диаметр шарика' явно или частично не представлены.
# LLM ans:	['Возможность смены стержня', 'Диаметр шарика', 'Рисунок на корпусе', 'Торговая марка', 'Форма корпуса', 'Цвет корпуса']
# correct ans:	['Возможность смены стержня', 'Единица продажи', 'Кол-во единиц продаж в промежуточной упаковке (кратность)', 'Наличие резиновой манжетки', 'Подходит под персонализацию', 'Диаметр шарика', 'Материал наконечника', 'Форма наконечника', 'Цвет корпуса', 'Длина стержня', 'Кол-во штук в единице продажи', 'Тип упаковки', 'Масляная', 'Страна происхождения', 'Размер', 'Малые закупки', 'Клип', 'Рисунок на корпусе', 'Количество единиц продаж в транспортной упаковке', 'Форма корпуса', 'Тип механизма']
# (5, 1, 16)
# ---------------
